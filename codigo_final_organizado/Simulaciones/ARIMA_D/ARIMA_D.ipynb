# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %% [markdown]
# ## General

# %%
from runner import main_test_reducido_doble

main_test_reducido_doble()
# Out:
# ================================================================================
# TEST REDUCIDO: DOBLE MODALIDAD (d=1,2)
# ================================================================================
# ================================================================================
# 🚀 PIPELINE MULTI-D CORREGIDO: ARIMA_I(p,d,q) - TODOS LOS MODELOS
# ================================================================================
# 📊 Total de escenarios: 4
#    - Valores de d: [1, 2]
#    - ARMA configs: 2
#    - Distribuciones: 1
#    - Varianzas: 1
#    - Modalidades por escenario: 2 (SIN_DIFF, CON_DIFF)
#    - Modelos: TODOS (9 modelos)
#    - Simulador base: ARIMASimulation (consistente con Pipeline140)
#    - Total filas esperadas: 96
# 📦 Procesando lote 1/1...
#    ✅ 96 filas guardadas
# ✅ Simulación completa: resultados_TEST_DOBLE_MODALIDAD.xlsx
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - DOBLE MODALIDAD (SIN_DIFF vs CON_DIFF)
# ================================================================================
#
# ================================================================================
# 🔍 1. COMPARACIÓN GLOBAL POR MODALIDAD
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      MCPS                      5.371024
# 2      AV-MCPS                   5.586868
# 3      Block Bootstrapping       6.148799
# 4      EnCQR-LSTM                6.201000
# 5      DeepAR                    6.245721
# 6      Sieve Bootstrap           6.268422
# 7      LSPM                      6.340207
# 8      AREPD                     6.378662
# 9      LSPMW                     6.628815
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           6.288443
# 2      LSPM                      12.711703
# 3      LSPMW                     45.535672
# 4      AV-MCPS                   85.394530
# 5      EnCQR-LSTM                116.596745
# 6      MCPS                      120.598129
# 7      DeepAR                    186.871766
# 8      AREPD                     357.141083
# 9      Block Bootstrapping       391.184471
#
# ================================================================================
# 📊 2. RANKING POR CADA VALOR DE d (AMBAS MODALIDADES)
# ================================================================================
#
# ======================================================================
# d = 1
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      DeepAR                    0.580525
#   2      Block Bootstrapping       0.594968
#   3      Sieve Bootstrap           0.596922
#   4      LSPM                      0.628496
#   5      AREPD                     0.644073
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.649398
#   2      DeepAR                    0.857486
#   3      LSPM                      0.919114
#   4      LSPMW                     1.165654
#   5      AV-MCPS                   2.964468
#
# ======================================================================
# d = 2
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      MCPS                      10.067865
#   2      AV-MCPS                   10.483468
#   3      EnCQR-LSTM                11.566877
#   4      Block Bootstrapping       11.702630
#   5      DeepAR                    11.910917
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           11.927489
#   2      LSPM                      24.504292
#   3      LSPMW                     89.905691
#   4      AV-MCPS                   167.824592
#   5      EnCQR-LSTM                226.306700
#
# ================================================================================
# 🎯 3. VICTORIAS POR MODALIDAD (Mejor modelo por paso)
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
#   DeepAR                   :   14 victorias (29.2%)
#   MCPS                     :   11 victorias (22.9%)
#   Block Bootstrapping      :    9 victorias (18.8%)
#   LSPM                     :    5 victorias (10.4%)
#   AV-MCPS                  :    4 victorias (8.3%)
#   Sieve Bootstrap          :    4 victorias (8.3%)
#   LSPMW                    :    1 victorias (2.1%)
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
#   Sieve Bootstrap          :   36 victorias (75.0%)
#   DeepAR                   :    9 victorias (18.8%)
#   LSPM                     :    2 victorias (4.2%)
#   LSPMW                    :    1 victorias (2.1%)
#
# ================================================================================
# 📈 4. TENDENCIAS: Desempeño según d aumenta
# ================================================================================
#
# ======================================================================
# MODALIDAD: CON_DIFF
# ======================================================================
#
# Modelo                    d=1    d=2
# ---------------------------------------
# AREPD                     0.6441  12.1133
# AV-MCPS                   0.6903  10.4835
# Block Bootstrapping       0.5950  11.7026
# DeepAR                    0.5805  11.9109
# EnCQR-LSTM                0.8351  11.5669
# LSPM                      0.6285  12.0519
# LSPMW                     0.6660  12.5917
# MCPS                      0.6742  10.0679
# Sieve Bootstrap           0.5969  11.9399
#
# ======================================================================
# MODALIDAD: SIN_DIFF
# ======================================================================
#
# Modelo                    d=1    d=2
# ---------------------------------------
# AREPD                     10.4909  703.7913
# AV-MCPS                   2.9645  167.8246
# Block Bootstrapping       10.9476  771.4214
# DeepAR                    0.8575  372.8860
# EnCQR-LSTM                6.8868  226.3067
# LSPM                      0.9191  24.5043
# LSPMW                     1.1657  89.9057
# MCPS                      3.6097  237.5865
# Sieve Bootstrap           0.6494  11.9275
#
# ================================================================================
# ⚖️  5. COMPARACIÓN DIRECTA: SIN_DIFF vs CON_DIFF
# ================================================================================
#
# Modelo                    SIN_DIFF     CON_DIFF     Diferencia   Mejor
# ---------------------------------------------------------------------------
# AREPD                     357.141083   6.378662   -350.762420   CON_DIFF
# AV-MCPS                   85.394530   5.586868   -79.807662   CON_DIFF
# Block Bootstrapping       391.184471   6.148799   -385.035672   CON_DIFF
# DeepAR                    186.871766   6.245721   -180.626045   CON_DIFF
# EnCQR-LSTM                116.596745   6.201000   -110.395745   CON_DIFF
# LSPM                      12.711703   6.340207   -6.371496   CON_DIFF
# LSPMW                     45.535672   6.628815   -38.906857   CON_DIFF
# MCPS                      120.598129   5.371024   -115.227105   CON_DIFF
# Sieve Bootstrap           6.288443   6.268422   -0.020021   CON_DIFF
#
# ================================================================================
# 🎲 6. MEJOR VALOR DE d PARA CADA MODELO Y MODALIDAD
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
#
# Modelo                    Mejor d    CRPS en ese d
# ------------------------------------------------------------
# AREPD                     1          0.644073
# AV-MCPS                   1          0.690268
# Block Bootstrapping       1          0.594968
# DeepAR                    1          0.580525
# EnCQR-LSTM                1          0.835123
# LSPM                      1          0.628496
# LSPMW                     1          0.665955
# MCPS                      1          0.674183
# Sieve Bootstrap           1          0.596922
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
#
# Modelo                    Mejor d    CRPS en ese d
# ------------------------------------------------------------
# AREPD                     1          10.490870
# AV-MCPS                   1          2.964468
# Block Bootstrapping       1          10.947552
# DeepAR                    1          0.857486
# EnCQR-LSTM                1          6.886790
# LSPM                      1          0.919114
# LSPMW                     1          1.165654
# MCPS                      1          3.609735
# Sieve Bootstrap           1          0.649398
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✓ MEJOR MODALIDAD GLOBAL:
#   • SIN_DIFF: CRPS promedio = 146.924727
#   • CON_DIFF: CRPS promedio = 6.129947
#   → GANADOR: CON_DIFF (diferencia: 140.794780)
#
# ✓ MEJOR MODELO GLOBAL:
#   → Sieve Bootstrap: CRPS = 6.278433
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 318.4s
#     Paso        Proceso  p  d  q ARMA_base Distribución  Varianza Modalidad  \
# 0      1  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0  SIN_DIFF
# 1      2  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0  SIN_DIFF
# 2      3  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0  SIN_DIFF
# 3      4  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0  SIN_DIFF
# 4      5  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0  SIN_DIFF
# ..   ...            ... .. .. ..       ...          ...       ...       ...
# 91     8  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0  CON_DIFF
# 92     9  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0  CON_DIFF
# 93    10  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0  CON_DIFF
# 94    11  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0  CON_DIFF
# 95    12  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0  CON_DIFF
#
#     Valor_Observado      AREPD   AV-MCPS  Block Bootstrapping    DeepAR  \
# 0        -10.596321   2.329352  0.625013             2.503322  0.576056
# 1        -12.130182   1.117990  0.750059             1.356239  0.614050
# 2        -11.266354   2.077124  0.642772             2.231517  0.595779
# 3        -11.594880   1.456107  0.589550             1.606264  0.556775
# 4        -11.656204   1.702349  1.169150             1.912559  0.567433
# ..              ...        ...       ...                  ...       ...
# 91     -1570.095839   3.576614  2.205202             3.992682  4.741314
# 92     -1576.700218   4.508068  2.020389             4.548944  5.385994
# 93     -1584.074811   6.768471  2.096551             5.591894  6.678957
# 94     -1592.467470   7.990534  2.528312             6.271151  7.237734
# 95     -1600.336540  10.092546  3.766965             7.111986  8.327734
#
#     EnCQR-LSTM      LSPM      LSPMW      MCPS  Sieve Bootstrap
# 0     1.759640  0.595247   0.605188  0.971398         0.576370
# 1     1.686371  0.951887   1.553298  0.636085         0.851131
# 2     1.697638  1.561462   0.669913  0.659684         0.809713
# 3     1.657518  0.887668   1.079819  0.634183         0.621405
# 4     1.660099  0.686845   0.864265  0.606370         0.906183
# ..         ...       ...        ...       ...              ...
# 91    4.327781  4.356318   3.991374  3.259719         4.465389
# 92    4.300342  5.808613   5.316507  2.279814         4.965222
# 93    4.428529  7.647392   7.953207  1.065652         6.259075
# 94    4.636252  7.518744   9.244775  0.976464         7.128925
# 95    5.379501  9.049471  11.388718  1.644973         7.816093
#
# [96 rows x 19 columns]

# %%
from runner import main_full_2800

main_full_2800()
# Out:
# ================================================================================
# INICIANDO SIMULACIÓN COMPLETA: 2,800 FILAS
# ================================================================================
# ================================================================================
# 🚀 PIPELINE MULTI-D CORREGIDO: ARIMA_I(p,d,q) - TODOS LOS MODELOS
# ================================================================================
# 📊 Total de escenarios: 980
#    - Valores de d: [1, 2, 3, 4, 5, 7, 10]
#    - ARMA configs: 7
#    - Distribuciones: 5
#    - Varianzas: 4
#    - Modalidades por escenario: 2 (SIN_DIFF, CON_DIFF)
#    - Modelos: TODOS (9 modelos)
#    - Simulador base: ARIMASimulation (consistente con Pipeline140)
#    - Total filas esperadas: 23520
# 📦 Procesando lote 1/49...
#    ✅ 480 filas guardadas
# 📦 Procesando lote 2/49...
#    ✅ 960 filas guardadas
# 📦 Procesando lote 3/49...
#    ✅ 1440 filas guardadas
# 📦 Procesando lote 4/49...
#    ✅ 1920 filas guardadas
# 📦 Procesando lote 5/49...
#    ✅ 2400 filas guardadas
# 📦 Procesando lote 6/49...
#    ✅ 2880 filas guardadas
# 📦 Procesando lote 7/49...
#    ✅ 3360 filas guardadas
# 📦 Procesando lote 8/49...
#    ✅ 3840 filas guardadas
# 📦 Procesando lote 9/49...
#    ✅ 4320 filas guardadas
# 📦 Procesando lote 10/49...
#    ✅ 4800 filas guardadas
# 📦 Procesando lote 11/49...
#    ✅ 5280 filas guardadas
# 📦 Procesando lote 12/49...
#    ✅ 5760 filas guardadas
# 📦 Procesando lote 13/49...
#    ✅ 6240 filas guardadas
# 📦 Procesando lote 14/49...
#    ✅ 6720 filas guardadas
# 📦 Procesando lote 15/49...
#    ✅ 7200 filas guardadas
# 📦 Procesando lote 16/49...
#    ✅ 7680 filas guardadas
# 📦 Procesando lote 17/49...
#    ✅ 8160 filas guardadas
# 📦 Procesando lote 18/49...
#    ✅ 8640 filas guardadas
# 📦 Procesando lote 19/49...
#    ✅ 9120 filas guardadas
# 📦 Procesando lote 20/49...
#    ✅ 9600 filas guardadas
# 📦 Procesando lote 21/49...
#    ✅ 10080 filas guardadas
# 📦 Procesando lote 22/49...
#    ✅ 10560 filas guardadas
# 📦 Procesando lote 23/49...
#    ✅ 11040 filas guardadas
# 📦 Procesando lote 24/49...
#    ✅ 11520 filas guardadas
# 📦 Procesando lote 25/49...
#    ✅ 12000 filas guardadas
# 📦 Procesando lote 26/49...
#    ✅ 12480 filas guardadas
# 📦 Procesando lote 27/49...
#    ✅ 12960 filas guardadas
# 📦 Procesando lote 28/49...
#    ✅ 13440 filas guardadas
# 📦 Procesando lote 29/49...
#    ✅ 13920 filas guardadas
# 📦 Procesando lote 30/49...
#    ✅ 14400 filas guardadas
# 📦 Procesando lote 31/49...
#    ✅ 14880 filas guardadas
# 📦 Procesando lote 32/49...
#    ✅ 15360 filas guardadas
# 📦 Procesando lote 33/49...
#    ✅ 15840 filas guardadas
# 📦 Procesando lote 34/49...
#    ✅ 16320 filas guardadas
# 📦 Procesando lote 35/49...
#    ✅ 16800 filas guardadas
# 📦 Procesando lote 36/49...
#    ✅ 17280 filas guardadas
# 📦 Procesando lote 37/49...
#    ✅ 17760 filas guardadas
# 📦 Procesando lote 38/49...
#    ✅ 18240 filas guardadas
# 📦 Procesando lote 39/49...
#    ✅ 18720 filas guardadas
# 📦 Procesando lote 40/49...
#    ✅ 19200 filas guardadas
# 📦 Procesando lote 41/49...
#    ✅ 19680 filas guardadas
# 📦 Procesando lote 42/49...
#    ✅ 20160 filas guardadas
# 📦 Procesando lote 43/49...
#    ✅ 20640 filas guardadas
# 📦 Procesando lote 44/49...
#    ✅ 21120 filas guardadas
# 📦 Procesando lote 45/49...
#    ✅ 21600 filas guardadas
# 📦 Procesando lote 46/49...
#    ✅ 22080 filas guardadas
# 📦 Procesando lote 47/49...
#    ✅ 22560 filas guardadas
# 📦 Procesando lote 48/49...
#    ✅ 23040 filas guardadas
# 📦 Procesando lote 49/49...
#    ✅ 23520 filas guardadas
# ✅ Simulación completa: resultados_ARIMA_d1_a_d10_DOBLE_MODALIDAD_COMPLETO.xlsx
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - DOBLE MODALIDAD (SIN_DIFF vs CON_DIFF)
# ================================================================================
#
# ================================================================================
# 🔍 1. COMPARACIÓN GLOBAL POR MODALIDAD
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           12077242.578518
# 2      LSPM                      9456371513399.662109
# 3      LSPMW                     58885179490417.242188
# 4      EnCQR-LSTM                76541393366994.906250
# 5      AV-MCPS                   83860425412443.250000
# 6      MCPS                      140366241397670.140625
# 7      DeepAR                    199480470965866.937500
# 8      AREPD                     201457660108008.937500
# 9      Block Bootstrapping       204721713978636.656250
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           270051528.712447
# 2      LSPM                      248407648393359.937500
# 3      LSPMW                     1522650142051661.750000
# 4      EnCQR-LSTM                2027490797189003.250000
# 5      AV-MCPS                   2166395963101891.500000
# 6      MCPS                      3529832433626792.000000
# 7      DeepAR                    4853139199714622.000000
# 8      AREPD                     4869371911059881.000000
# 9      Block Bootstrapping       4937263440564837.000000
#
# ================================================================================
# 📊 2. RANKING POR CADA VALOR DE d (AMBAS MODALIDADES)
# ================================================================================
#
# ======================================================================
# d = 1
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.548580
#   2      DeepAR                    0.570322
#   3      LSPM                      0.664633
#   4      MCPS                      0.683067
#   5      Block Bootstrapping       0.699491
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.549507
#   2      LSPM                      1.134104
#   3      DeepAR                    2.657471
#   4      MCPS                      2.691116
#   5      AV-MCPS                   3.029405
#
# ======================================================================
# d = 2
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      EnCQR-LSTM                28.191109
#   2      Sieve Bootstrap           28.832787
#   3      LSPM                      28.913598
#   4      AV-MCPS                   29.276382
#   5      MCPS                      29.343725
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           28.846607
#   2      LSPM                      58.163262
#   3      LSPMW                     218.434103
#   4      AV-MCPS                   493.705666
#   5      MCPS                      606.379519
#
# ======================================================================
# d = 3
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           27.260319
#   2      LSPM                      54.948613
#   3      LSPMW                     206.815818
#   4      AV-MCPS                   513.574904
#   5      MCPS                      596.269918
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           27.259840
#   2      LSPM                      4680.645402
#   3      LSPMW                     30721.693835
#   4      AV-MCPS                   51365.925107
#   5      EnCQR-LSTM                64392.068103
#
# ======================================================================
# d = 4
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           27.045442
#   2      LSPM                      4335.482842
#   3      LSPMW                     27775.585299
#   4      AV-MCPS                   50680.783564
#   5      EnCQR-LSTM                57558.214930
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           27.049973
#   2      LSPM                      401817.520224
#   3      LSPMW                     2576969.001247
#   4      AV-MCPS                   3946194.012936
#   5      EnCQR-LSTM                4030683.788336
#
# ======================================================================
# d = 5
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           28.211253
#   2      LSPM                      482293.413379
#   3      LSPMW                     3089957.108081
#   4      AV-MCPS                   4647295.854732
#   5      EnCQR-LSTM                4791721.657585
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           34.516324
#   2      LSPM                      31959278.309843
#   3      LSPMW                     202282824.245379
#   4      EnCQR-LSTM                283645076.265423
#   5      AV-MCPS                   301596277.797565
#
# ======================================================================
# d = 7
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           1261.129090
#   2      LSPM                      1292964334.799403
#   3      LSPMW                     8139888003.539444
#   4      EnCQR-LSTM                10554398124.217987
#   5      AV-MCPS                   12007879160.781900
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           66863.287103
#   2      LSPM                      53727782889.187164
#   3      LSPMW                     334035903055.759399
#   4      EnCQR-LSTM                433742937238.895264
#   5      AV-MCPS                   491505184098.564941
#
# ======================================================================
# d = 10
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           84539325.022159
#   2      LSPM                      66193307142749.421875
#   3      LSPMW                     412188113426947.062500
#   4      EnCQR-LSTM                535779194320910.187500
#   5      AV-MCPS                   587010965309421.875000
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           1890293719.477777
#   2      LSPM                      1738799778604794.500000
#   3      LSPMW                     10658216753567838.000000
#   4      EnCQR-LSTM                14192001549645004.000000
#   5      AV-MCPS                   15164279930934808.000000
#
# ================================================================================
# 🎯 3. VICTORIAS POR MODALIDAD (Mejor modelo por paso)
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
#   Sieve Bootstrap          : 9366 victorias (79.6%)
#   LSPM                     :  433 victorias (3.7%)
#   EnCQR-LSTM               :  347 victorias (3.0%)
#   DeepAR                   :  346 victorias (2.9%)
#   LSPMW                    :  341 victorias (2.9%)
#   Block Bootstrapping      :  331 victorias (2.8%)
#   MCPS                     :  223 victorias (1.9%)
#   AREPD                    :  198 victorias (1.7%)
#   AV-MCPS                  :  175 victorias (1.5%)
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
#   Sieve Bootstrap          : 11404 victorias (97.0%)
#   LSPM                     :  159 victorias (1.4%)
#   DeepAR                   :   84 victorias (0.7%)
#   LSPMW                    :   69 victorias (0.6%)
#   MCPS                     :   29 victorias (0.2%)
#   AV-MCPS                  :   15 victorias (0.1%)
#
# ================================================================================
# 📈 4. TENDENCIAS: Desempeño según d aumenta
# ================================================================================
#
# ======================================================================
# MODALIDAD: CON_DIFF
# ======================================================================
#
# Modelo                    d=1    d=2    d=3    d=4    d=5    d=7    d=10
# --------------------------------------------------------------------------
# AREPD                     0.7485  33.8483  1668.7932  199521.2751  18828212.0560  37785982911.2400  1410165815743714.5000
# AV-MCPS                   0.6998  29.2764  513.5749  50680.7836  4647295.8547  12007879160.7819  587010965309421.8750
# Block Bootstrapping       0.6995  34.4102  1822.0214  211562.0982  19667379.5625  38798178024.4242  1433013179791633.7500
# DeepAR                    0.5703  30.2758  1018.0384  160237.4994  16875825.7409  35937620393.9189  1396327342103562.7500
# EnCQR-LSTM                0.8877  28.1911  621.0127  57558.2149  4791721.6576  10554398124.2180  535779194320910.1875
# LSPM                      0.6646  28.9136  54.9486  4335.4828  482293.4134  1292964334.7994  66193307142749.4219
# LSPMW                     0.8202  29.8079  206.8158  27775.5853  3089957.1081  8139888003.5394  412188113426947.0625
# MCPS                      0.6831  29.3437  596.2699  85253.8510  9156465.7286  22094331867.4675  982541586209477.7500
# Sieve Bootstrap           0.5486  28.8328  27.2603  27.0454  28.2113  1261.1291  84539325.0222
#
# ======================================================================
# MODALIDAD: SIN_DIFF
# ======================================================================
#
# Modelo                    d=1    d=2    d=3    d=4    d=5    d=7    d=10
# --------------------------------------------------------------------------
# AREPD                     7.7458  1690.6302  224661.9280  15706235.6787  1064189171.0883  1393436492059.6001  34084208860805336.0000
# AV-MCPS                   3.0294  493.7057  51365.9251  3946194.0129  301596277.7976  491505184098.5649  15164279930934808.0000
# Block Bootstrapping       8.6599  1842.9216  239041.5702  16400704.4187  1100385677.7894  1424477932023.2080  34559418488994568.0000
# DeepAR                    2.6575  1032.3643  173959.1630  14005904.0101  992793839.8827  1345866062803.3613  33970627524964820.0000
# EnCQR-LSTM                6.0796  623.1498  64392.0681  4030683.7883  283645076.2654  433742937238.8953  14192001549645004.0000
# LSPM                      1.1341  58.1633  4680.6454  401817.5202  31959278.3098  53727782889.1872  1738799778604794.5000
# LSPMW                     4.0150  218.4341  30721.6938  2576969.0012  202282824.2454  334035903055.7594  10658216753567838.0000
# MCPS                      2.6911  606.3795  94684.8101  7647897.0934  573502194.4014  869544076802.2577  24707956910065352.0000
# Sieve Bootstrap           0.5495  28.8466  27.2598  27.0500  34.5163  66863.2871  1890293719.4778
#
# ================================================================================
# ⚖️  5. COMPARACIÓN DIRECTA: SIN_DIFF vs CON_DIFF
# ================================================================================
#
# Modelo                    SIN_DIFF     CON_DIFF     Diferencia   Mejor
# ---------------------------------------------------------------------------
# AREPD                     4869371911059881.000000   201457660108008.937500   -4667914250951872.000000   CON_DIFF
# AV-MCPS                   2166395963101891.500000   83860425412443.250000   -2082535537689448.250000   CON_DIFF
# Block Bootstrapping       4937263440564837.000000   204721713978636.656250   -4732541726586200.000000   CON_DIFF
# DeepAR                    4853139199714622.000000   199480470965866.937500   -4653658728748755.000000   CON_DIFF
# EnCQR-LSTM                2027490797189003.250000   76541393366994.906250   -1950949403822008.250000   CON_DIFF
# LSPM                      248407648393359.937500   9456371513399.662109   -238951276879960.281250   CON_DIFF
# LSPMW                     1522650142051661.750000   58885179490417.242188   -1463764962561244.500000   CON_DIFF
# MCPS                      3529832433626792.000000   140366241397670.140625   -3389466192229122.000000   CON_DIFF
# Sieve Bootstrap           270051528.712447   12077242.578518   -257974286.133929   CON_DIFF
#
# ================================================================================
# 🎲 6. MEJOR VALOR DE d PARA CADA MODELO Y MODALIDAD
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
#
# Modelo                    Mejor d    CRPS en ese d
# ------------------------------------------------------------
# AREPD                     1          0.748471
# AV-MCPS                   1          0.699830
# Block Bootstrapping       1          0.699491
# DeepAR                    1          0.570322
# EnCQR-LSTM                1          0.887702
# LSPM                      1          0.664633
# LSPMW                     1          0.820184
# MCPS                      1          0.683067
# Sieve Bootstrap           1          0.548580
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
#
# Modelo                    Mejor d    CRPS en ese d
# ------------------------------------------------------------
# AREPD                     1          7.745759
# AV-MCPS                   1          3.029405
# Block Bootstrapping       1          8.659902
# DeepAR                    1          2.657471
# EnCQR-LSTM                1          6.079569
# LSPM                      1          1.134104
# LSPMW                     1          4.015035
# MCPS                      1          2.691116
# Sieve Bootstrap           1          0.549507
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✓ MEJOR MODALIDAD GLOBAL:
#   • SIN_DIFF: CRPS promedio = 2683839089528175.000000
#   • CON_DIFF: CRPS promedio = 108307718701186.703125
#   → GANADOR: CON_DIFF (diferencia: 2575531370826988.500000)
#
# ✓ MEJOR MODELO GLOBAL:
#   → Sieve Bootstrap: CRPS = 141064385.645483
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 52520.2s (14.59 horas)
#        Paso         Proceso  p   d  q  ARMA_base Distribución  Varianza  \
# 0         1   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# 1         2   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# 2         3   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# 3         4   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# 4         5   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# ...     ...             ... ..  .. ..        ...          ...       ...
# 23515     8  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 23516     9  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 23517    10  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 23518    11  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 23519    12  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
#
#       Modalidad  Valor_Observado         AREPD       AV-MCPS  \
# 0      SIN_DIFF    -4.738819e+00  1.041718e+00  2.795142e-01
# 1      SIN_DIFF    -5.424782e+00  4.999805e-01  3.354356e-01
# 2      SIN_DIFF    -5.038467e+00  9.289181e-01  2.874566e-01
# 3      SIN_DIFF    -5.185388e+00  6.511909e-01  2.636547e-01
# 4      SIN_DIFF    -5.212813e+00  7.613135e-01  5.228589e-01
# ...         ...              ...           ...           ...
# 23515  CON_DIFF     1.698657e+17  5.661457e+15  2.564760e+15
# 23516  CON_DIFF     1.773095e+17  5.881895e+15  2.897592e+15
# 23517  CON_DIFF     1.850418e+17  6.109456e+15  3.150833e+15
# 23518  CON_DIFF     1.930724e+17  6.344321e+15  3.453590e+15
# 23519  CON_DIFF     2.014112e+17  6.586672e+15  3.736797e+15
#
#        Block Bootstrapping        DeepAR    EnCQR-LSTM          LSPM  \
# 0             1.119520e+00  2.576202e-01  7.596134e-01  2.662027e-01
# 1             6.065287e-01  2.746116e-01  7.319968e-01  4.256969e-01
# 2             9.979647e-01  2.664404e-01  7.320636e-01  6.983070e-01
# 3             7.183433e-01  2.489975e-01  7.160075e-01  3.969771e-01
# 4             8.553222e-01  2.537637e-01  7.161896e-01  3.071665e-01
# ...                    ...           ...           ...           ...
# 23515         5.687886e+15  5.726722e+15  2.291539e+15  2.919953e+14
# 23516         5.883601e+15  6.007267e+15  2.531487e+15  2.288994e+14
# 23517         6.387632e+15  6.315912e+15  2.783320e+15  9.712010e+13
# 23518         6.402307e+15  6.590700e+15  3.047260e+15  3.881461e+14
# 23519         6.588372e+15  6.907075e+15  3.323471e+15  3.477988e+14
#
#               LSPMW          MCPS  Sieve Bootstrap
# 0      2.706485e-01  4.344227e-01     2.577606e-01
# 1      6.946558e-01  2.844660e-01     3.806374e-01
# 2      2.995940e-01  2.950197e-01     3.621149e-01
# 3      4.829099e-01  2.836154e-01     2.779005e-01
# 4      3.865111e-01  2.711770e-01     4.052575e-01
# ...             ...           ...              ...
# 23515  1.898700e+15  4.043397e+15     7.341418e+08
# 23516  2.177769e+15  4.464665e+15     7.632432e+08
# 23517  2.466296e+15  4.649216e+15     8.215416e+08
# 23518  2.764554e+15  4.960274e+15     8.318316e+08
# 23519  3.072824e+15  5.222780e+15     8.653862e+08
#
# [23520 rows x 19 columns]

# %% [markdown]
# ## Sieve Boostrap

# %%
from runner import main_sieve_test_reducido

main_sieve_test_reducido()
# Out:
# ================================================================================
# TEST REDUCIDO: SIEVE BOOTSTRAP (d=1,2,3)
# ================================================================================
# ================================================================================
# 🚀 PIPELINE SIEVE BOOTSTRAP - CONSISTENTE CON PIPELINE140
# ================================================================================
# 📊 Total de escenarios: 24
#    - Valores de d: [1, 2, 3]
#    - ARMA configs: 2
#    - Distribuciones: 2
#    - Varianzas: 2
#    - Modalidades: 2 (SIN_DIFF, CON_DIFF)
#    - Modelo: SIEVE BOOTSTRAP
#    - Simulador base: ARIMASimulation (consistente con Pipeline140)
#    - Total filas esperadas: 576
# 📦 Procesando lote 1/3...
#    ✅ 192 filas guardadas
# 📦 Procesando lote 2/3...
#    ✅ 384 filas guardadas
# 📦 Procesando lote 3/3...
#    ✅ 576 filas guardadas
# ✅ Simulación completa: resultados_TEST_SIEVE.xlsx
#
# ================================================================================
# ANÁLISIS DE RESULTADOS DEL TEST
# ================================================================================
#
# ================================================================================
# ANÁLISIS SIEVE BOOTSTRAP - DOBLE MODALIDAD
# ================================================================================
#
# ================================================================================
# 🔬 0. TEST ESTADÍSTICO DIEBOLD-MARIANO MODIFICADO
# ================================================================================
#
# ====================================================================================================
# TEST DIEBOLD-MARIANO MODIFICADO (HLN): SIN_DIFF vs CON_DIFF
# ====================================================================================================
#
# H0: No hay diferencia significativa entre modalidades
# H1: Hay diferencia significativa entre modalidades
#
# Significancia: *** p<0.01, ** p<0.05, * p<0.10, No = no significativo
#
#
#  d  N_obs  ECRPS_SIN_DIFF  ECRPS_CON_DIFF  Diferencia  DM_stat  HLN-DM_stat  p_valor Significativo    Mejor
#  1     96        0.544772        0.534090    0.010682   2.0164       2.0059   0.0477            ** CON_DIFF
#  2     96       16.764088       16.639752    0.124335   6.4899       6.4560   0.0000           *** CON_DIFF
#  3     96       13.524168       13.519304    0.004863   0.1595       0.1587   0.8743            No CON_DIFF
#
# ====================================================================================================
# RESUMEN DEL TEST ESTADÍSTICO
# ====================================================================================================
#
# ✓ Total de comparaciones: 3
# ✓ Diferencias significativas: 2 (66.7%)
# ✓ No significativas: 1 (33.3%)
#
# ✓ SIN_DIFF mejor: 0 casos (0.0%)
# ✓ CON_DIFF mejor: 3 casos (100.0%)
#
# ✓ ECRPS promedio global:
#   • SIN_DIFF: 10.277676
#   • CON_DIFF: 10.231049
#   • Diferencia: +0.046627
#   • CON_DIFF es 0.45% mejor globalmente
#
# ✅ Resultados del test guardados en: resultados_DM_test_sieve.xlsx
#
# ================================================================================
# 🔍 1. COMPARACIÓN GLOBAL POR MODALIDAD
# ================================================================================
#
# CON_DIFF:
#   CRPS Promedio: 10.231049
#   Observaciones válidas: 288/288
#
# SIN_DIFF:
#   CRPS Promedio: 10.277676
#   Observaciones válidas: 288/288
#
# ================================================================================
# 📊 2. DESEMPEÑO POR VALOR DE d
# ================================================================================
#
# d      SIN_DIFF        CON_DIFF        Mejor
# -------------------------------------------------------
# 1      0.544772      0.534090      CON_DIFF
# 2      16.764088      16.639752      CON_DIFF
# 3      13.524168      13.519304      CON_DIFF
#
# ================================================================================
# 📈 3. TENDENCIAS POR DISTRIBUCIÓN (Promedio por d)
# ================================================================================
#
# --- normal ---
# d      SIN_DIFF     CON_DIFF
# -----------------------------------
# 1      0.555147     0.544462
# 2      15.955363    15.839869
# 3      9.048742     8.909066
#
# --- uniform ---
# d      SIN_DIFF     CON_DIFF
# -----------------------------------
# 1      0.534396     0.523717
# 2      17.572812    17.439636
# 3      17.999594    18.129543
#
# ================================================================================
# 🎲 4. MEJOR VALOR DE d POR MODALIDAD
# ================================================================================
#
# CON_DIFF:
#   Mejor d: 1
#   CRPS en d=1: 0.534090
#
# SIN_DIFF:
#   Mejor d: 1
#   CRPS en d=1: 0.544772
#
# ================================================================================
# ⚖️  5. COMPARACIÓN DIRECTA GLOBAL
# ================================================================================
#
# SIN_DIFF: 10.277676
# CON_DIFF: 10.231049
#
# Diferencia: -0.046627 (0.45%)
# GANADOR: CON_DIFF
#
# ================================================================================
# 🔄 6. RESUMEN POR PROCESO ARMA BASE
# ================================================================================
#
# ARMA Base       SIN_DIFF     CON_DIFF     Mejor
# -------------------------------------------------------
# AR(1)           15.937854   15.881038   CON_DIFF
# RW              4.617498   4.581059   CON_DIFF
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✓ MEJOR MODALIDAD GLOBAL:
#   • SIN_DIFF: CRPS = 10.277676
#   • CON_DIFF: CRPS = 10.231049
#   → GANADOR: CON_DIFF (mejora de 0.46%)
#
# ✓ MEJOR VALOR DE d GLOBAL:
#   → d = 1: CRPS = 0.539431
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 21.1s
#      Paso        Proceso  p  d  q ARMA_base Distribución  Varianza Modalidad  \
# 0       1  ARMA_I(0,1,0)  0  1  0        RW       normal       0.5  SIN_DIFF
# 1       2  ARMA_I(0,1,0)  0  1  0        RW       normal       0.5  SIN_DIFF
# 2       3  ARMA_I(0,1,0)  0  1  0        RW       normal       0.5  SIN_DIFF
# 3       4  ARMA_I(0,1,0)  0  1  0        RW       normal       0.5  SIN_DIFF
# 4       5  ARMA_I(0,1,0)  0  1  0        RW       normal       0.5  SIN_DIFF
# ..    ...            ... .. .. ..       ...          ...       ...       ...
# 571     8  ARMA_I(1,3,0)  1  3  0     AR(1)      uniform       1.0  CON_DIFF
# 572     9  ARMA_I(1,3,0)  1  3  0     AR(1)      uniform       1.0  CON_DIFF
# 573    10  ARMA_I(1,3,0)  1  3  0     AR(1)      uniform       1.0  CON_DIFF
# 574    11  ARMA_I(1,3,0)  1  3  0     AR(1)      uniform       1.0  CON_DIFF
# 575    12  ARMA_I(1,3,0)  1  3  0     AR(1)      uniform       1.0  CON_DIFF
#
#      Valor_Observado  Sieve Bootstrap
# 0          -7.492730         0.407555
# 1          -8.577334         0.601841
# 2          -7.966516         0.572554
# 3          -8.198818         0.439399
# 4          -8.242181         0.640768
# ..               ...              ...
# 571    -16557.629872         3.632021
# 572    -17085.116759         4.269343
# 573    -17617.878631         5.274436
# 574    -18155.845242         6.235772
# 575    -18700.618895         5.195864
#
# [576 rows x 11 columns]

# %%
from runner import main_sieve_full

main_sieve_full()
# Out:
# ================================================================================
# SIMULACIÓN SIEVE BOOTSTRAP - CONFIGURACIÓN COMPLETA
# Ejecutando análisis exhaustivo con test estadístico Diebold-Mariano
# ================================================================================
# ================================================================================
# 🚀 PIPELINE SIEVE BOOTSTRAP - CONSISTENTE CON PIPELINE140
# ================================================================================
# 📊 Total de escenarios: 980
#    - Valores de d: [1, 2, 3, 4, 5, 7, 10]
#    - ARMA configs: 7
#    - Distribuciones: 5
#    - Varianzas: 4
#    - Modalidades: 2 (SIN_DIFF, CON_DIFF)
#    - Modelo: SIEVE BOOTSTRAP
#    - Simulador base: ARIMASimulation (consistente con Pipeline140)
#    - Total filas esperadas: 23520
# 📦 Procesando lote 1/33...
#    ✅ 720 filas guardadas
# 📦 Procesando lote 2/33...
#    ✅ 1440 filas guardadas
# 📦 Procesando lote 3/33...
#    ✅ 2160 filas guardadas
# 📦 Procesando lote 4/33...
#    ✅ 2880 filas guardadas
# 📦 Procesando lote 5/33...
#    ✅ 3600 filas guardadas
# 📦 Procesando lote 6/33...
#    ✅ 4320 filas guardadas
# 📦 Procesando lote 7/33...
#    ✅ 5040 filas guardadas
# 📦 Procesando lote 8/33...
#    ✅ 5760 filas guardadas
# 📦 Procesando lote 9/33...
#    ✅ 6480 filas guardadas
# 📦 Procesando lote 10/33...
#    ✅ 7200 filas guardadas
# 📦 Procesando lote 11/33...
#    ✅ 7920 filas guardadas
# 📦 Procesando lote 12/33...
#    ✅ 8640 filas guardadas
# 📦 Procesando lote 13/33...
#    ✅ 9360 filas guardadas
# 📦 Procesando lote 14/33...
#    ✅ 10080 filas guardadas
# 📦 Procesando lote 15/33...
#    ✅ 10800 filas guardadas
# 📦 Procesando lote 16/33...
#    ✅ 11520 filas guardadas
# 📦 Procesando lote 17/33...
#    ✅ 12240 filas guardadas
# 📦 Procesando lote 18/33...
#    ✅ 12960 filas guardadas
# 📦 Procesando lote 19/33...
#    ✅ 13680 filas guardadas
# 📦 Procesando lote 20/33...
#    ✅ 14400 filas guardadas
# 📦 Procesando lote 21/33...
#    ✅ 15120 filas guardadas
# 📦 Procesando lote 22/33...
#    ✅ 15840 filas guardadas
# 📦 Procesando lote 23/33...
#    ✅ 16560 filas guardadas
# 📦 Procesando lote 24/33...
#    ✅ 17280 filas guardadas
# 📦 Procesando lote 25/33...
#    ✅ 18000 filas guardadas
# 📦 Procesando lote 26/33...
#    ✅ 18720 filas guardadas
# 📦 Procesando lote 27/33...
#    ✅ 19440 filas guardadas
# 📦 Procesando lote 28/33...
#    ✅ 20160 filas guardadas
# 📦 Procesando lote 29/33...
#    ✅ 20880 filas guardadas
# 📦 Procesando lote 30/33...
#    ✅ 21600 filas guardadas
# 📦 Procesando lote 31/33...
#    ✅ 22320 filas guardadas
# 📦 Procesando lote 32/33...
#    ✅ 23040 filas guardadas
# 📦 Procesando lote 33/33...
#    ✅ 23520 filas guardadas
# ✅ Simulación completa: resultados_SIEVE_d1_a_d10_COMPLETO.xlsx
#
# ================================================================================
# ANÁLISIS COMPLETO DE RESULTADOS
# ================================================================================
#
# ================================================================================
# ANÁLISIS SIEVE BOOTSTRAP - DOBLE MODALIDAD
# ================================================================================
#
# ================================================================================
# 🔬 0. TEST ESTADÍSTICO DIEBOLD-MARIANO MODIFICADO
# ================================================================================
#
# ====================================================================================================
# TEST DIEBOLD-MARIANO MODIFICADO (HLN): SIN_DIFF vs CON_DIFF
# ====================================================================================================
#
# H0: No hay diferencia significativa entre modalidades
# H1: Hay diferencia significativa entre modalidades
#
# Significancia: *** p<0.01, ** p<0.05, * p<0.10, No = no significativo
#
#
#  d  N_obs  ECRPS_SIN_DIFF  ECRPS_CON_DIFF   Diferencia  DM_stat  HLN-DM_stat  p_valor Significativo    Mejor
#  1   1680    5.722630e-01    5.703340e-01 1.928000e-03   1.7064       1.7059   0.0882             * CON_DIFF
#  2   1680    2.885243e+01    2.884009e+01 1.234200e-02   1.9721       1.9716   0.0488            ** CON_DIFF
#  3   1680    2.728425e+01    2.727807e+01 6.187000e-03   0.6566       0.6564   0.5116            No CON_DIFF
#  4   1680    2.706382e+01    2.705934e+01 4.488000e-03   0.2755       0.2754   0.7831            No CON_DIFF
#  5   1680    1.296664e+02    2.820066e+01 1.014657e+02  19.2926      19.2869   0.0000           *** CON_DIFF
#  7   1680    4.058065e+05    1.004961e+04 3.957569e+05  30.5876      30.5784   0.0000           *** CON_DIFF
# 10   1680    1.385449e+10    5.211210e+08 1.333337e+10  28.2196      28.2112   0.0000           *** CON_DIFF
#
# ====================================================================================================
# RESUMEN DEL TEST ESTADÍSTICO
# ====================================================================================================
#
# ✓ Total de comparaciones: 7
# ✓ Diferencias significativas: 5 (71.4%)
# ✓ No significativas: 2 (28.6%)
#
# ✓ SIN_DIFF mejor: 0 casos (0.0%)
# ✓ CON_DIFF mejor: 7 casos (100.0%)
#
# ✓ ECRPS promedio global:
#   • SIN_DIFF: 1979270389.200016
#   • CON_DIFF: 74447311.576861
#   • Diferencia: +1904823077.623155
#   • CON_DIFF es 96.24% mejor globalmente
#
# ✅ Resultados del test guardados en: resultados_DM_test_sieve.xlsx
#
# ================================================================================
# 🔍 1. COMPARACIÓN GLOBAL POR MODALIDAD
# ================================================================================
#
# CON_DIFF:
#   CRPS Promedio: 74447311.576861
#   Observaciones válidas: 11760/11760
#
# SIN_DIFF:
#   CRPS Promedio: 1979270389.200016
#   Observaciones válidas: 11760/11760
#
# ================================================================================
# 📊 2. DESEMPEÑO POR VALOR DE d
# ================================================================================
#
# d      SIN_DIFF        CON_DIFF        Mejor
# -------------------------------------------------------
# 1      0.572263      0.570334      CON_DIFF
# 2      28.852435      28.840093      CON_DIFF
# 3      27.284253      27.278066      CON_DIFF
# 4      27.063823      27.059335      CON_DIFF
# 5      129.666405      28.200658      CON_DIFF
# 7      405806.540753      10049.608713      CON_DIFF
# 10     13854486704.420177      521121019.480825      CON_DIFF
#
# ================================================================================
# 📈 3. TENDENCIAS POR DISTRIBUCIÓN (Promedio por d)
# ================================================================================
#
# --- exponential ---
# d      SIN_DIFF     CON_DIFF
# -----------------------------------
# 1      0.525031     0.520296
# 2      43.605961    43.590975
# 3      27.002632    26.868527
# 4      29.680416    29.764669
# 5      97.890812    23.594603
# 7      345276.276550 6922.235908
# 10     12209745097.895023 448698951.402648
#
# --- mixture ---
# d      SIN_DIFF     CON_DIFF
# -----------------------------------
# 1      0.577389     0.578710
# 2      6.571525     6.507416
# 3      5.177115     5.111421
# 4      5.219784     5.215955
# 5      122.822736   4.016510
# 7      383815.803304 9405.846301
# 10     14085898226.183716 532595203.725901
#
# --- normal ---
# d      SIN_DIFF     CON_DIFF
# -----------------------------------
# 1      0.577344     0.580553
# 2      27.871483    27.826990
# 3      43.796717    43.918319
# 4      36.015878    35.687401
# 5      94.104914    38.004900
# 7      478182.845505 12388.330950
# 10     17482000498.466606 658404664.367762
#
# --- t-student ---
# d      SIN_DIFF     CON_DIFF
# -----------------------------------
# 1      0.569441     0.570025
# 2      36.466950    36.437892
# 3      33.450474    33.467084
# 4      27.323025    27.397769
# 5      178.346206   44.871899
# 7      398514.699597 10476.373976
# 10     11743158069.059788 442806082.651553
#
# --- uniform ---
# d      SIN_DIFF     CON_DIFF
# -----------------------------------
# 1      0.612107     0.602087
# 2      29.746255    29.837191
# 3      26.994330    27.024980
# 4      37.080013    37.230880
# 5      155.167358   30.515377
# 7      423243.078808 11055.256429
# 10     13751631630.495768 523100195.256262
#
# ================================================================================
# 🎲 4. MEJOR VALOR DE d POR MODALIDAD
# ================================================================================
#
# CON_DIFF:
#   Mejor d: 1
#   CRPS en d=1: 0.570334
#
# SIN_DIFF:
#   Mejor d: 1
#   CRPS en d=1: 0.572263
#
# ================================================================================
# ⚖️  5. COMPARACIÓN DIRECTA GLOBAL
# ================================================================================
#
# SIN_DIFF: 1979270389.200016
# CON_DIFF: 74447311.576861
#
# Diferencia: -1904823077.623155 (96.24%)
# GANADOR: CON_DIFF
#
# ================================================================================
# 🔄 6. RESUMEN POR PROCESO ARMA BASE
# ================================================================================
#
# ARMA Base       SIN_DIFF     CON_DIFF     Mejor
# -------------------------------------------------------
# AR(1)           2342375552.980221   88525557.356802   CON_DIFF
# AR(2)           1020925679.631705   34880236.987760   CON_DIFF
# ARMA(1,1)       2024658159.568826   76419458.872994   CON_DIFF
# ARMA(2,2)       5192754008.605972   207066185.234295   CON_DIFF
# MA(1)           980324803.157099   34331601.898398   CON_DIFF
# MA(2)           1387345652.195069   49711384.466808   CON_DIFF
# RW              906508868.261220   30196756.220967   CON_DIFF
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✓ MEJOR MODALIDAD GLOBAL:
#   • SIN_DIFF: CRPS = 1979270389.200016
#   • CON_DIFF: CRPS = 74447311.576861
#   → GANADOR: CON_DIFF (mejora de 2558.62%)
#
# ✓ MEJOR VALOR DE d GLOBAL:
#   → d = 1: CRPS = 0.571298
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 305.0s (5.08 minutos)
#        Paso         Proceso  p   d  q  ARMA_base Distribución  Varianza  \
# 0         1   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# 1         2   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# 2         3   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# 3         4   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# 4         5   ARMA_I(0,1,0)  0   1  0         RW       normal       0.2
# ...     ...             ... ..  .. ..        ...          ...       ...
# 23515     8  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 23516     9  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 23517    10  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 23518    11  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 23519    12  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
#
#       Modalidad  Valor_Observado  Sieve Bootstrap
# 0      SIN_DIFF    -4.738819e+00     2.563525e-01
# 1      SIN_DIFF    -5.424782e+00     3.711926e-01
# 2      SIN_DIFF    -5.038467e+00     3.042493e-01
# 3      SIN_DIFF    -5.185388e+00     2.798301e-01
# 4      SIN_DIFF    -5.212813e+00     2.987419e-01
# ...         ...              ...              ...
# 23515  CON_DIFF     1.698657e+17     2.256995e+09
# 23516  CON_DIFF     1.773095e+17     2.596738e+09
# 23517  CON_DIFF     1.850418e+17     2.990218e+09
# 23518  CON_DIFF     1.930724e+17     3.387065e+09
# 23519  CON_DIFF     2.014112e+17     3.840131e+09
#
# [23520 rows x 11 columns]
