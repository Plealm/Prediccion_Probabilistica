# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_test_reducido_doble

main_test_reducido_doble()
# Out:
# ================================================================================
# TEST REDUCIDO: DOBLE MODALIDAD (d=1,2)
# ================================================================================
# ================================================================================
# EVALUACIÓN ARMA MULTI-D - DOBLE MODALIDAD (SIN DATA LEAKAGE)
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
# 📊 ESCENARIOS BASE: 4
# 📊 FILAS TOTALES ESPERADAS: ~104
# ================================================================================
#
#
# 🚀 Lote 1/1 (Escenarios 1-4)...
# ================================================================================
# ✅ COMPLETADO - 104 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - DOBLE MODALIDAD (SIN_DIFF vs CON_DIFF)
# ================================================================================
#
# ================================================================================
# 🔍 1. COMPARACIÓN GLOBAL POR MODALIDAD
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.662870
# 2      AV-MCPS                   0.777768
# 3      MCPS                      0.816982
# 4      LSPM                      0.901464
# 5      DeepAR                    0.937070
# 6      LSPMW                     1.911255
# 7      AREPD                     2.191106
# 8      Block Bootstrapping       2.627033
# 9      EnCQR-LSTM                2.629696
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.636343
# 2      LSPM                      7.745675
# 3      LSPMW                     52.488358
# 4      EnCQR-LSTM                92.789370
# 5      AV-MCPS                   108.404940
# 6      MCPS                      177.952244
# 7      DeepAR                    410.561545
# 8      AREPD                     457.268814
# 9      Block Bootstrapping       476.491372
#
# ================================================================================
# 📊 2. RANKING POR CADA VALOR DE d (AMBAS MODALIDADES)
# ================================================================================
#
# ======================================================================
# d = 1
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.612053
#   2      DeepAR                    0.623542
#   3      LSPM                      0.653807
#   4      MCPS                      0.706639
#   5      AV-MCPS                   0.746332
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.583514
#   2      DeepAR                    0.618873
#   3      AV-MCPS                   0.806187
#   4      MCPS                      0.920710
#   5      LSPM                      1.337562
#
# ======================================================================
# d = 2
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.713687
#   2      AV-MCPS                   0.809204
#   3      MCPS                      0.927324
#   4      LSPM                      1.149120
#   5      DeepAR                    1.250598
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.689171
#   2      LSPM                      14.153787
#   3      LSPMW                     100.241583
#   4      EnCQR-LSTM                181.792313
#   5      AV-MCPS                   216.003694
#
# ================================================================================
# 🎯 3. VICTORIAS POR MODALIDAD (Mejor modelo por paso)
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
#   Sieve Bootstrap          :   18 victorias (37.5%)
#   MCPS                     :   10 victorias (20.8%)
#   AV-MCPS                  :    8 victorias (16.7%)
#   DeepAR                   :    6 victorias (12.5%)
#   LSPM                     :    2 victorias (4.2%)
#   LSPMW                    :    2 victorias (4.2%)
#   AREPD                    :    1 victorias (2.1%)
#   Block Bootstrapping      :    1 victorias (2.1%)
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
#   Sieve Bootstrap          :   34 victorias (70.8%)
#   DeepAR                   :    5 victorias (10.4%)
#   MCPS                     :    3 victorias (6.2%)
#   AV-MCPS                  :    2 victorias (4.2%)
#   LSPM                     :    2 victorias (4.2%)
#   LSPMW                    :    2 victorias (4.2%)
#
# ================================================================================
# 📈 4. TENDENCIAS: Desempeño según d aumenta
# ================================================================================
#
# ======================================================================
# MODALIDAD: CON_DIFF
# ======================================================================
#
# Modelo                    d=1    d=2
# ---------------------------------------
# AREPD                     0.8369  3.5453
# AV-MCPS                   0.7463  0.8092
# Block Bootstrapping       0.7558  4.4982
# DeepAR                    0.6235  1.2506
# EnCQR-LSTM                0.9559  4.3035
# LSPM                      0.6538  1.1491
# LSPMW                     0.9928  2.8297
# MCPS                      0.7066  0.9273
# Sieve Bootstrap           0.6121  0.7137
#
# ======================================================================
# MODALIDAD: SIN_DIFF
# ======================================================================
#
# Modelo                    d=1    d=2
# ---------------------------------------
# AREPD                     6.6850  907.8526
# AV-MCPS                   0.8062  216.0037
# Block Bootstrapping       6.2853  946.6974
# DeepAR                    0.6189  820.5042
# EnCQR-LSTM                3.7864  181.7923
# LSPM                      1.3376  14.1538
# LSPMW                     4.7351  100.2416
# MCPS                      0.9207  354.9838
# Sieve Bootstrap           0.5835  0.6892
#
# ================================================================================
# ⚖️  5. COMPARACIÓN DIRECTA: SIN_DIFF vs CON_DIFF
# ================================================================================
#
# Modelo                    SIN_DIFF     CON_DIFF     Diferencia   Mejor
# ---------------------------------------------------------------------------
# AREPD                     457.268814   2.191106   -455.077708   CON_DIFF
# AV-MCPS                   108.404940   0.777768   -107.627173   CON_DIFF
# Block Bootstrapping       476.491372   2.627033   -473.864339   CON_DIFF
# DeepAR                    410.561545   0.937070   -409.624475   CON_DIFF
# EnCQR-LSTM                92.789370   2.629696   -90.159674   CON_DIFF
# LSPM                      7.745675   0.901464   -6.844211   CON_DIFF
# LSPMW                     52.488358   1.911255   -50.577102   CON_DIFF
# MCPS                      177.952244   0.816982   -177.135263   CON_DIFF
# Sieve Bootstrap           0.636343   0.662870   +0.026528   SIN_DIFF
#
# ================================================================================
# 🎲 6. MEJOR VALOR DE d PARA CADA MODELO Y MODALIDAD
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
#
# Modelo                    Mejor d    CRPS en ese d
# ------------------------------------------------------------
# AREPD                     1          0.836916
# AV-MCPS                   1          0.746332
# Block Bootstrapping       1          0.755825
# DeepAR                    1          0.623542
# EnCQR-LSTM                1          0.955930
# LSPM                      1          0.653807
# LSPMW                     1          0.992801
# MCPS                      1          0.706639
# Sieve Bootstrap           1          0.612053
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
#
# Modelo                    Mejor d    CRPS en ese d
# ------------------------------------------------------------
# AREPD                     1          6.685028
# AV-MCPS                   1          0.806187
# Block Bootstrapping       1          6.285328
# DeepAR                    1          0.618873
# EnCQR-LSTM                1          3.786427
# LSPM                      1          1.337562
# LSPMW                     1          4.735132
# MCPS                      1          0.920710
# Sieve Bootstrap           1          0.583514
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✓ MEJOR MODALIDAD GLOBAL:
#   • SIN_DIFF: CRPS promedio = 198.259851
#   • CON_DIFF: CRPS promedio = 1.495027
#   → GANADOR: CON_DIFF (diferencia: 196.764824)
#
# ✓ MEJOR MODELO GLOBAL:
#   → Sieve Bootstrap: CRPS = 0.649606
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 211.0s
#          Paso        Proceso  p  d  q ARMA_base Distribución  Varianza  \
# 0           1  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0
# 1           2  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0
# 2           3  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0
# 3           4  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0
# 4           5  ARMA_I(0,1,0)  0  1  0        RW       normal       1.0
# ..        ...            ... .. .. ..       ...          ...       ...
# 99          9  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0
# 100        10  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0
# 101        11  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0
# 102        12  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0
# 103  Promedio  ARMA_I(1,2,0)  1  2  0     AR(1)       normal       1.0
#
#     Modalidad  Valor_Observado  Block Bootstrapping  Sieve Bootstrap  \
# 0    SIN_DIFF       -17.091393             4.326839         0.228563
# 1    SIN_DIFF       -16.749838             4.058956         0.475402
# 2    SIN_DIFF       -15.021140             2.484305         1.090736
# 3    SIN_DIFF       -16.007997             3.278375         0.889440
# 4    SIN_DIFF       -16.253275             3.542339         0.237905
# ..        ...              ...                  ...              ...
# 99   CON_DIFF      2159.339960             5.387708         0.275637
# 100  CON_DIFF      2178.609720             5.214594         1.182006
# 101  CON_DIFF      2196.985073             5.069716         1.432306
# 102  CON_DIFF      2214.031757             5.291846         0.548939
# 103  CON_DIFF              NaN             5.957615         0.745821
#
#          LSPM     LSPMW    DeepAR     AREPD      MCPS   AV-MCPS  EnCQR-LSTM
# 0    1.714081  1.392278  0.479680  4.064471  0.653288  0.630828    1.805407
# 1    0.285013  1.071480  0.225920  3.722474  0.695783  0.586144    1.806785
# 2    1.843047  0.352459  0.969507  2.201196  1.121097  0.843736    1.907184
# 3    0.383622  0.556275  0.442704  3.024786  0.901414  0.577601    1.834675
# 4    1.044559  0.699397  0.320775  3.220772  0.779398  0.600067    1.838234
# ..        ...       ...       ...       ...       ...       ...         ...
# 99   1.016477  7.747963  0.935973  3.833493  1.677554  1.106990    5.565542
# 100  1.843584  5.660684  0.677835  4.057621  0.739364  0.652997    5.802655
# 101  0.495679  6.555091  0.708090  3.861326  0.974191  0.564043    5.736248
# 102  2.745338  7.883760  1.655310  3.738613  1.715854  1.102294    5.624573
# 103  1.579696  5.199234  1.841589  4.590533  1.346198  1.153054    5.787332
#
# [104 rows x 19 columns]

# %%
from runner import main_full_2800

main_full_2800()
# Out:
# ================================================================================
# INICIANDO SIMULACIÓN COMPLETA: 2,800 FILAS
# ================================================================================
# ================================================================================
# EVALUACIÓN ARMA MULTI-D - DOBLE MODALIDAD (SIN DATA LEAKAGE)
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 20
# 📊 ESCENARIOS BASE: 840
# 📊 FILAS TOTALES ESPERADAS: ~21840
# ================================================================================
#
#
# 🚀 Lote 1/42 (Escenarios 1-20)...
# 🚀 Lote 2/42 (Escenarios 21-40)...
# 🚀 Lote 3/42 (Escenarios 41-60)...
# 🚀 Lote 4/42 (Escenarios 61-80)...
# 🚀 Lote 5/42 (Escenarios 81-100)...
# 🚀 Lote 6/42 (Escenarios 101-120)...
# 🚀 Lote 7/42 (Escenarios 121-140)...
# 🚀 Lote 8/42 (Escenarios 141-160)...
# 🚀 Lote 9/42 (Escenarios 161-180)...
# 🚀 Lote 10/42 (Escenarios 181-200)...
# 🚀 Lote 11/42 (Escenarios 201-220)...
# 🚀 Lote 12/42 (Escenarios 221-240)...
# 🚀 Lote 13/42 (Escenarios 241-260)...
# 🚀 Lote 14/42 (Escenarios 261-280)...
# 🚀 Lote 15/42 (Escenarios 281-300)...
# 🚀 Lote 16/42 (Escenarios 301-320)...
# 🚀 Lote 17/42 (Escenarios 321-340)...
# 🚀 Lote 18/42 (Escenarios 341-360)...
# 🚀 Lote 19/42 (Escenarios 361-380)...
# 🚀 Lote 20/42 (Escenarios 381-400)...
# 🚀 Lote 21/42 (Escenarios 401-420)...
# 🚀 Lote 22/42 (Escenarios 421-440)...
# 🚀 Lote 23/42 (Escenarios 441-460)...
# 🚀 Lote 24/42 (Escenarios 461-480)...
# 🚀 Lote 25/42 (Escenarios 481-500)...
# 🚀 Lote 26/42 (Escenarios 501-520)...
# 🚀 Lote 27/42 (Escenarios 521-540)...
# 🚀 Lote 28/42 (Escenarios 541-560)...
# 🚀 Lote 29/42 (Escenarios 561-580)...
# 🚀 Lote 30/42 (Escenarios 581-600)...
# 🚀 Lote 31/42 (Escenarios 601-620)...
# 🚀 Lote 32/42 (Escenarios 621-640)...
# 🚀 Lote 33/42 (Escenarios 641-660)...
# 🚀 Lote 34/42 (Escenarios 661-680)...
# 🚀 Lote 35/42 (Escenarios 681-700)...
# 🚀 Lote 36/42 (Escenarios 701-720)...
# 🚀 Lote 37/42 (Escenarios 721-740)...
# 🚀 Lote 38/42 (Escenarios 741-760)...
# 🚀 Lote 39/42 (Escenarios 761-780)...
# 🚀 Lote 40/42 (Escenarios 781-800)...
# 🚀 Lote 41/42 (Escenarios 801-820)...
# 🚀 Lote 42/42 (Escenarios 821-840)...
# ================================================================================
# ✅ COMPLETADO - 21840 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - DOBLE MODALIDAD (SIN_DIFF vs CON_DIFF)
# ================================================================================
#
# ================================================================================
# 🔍 1. COMPARACIÓN GLOBAL POR MODALIDAD
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           3957394.071039
# 2      LSPM                      3539648448910.103027
# 3      LSPMW                     21579039908704.242188
# 4      EnCQR-LSTM                26915807267348.277344
# 5      AV-MCPS                   30624979967316.515625
# 6      MCPS                      50507983180760.171875
# 7      DeepAR                    70872202513675.687500
# 8      AREPD                     71196537588869.390625
# 9      Block Bootstrapping       72247966646188.671875
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           90125701.684324
# 2      LSPM                      88723785898858.171875
# 3      LSPMW                     534641751902881.000000
# 4      EnCQR-LSTM                684437978917305.500000
# 5      AV-MCPS                   750188286285894.375000
# 6      MCPS                      1207255654191056.500000
# 7      AREPD                     1636491389562096.250000
# 8      DeepAR                    1638872541504514.500000
# 9      Block Bootstrapping       1657705366960646.500000
#
# ================================================================================
# 📊 2. RANKING POR CADA VALOR DE d (AMBAS MODALIDADES)
# ================================================================================
#
# ======================================================================
# d = 2
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.560534
#   2      LSPM                      1.073373
#   3      MCPS                      2.988876
#   4      AV-MCPS                   3.095171
#   5      LSPMW                     3.221895
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.566971
#   2      LSPM                      25.891477
#   3      LSPMW                     171.150173
#   4      EnCQR-LSTM                346.086703
#   5      AV-MCPS                   432.474902
#
# ======================================================================
# d = 3
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.565140
#   2      LSPM                      24.888578
#   3      LSPMW                     163.338907
#   4      EnCQR-LSTM                351.545479
#   5      AV-MCPS                   410.754605
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.595004
#   2      LSPM                      3231.522475
#   3      LSPMW                     20796.859525
#   4      EnCQR-LSTM                32932.745799
#   5      AV-MCPS                   35633.947684
#
# ======================================================================
# d = 4
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.590235
#   2      LSPM                      3151.609216
#   3      LSPMW                     20273.198807
#   4      EnCQR-LSTM                32221.867859
#   5      AV-MCPS                   33696.601586
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.693984
#   2      LSPM                      253914.127060
#   3      LSPMW                     1618136.549810
#   4      EnCQR-LSTM                2237609.605009
#   5      AV-MCPS                   2532731.875712
#
# ======================================================================
# d = 5
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           0.676568
#   2      LSPM                      248879.563930
#   3      LSPMW                     1585592.241718
#   4      EnCQR-LSTM                2197223.980202
#   5      AV-MCPS                   2411981.985261
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           2.630095
#   2      LSPM                      14362803.203614
#   3      LSPMW                     91851082.959934
#   4      EnCQR-LSTM                117374517.142665
#   5      AV-MCPS                   136749283.329356
#
# ======================================================================
# d = 7
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           245.595065
#   2      LSPM                      708324774.535336
#   3      LSPMW                     4486409476.572278
#   4      EnCQR-LSTM                5593052108.126057
#   5      AV-MCPS                   6567641331.000213
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           16615.916827
#   2      LSPM                      26696155622.908821
#   3      LSPMW                     166987121986.359680
#   4      EnCQR-LSTM                206094804466.617126
#   5      AV-MCPS                   242050159196.684479
#
# ======================================================================
# d = 10
# ======================================================================
#
#   --- CON_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           23744116.438693
#   2      LSPM                      21237182116628.949219
#   3      LSPMW                     129469751436716.890625
#   4      EnCQR-LSTM                161489248322178.437500
#   5      AV-MCPS                   183743309716475.656250
#
#   --- SIN_DIFF ---
#   Rank   Modelo                    CRPS
#   --------------------------------------------------
#   1      Sieve Bootstrap           540737589.703063
#   2      LSPM                      532316004617551.312500
#   3      LSPMW                     3207683430805112.500000
#   4      EnCQR-LSTM                4106421659053960.500000
#   5      AV-MCPS                   4500887528238088.500000
#
# ================================================================================
# 🎯 3. VICTORIAS POR MODALIDAD (Mejor modelo por paso)
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
#   Sieve Bootstrap          : 9201 victorias (91.3%)
#   LSPM                     :  350 victorias (3.5%)
#   DeepAR                   :  145 victorias (1.4%)
#   LSPMW                    :  139 victorias (1.4%)
#   AV-MCPS                  :  134 victorias (1.3%)
#   MCPS                     :  100 victorias (1.0%)
#   AREPD                    :    7 victorias (0.1%)
#   Block Bootstrapping      :    3 victorias (0.0%)
#   EnCQR-LSTM               :    1 victorias (0.0%)
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
#   Sieve Bootstrap          : 10031 victorias (99.5%)
#   LSPM                     :   40 victorias (0.4%)
#   LSPMW                    :    9 victorias (0.1%)
#
# ================================================================================
# 📈 4. TENDENCIAS: Desempeño según d aumenta
# ================================================================================
#
# ======================================================================
# MODALIDAD: CON_DIFF
# ======================================================================
#
# Modelo                    d=2    d=3    d=4    d=5    d=7    d=10
# -------------------------------------------------------------------
# AREPD                     9.0756  1338.1764  137542.3717  9016282.2923  19545106679.9857  427159671271364.3125
# AV-MCPS                   3.0952  410.7546  33696.6016  2411981.9853  6567641331.0002  183743309716475.6562
# Block Bootstrapping       10.2046  1451.0765  145061.5846  9377029.4078  20002242635.0685  433467788110944.7500
# DeepAR                    3.7880  977.5142  118895.1730  8199453.4218  18895652642.2688  425214311110082.0000
# EnCQR-LSTM                5.7123  351.5455  32221.8679  2197223.9802  5593052108.1261  161489248322178.4375
# LSPM                      1.0734  24.8886  3151.6092  248879.5639  708324774.5353  21237182116628.9492
# LSPMW                     3.2219  163.3389  20273.1988  1585592.2417  4486409476.5723  129469751436716.8906
# MCPS                      2.9889  503.1237  61911.5622  4566112.9396  11861131600.1337  303036033324430.3125
# Sieve Bootstrap           0.5605  0.5651  0.5902  0.6766  245.5951  23744116.4387
#
# ======================================================================
# MODALIDAD: SIN_DIFF
# ======================================================================
#
# Modelo                    d=2    d=3    d=4    d=5    d=7    d=10
# -------------------------------------------------------------------
# AREPD                     1399.6023  140324.1127  9126401.1838  457115021.1690  654936603357.6807  9818292934386076.0000
# AV-MCPS                   432.4749  35633.9477  2532731.8757  136749283.3294  242050159196.6845  4500887528238088.5000
# Block Bootstrapping       1511.2574  147924.0603  9483846.0095  470787024.8739  667905123447.3088  9945563816220124.0000
# DeepAR                    1083.1944  121166.9492  8278910.3982  424487321.4843  638367302689.8635  9832596448835916.0000
# EnCQR-LSTM                346.0867  32932.7458  2237609.6050  117374517.1427  206094804466.6171  4106421659053960.5000
# LSPM                      25.8915  3231.5225  253914.1271  14362803.2036  26696155622.9088  532316004617551.3125
# LSPMW                     171.1502  20796.8595  1618136.5498  91851082.9599  166987121986.3597  3207683430805112.5000
# MCPS                      531.0157  62540.0613  4643676.8955  255441819.3437  423117555210.8474  7243110547442561.0000
# Sieve Bootstrap           0.5670  0.5950  0.6940  2.6301  16615.9168  540737589.7031
#
# ================================================================================
# ⚖️  5. COMPARACIÓN DIRECTA: SIN_DIFF vs CON_DIFF
# ================================================================================
#
# Modelo                    SIN_DIFF     CON_DIFF     Diferencia   Mejor
# ---------------------------------------------------------------------------
# AREPD                     1636491389562096.250000   71196537588869.390625   -1565294851973226.750000   CON_DIFF
# AV-MCPS                   750188286285894.375000   30624979967316.515625   -719563306318577.875000   CON_DIFF
# Block Bootstrapping       1657705366960646.500000   72247966646188.671875   -1585457400314457.750000   CON_DIFF
# DeepAR                    1638872541504514.500000   70872202513675.687500   -1568000338990838.750000   CON_DIFF
# EnCQR-LSTM                684437978917305.500000   26915807267348.277344   -657522171649957.250000   CON_DIFF
# LSPM                      88723785898858.171875   3539648448910.103027   -85184137449948.062500   CON_DIFF
# LSPMW                     534641751902881.000000   21579039908704.242188   -513062711994176.750000   CON_DIFF
# MCPS                      1207255654191056.500000   50507983180760.171875   -1156747671010296.250000   CON_DIFF
# Sieve Bootstrap           90125701.684324   3957394.071039   -86168307.613285   CON_DIFF
#
# ================================================================================
# 🎲 6. MEJOR VALOR DE d PARA CADA MODELO Y MODALIDAD
# ================================================================================
#
# ============================================================
# MODALIDAD: CON_DIFF
# ============================================================
#
# Modelo                    Mejor d    CRPS en ese d
# ------------------------------------------------------------
# AREPD                     2          9.075626
# AV-MCPS                   2          3.095171
# Block Bootstrapping       2          10.204580
# DeepAR                    2          3.788029
# EnCQR-LSTM                2          5.712261
# LSPM                      2          1.073373
# LSPMW                     2          3.221895
# MCPS                      2          2.988876
# Sieve Bootstrap           2          0.560534
#
# ============================================================
# MODALIDAD: SIN_DIFF
# ============================================================
#
# Modelo                    Mejor d    CRPS en ese d
# ------------------------------------------------------------
# AREPD                     2          1399.602287
# AV-MCPS                   2          432.474902
# Block Bootstrapping       2          1511.257419
# DeepAR                    2          1083.194417
# EnCQR-LSTM                2          346.086703
# LSPM                      2          25.891477
# LSPMW                     2          171.150173
# MCPS                      2          531.015701
# Sieve Bootstrap           2          0.566971
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✓ MEJOR MODALIDAD GLOBAL:
#   • SIN_DIFF: CRPS promedio = 910924093927661.625000
#   • CON_DIFF: CRPS promedio = 38609352164351.906250
#   → GANADOR: CON_DIFF (diferencia: 872314741763309.750000)
#
# ✓ MEJOR MODELO GLOBAL:
#   → Sieve Bootstrap: CRPS = 47041547.877682
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 23626.0s (6.56 horas)
#            Paso         Proceso  p   d  q  ARMA_base Distribución  Varianza  \
# 0             1   ARMA_I(0,2,0)  0   2  0         RW       normal       0.2
# 1             2   ARMA_I(0,2,0)  0   2  0         RW       normal       0.2
# 2             3   ARMA_I(0,2,0)  0   2  0         RW       normal       0.2
# 3             4   ARMA_I(0,2,0)  0   2  0         RW       normal       0.2
# 4             5   ARMA_I(0,2,0)  0   2  0         RW       normal       0.2
# ...         ...             ... ..  .. ..        ...          ...       ...
# 21835         9  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 21836        10  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 21837        11  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 21838        12  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
# 21839  Promedio  ARMA_I(2,10,2)  2  10  2  ARMA(2,2)      mixture       3.0
#
#       Modalidad  Valor_Observado  Block Bootstrapping  Sieve Bootstrap  \
# 0      SIN_DIFF    -9.226713e+02         3.901707e+02     1.352009e-01
# 1      SIN_DIFF    -9.301621e+02         4.039832e+02     1.027137e-01
# 2      SIN_DIFF    -9.368798e+02         4.013723e+02     6.849108e-01
# 3      SIN_DIFF    -9.440387e+02         4.084865e+02     2.067724e-01
# 4      SIN_DIFF    -9.513074e+02         4.176936e+02     1.054916e-01
# ...         ...              ...                  ...              ...
# 21835  CON_DIFF    -2.463766e+16         9.410215e+14     2.741720e+07
# 21836  CON_DIFF    -2.584005e+16         1.003708e+15     2.873333e+07
# 21837  CON_DIFF    -2.709438e+16         1.037999e+15     3.011847e+07
# 21838  CON_DIFF    -2.840260e+16         1.083030e+15     3.111269e+07
# 21839  CON_DIFF              NaN         8.641745e+14     2.478574e+07
#
#                LSPM         LSPMW        DeepAR         AREPD          MCPS  \
# 0      8.196214e+00  8.100195e+00  2.234439e+02  3.611193e+02  1.113657e+02
# 1      7.213344e+00  1.559095e+01  2.314336e+02  3.647827e+02  1.211357e+02
# 2      6.145310e+00  2.230861e+01  2.342027e+02  3.676493e+02  1.309513e+02
# 3      6.208891e+00  2.946760e+01  2.418538e+02  3.708971e+02  1.353154e+02
# 4      7.570015e+00  3.673629e+01  2.472959e+02  3.742307e+02  1.435989e+02
# ...             ...           ...           ...           ...           ...
# 21835  4.420783e+13  3.719065e+14  9.730695e+14  9.330030e+14  7.325588e+14
# 21836  4.740487e+13  4.219429e+14  1.021595e+15  9.733261e+14  7.583566e+14
# 21837  4.624103e+13  4.738784e+14  1.072554e+15  1.015117e+15  8.142726e+14
# 21838  5.342544e+13  5.277751e+14  1.132340e+15  1.058418e+15  8.872014e+14
# 21839  4.275718e+13  2.648438e+14  8.701971e+14  8.463322e+14  6.139057e+14
#
#             AV-MCPS    EnCQR-LSTM
# 0      6.661377e+01  9.184823e+01
# 1      7.678781e+01  9.157754e+01
# 2      8.559926e+01  9.124975e+01
# 3      9.044136e+01  9.099177e+01
# 4      9.899170e+01  9.076432e+01
# ...             ...           ...
# 21835  4.874452e+14  4.284192e+14
# 21836  5.277924e+14  4.720392e+14
# 21837  5.811224e+14  5.170537e+14
# 21838  6.415789e+14  5.634318e+14
# 21839  3.756465e+14  3.384971e+14
#
# [21840 rows x 19 columns]
