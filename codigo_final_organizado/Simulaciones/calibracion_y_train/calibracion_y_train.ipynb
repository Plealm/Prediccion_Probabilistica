# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_test_tamanos_reducido

main_test_tamanos_reducido()
# Out:
# 🚀 INICIANDO TEST REDUCIDO
# 📊 Total de escenarios: 12
# 📦 Número de batches: 6
# 🔄 Procesando batch 1/6...
# ✅ Guardado progreso: 24 filas
# 🔄 Procesando batch 2/6...
# ✅ Guardado progreso: 48 filas
# 🔄 Procesando batch 3/6...
# ✅ Guardado progreso: 72 filas
# 🔄 Procesando batch 4/6...
# ✅ Guardado progreso: 96 filas
# 🔄 Procesando batch 5/6...
# ✅ Guardado progreso: 120 filas
# 🔄 Procesando batch 6/6...
# ✅ Guardado progreso: 144 filas
#
# 🎉 ¡Completado! Total de filas: 144
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
#
# 📊 1. RANKING GLOBAL POR TIPO DE PROCESO
# ======================================================================
#
# --- ARMA ---
#  1. Sieve Bootstrap      0.593673
#  2. DeepAR               0.667028
#  3. LSPM                 0.826608
#  4. MCPS                 0.892494
#  5. AV-MCPS              1.092713
#
# --- ARIMA ---
#  1. Sieve Bootstrap      0.628891
#  2. LSPM                 0.834873
#  3. LSPMW                1.301629
#  4. MCPS                 1.954469
#  5. AV-MCPS              1.973833
#
# --- SETAR ---
#  1. Block Bootstrapping  0.608492
#  2. DeepAR               0.619954
#  3. Sieve Bootstrap      0.636137
#  4. LSPM                 0.636459
#  5. LSPMW                0.653934
#
# 📊 2. RANKING GLOBAL POR TAMAÑO TOTAL DE DATOS
# ======================================================================
#
# --- N_Total = 120 ---
#  1. Sieve Bootstrap      0.616298
#  2. DeepAR               0.641917
#  3. LSPM                 0.754634
#
# --- N_Total = 140 ---
#  1. Sieve Bootstrap      0.653496
#  2. LSPM                 0.728539
#  3. MCPS                 1.272727
#
# --- N_Total = 220 ---
#  1. Sieve Bootstrap      0.618676
#  2. LSPM                 0.824060
#  3. LSPMW                1.269786
#
# --- N_Total = 240 ---
#  1. Sieve Bootstrap      0.589799
#  2. DeepAR               0.662909
#  3. MCPS                 0.696944
#
# 📈 3. IMPACTO DE N_TRAIN EN EL DESEMPEÑO (por tipo de proceso)
# ======================================================================
#
# --- ARMA ---
# N_Train                   100       200
# AREPD                1.108301  1.677856
# AV-MCPS              1.170860  1.014567
# Block Bootstrapping  1.166755  1.582023
# DeepAR               0.598554  0.735501
# EnCQR-LSTM           1.743920  1.513953
# LSPM                 0.766688  0.886529
# LSPMW                1.766036  1.643056
# MCPS                 0.748883  1.036106
# Sieve Bootstrap      0.594611  0.592735
#
# --- ARIMA ---
# N_Train                   100        200
# AREPD                3.831345   9.811324
# AV-MCPS              2.297213   1.650453
# Block Bootstrapping  3.865482  10.425496
# DeepAR               1.648320   7.881409
# EnCQR-LSTM           4.506282   4.530777
# LSPM                 0.826823   0.842923
# LSPMW                1.562990   1.040267
# MCPS                 1.837314   2.071624
# Sieve Bootstrap      0.671847   0.585935
#
# --- SETAR ---
# N_Train                   100       200
# AREPD                0.631072  0.766385
# AV-MCPS              0.648071  0.735681
# Block Bootstrapping  0.605862  0.611122
# DeepAR               0.637202  0.602707
# EnCQR-LSTM           0.758854  0.695769
# LSPM                 0.631248  0.641670
# LSPMW                0.670744  0.637123
# MCPS                 0.644602  0.740415
# Sieve Bootstrap      0.638233  0.634041
#
# 🎯 4. MEJOR COMBINACIÓN (N_TRAIN, N_CALIB) POR MODELO
# ======================================================================
# Modelo                    N_Train    N_Calib    CRPS         Tipo
# ---------------------------------------------------------------------------
# AREPD                     100        40         0.612068      SETAR
# AV-MCPS                   100        20         0.641316      SETAR
# Block Bootstrapping       100        20         0.598606      SETAR
# DeepAR                    200        40         0.590555      SETAR
# EnCQR-LSTM                200        40         0.595981      SETAR
# LSPM                      200        40         0.614985      SETAR
# LSPMW                     200        40         0.582964      SETAR
# MCPS                      200        40         0.634078      SETAR
# Sieve Bootstrap           100        20         0.570078      ARIMA
#
# 📋 5. RESUMEN EJECUTIVO
# ======================================================================
#
# ✅ MEJOR MODELO GLOBAL:
#    → Sieve Bootstrap: CRPS = 0.619567
#
# ❌ PEOR MODELO GLOBAL:
#    → Block Bootstrapping: CRPS = 3.042790
#
# 🎯 MEJOR MODELO POR TIPO DE PROCESO:
#    ARMA      : Sieve Bootstrap (0.593673)
#    ARIMA     : Sieve Bootstrap (0.628891)
#    SETAR     : Block Bootstrapping (0.608492)
#
# 🎯 MEJOR TAMAÑO TOTAL DE DATOS:
#    → N_Total = 120: CRPS promedio = 1.262339
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#      Paso Tipo_Proceso  Proceso Distribución  Varianza  N_Train  N_Calib  \
# 0       1         ARMA    AR(1)       normal       1.0      100       20
# 1       2         ARMA    AR(1)       normal       1.0      100       20
# 2       3         ARMA    AR(1)       normal       1.0      100       20
# 3       4         ARMA    AR(1)       normal       1.0      100       20
# 4       5         ARMA    AR(1)       normal       1.0      100       20
# ..    ...          ...      ...          ...       ...      ...      ...
# 139     8        SETAR  SETAR-1       normal       1.0      200       40
# 140     9        SETAR  SETAR-1       normal       1.0      200       40
# 141    10        SETAR  SETAR-1       normal       1.0      200       40
# 142    11        SETAR  SETAR-1       normal       1.0      200       40
# 143    12        SETAR  SETAR-1       normal       1.0      200       40
#
#      N_Total        Size  Block Bootstrapping  Sieve Bootstrap      LSPM  \
# 0        120  Tr100_Ca20             0.698466         0.600297  0.644225
# 1        120  Tr100_Ca20             0.673509         0.571112  0.580920
# 2        120  Tr100_Ca20             0.704594         0.590401  0.630223
# 3        120  Tr100_Ca20             0.718477         0.560104  0.561808
# 4        120  Tr100_Ca20             0.717585         0.595233  0.850340
# ..       ...         ...                  ...              ...       ...
# 139      240  Tr200_Ca40             0.596956         0.615483  0.610549
# 140      240  Tr200_Ca40             0.598471         0.619802  0.617840
# 141      240  Tr200_Ca40             0.562532         0.564664  0.559134
# 142      240  Tr200_Ca40             0.631207         0.607383  0.646909
# 143      240  Tr200_Ca40             0.590144         0.553853  0.610327
#
#         LSPMW     AREPD      MCPS   AV-MCPS    DeepAR  EnCQR-LSTM
# 0    0.653822  0.613288  0.638138  1.202028  0.591561    0.769126
# 1    0.731312  0.598902  0.598348  1.355626  0.572691    0.690365
# 2    0.623174  0.635586  0.737884  1.633000  0.584659    0.812547
# 3    0.577059  0.644166  0.711089  1.569325  0.560364    0.848448
# 4    1.016553  0.654972  0.880737  1.508263  0.582860    0.598987
# ..        ...       ...       ...       ...       ...         ...
# 139  0.556138  0.650069  0.692430  0.589238  0.586742    0.567240
# 140  0.572067  0.630190  0.662130  0.621166  0.586766    0.584006
# 141  0.574287  0.567912  0.597643  0.611531  0.562129    0.589782
# 142  0.577953  0.691735  0.608598  0.610235  0.584642    0.587681
# 143  0.641857  0.557723  0.598147  0.768119  0.558044    0.666565
#
# [144 rows x 18 columns]

# %%
from runner import main_comparacion_todos_procesos

main_comparacion_todos_procesos()
# Out:
# ================================================================================
# 🚀 INICIANDO PIPELINE UNIFICADO - TODOS LOS PROCESOS
# ================================================================================
# 📊 Total de escenarios: 3780
# 📦 Número de batches: 189
# 🔄 Procesando batch 1/189...
# ✅ Guardado progreso: 240 filas
# 🔄 Procesando batch 2/189...
# ✅ Guardado progreso: 480 filas
# 🔄 Procesando batch 3/189...
# ✅ Guardado progreso: 720 filas
# 🔄 Procesando batch 4/189...
# ✅ Guardado progreso: 960 filas
# 🔄 Procesando batch 5/189...
# ✅ Guardado progreso: 1200 filas
# 🔄 Procesando batch 6/189...
# ✅ Guardado progreso: 1440 filas
# 🔄 Procesando batch 7/189...
# ✅ Guardado progreso: 1680 filas
# 🔄 Procesando batch 8/189...
# ✅ Guardado progreso: 1920 filas
# 🔄 Procesando batch 9/189...
# ✅ Guardado progreso: 2160 filas
# 🔄 Procesando batch 10/189...
# ✅ Guardado progreso: 2400 filas
# 🔄 Procesando batch 11/189...
# ✅ Guardado progreso: 2640 filas
# 🔄 Procesando batch 12/189...
# ✅ Guardado progreso: 2880 filas
# 🔄 Procesando batch 13/189...
# ✅ Guardado progreso: 3120 filas
# 🔄 Procesando batch 14/189...
# ✅ Guardado progreso: 3360 filas
# 🔄 Procesando batch 15/189...
# ✅ Guardado progreso: 3600 filas
# 🔄 Procesando batch 16/189...
# ✅ Guardado progreso: 3840 filas
# 🔄 Procesando batch 17/189...
# ✅ Guardado progreso: 4080 filas
# 🔄 Procesando batch 18/189...
# ✅ Guardado progreso: 4320 filas
# 🔄 Procesando batch 19/189...
# ✅ Guardado progreso: 4560 filas
# 🔄 Procesando batch 20/189...
# ✅ Guardado progreso: 4800 filas
# 🔄 Procesando batch 21/189...
# ✅ Guardado progreso: 5040 filas
# 🔄 Procesando batch 22/189...
# ✅ Guardado progreso: 5280 filas
# 🔄 Procesando batch 23/189...
# ✅ Guardado progreso: 5520 filas
# 🔄 Procesando batch 24/189...
# ✅ Guardado progreso: 5760 filas
# 🔄 Procesando batch 25/189...
# ✅ Guardado progreso: 6000 filas
# 🔄 Procesando batch 26/189...
# ✅ Guardado progreso: 6240 filas
# 🔄 Procesando batch 27/189...
# ✅ Guardado progreso: 6480 filas
# 🔄 Procesando batch 28/189...
# ✅ Guardado progreso: 6720 filas
# 🔄 Procesando batch 29/189...
# ✅ Guardado progreso: 6960 filas
# 🔄 Procesando batch 30/189...
# ✅ Guardado progreso: 7200 filas
# 🔄 Procesando batch 31/189...
# ✅ Guardado progreso: 7440 filas
# 🔄 Procesando batch 32/189...
# ✅ Guardado progreso: 7680 filas
# 🔄 Procesando batch 33/189...
# ✅ Guardado progreso: 7920 filas
# 🔄 Procesando batch 34/189...
# ✅ Guardado progreso: 8160 filas
# 🔄 Procesando batch 35/189...
# ✅ Guardado progreso: 8400 filas
# 🔄 Procesando batch 36/189...
# ✅ Guardado progreso: 8640 filas
# 🔄 Procesando batch 37/189...
# ✅ Guardado progreso: 8880 filas
# 🔄 Procesando batch 38/189...
# ✅ Guardado progreso: 9120 filas
# 🔄 Procesando batch 39/189...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from runner import main_comparacion_todos_procesos
# ----> 3 main_comparacion_todos_procesos()
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base\runner.py:955, in main_comparacion_todos_procesos(train_sizes, calib_sizes)
#     952 if calib_sizes:
#     953     pipeline.CALIB_SIZES = calib_sizes
# --> 955 df = pipeline.run_all(
#     956     excel_filename="RESULTADOS_TODOS_PROCESOS.xlsx",
#     957     batch_size=20,
#     958     max_workers=3
#     959 )
#     961 # Análisis
#     962 analisis_tamanos_crecientes(df)
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base\pipeline.py:1432, in Pipeline140_TamanosCrecientes.run_all(self, excel_filename, batch_size, max_workers)
#    1428 batch = tasks[start_idx:end_idx]
#    1430 print(f"🔄 Procesando batch {i+1}/{num_batches}...")
# -> 1432 results = Parallel(n_jobs=max_workers, backend='loky')(
#    1433     delayed(self._run_scenario_wrapper)(t) for t in batch
#    1434 )
#    1436 for r in results:
#    1437     all_results.extend(r)
#
# File c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:
