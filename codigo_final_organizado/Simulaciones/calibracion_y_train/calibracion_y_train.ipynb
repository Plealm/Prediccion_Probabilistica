# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_test_tamanos_reducido

main_test_tamanos_reducido()
# Out:
# ================================================================================
# 🧪 TEST REDUCIDO - TAMAÑOS CRECIENTES
# ================================================================================
#
# 🔍 Generando escenarios para ARMA:
#    • Configs: 2
#    • Tamaños: 2
#    • Distribuciones: 2
#    • Varianzas: 2
#    • ESPERADOS: 16 escenarios
#    • Filas esperadas: 192
#
# ✅ Generados 16 escenarios
#
#
# ============================================================
# 🚀 PIPELINE TAMAÑOS CRECIENTES - ARMA
# ============================================================
# 📊 Total escenarios: 16
# 📦 Batches: 4 (tamaño 4)
# 👷 Workers: 2 de 16 cores
# 💾 Guardado cada 2 batches
# ============================================================
#
# 🔄 Batch 1/4... ✅ 48 filas
# 🔄 Batch 2/4... ✅ 96 filas
# 💾 Checkpoint: TEST_TAMANOS.xlsx
# 🔄 Batch 3/4... ✅ 144 filas
# 🔄 Batch 4/4... ✅ 192 filas
# 💾 Checkpoint: TEST_TAMANOS.xlsx
#
# 🎉 Completado: 192 filas → TEST_TAMANOS.xlsx
#
#
# ✅ Test completado: 192 filas
# 📁 Archivo: TEST_TAMANOS.xlsx
#
# 📊 Verificación de NaN:
#    ✅ Block Bootstrapping: Sin NaN
#    ✅ Sieve Bootstrap: Sin NaN
#    ✅ LSPM: Sin NaN
#    ✅ LSPMW: Sin NaN
#    ✅ AREPD: Sin NaN
#    ✅ MCPS: Sin NaN
#    ✅ AV-MCPS: Sin NaN
#    ✅ DeepAR: Sin NaN
#    ✅ EnCQR-LSTM: Sin NaN
#      Paso Tipo_Proceso Proceso Distribución  Varianza  N_Train  N_Calib  \
# 0       1         ARMA   AR(1)       normal       0.5      100       20
# 1       2         ARMA   AR(1)       normal       0.5      100       20
# 2       3         ARMA   AR(1)       normal       0.5      100       20
# 3       4         ARMA   AR(1)       normal       0.5      100       20
# 4       5         ARMA   AR(1)       normal       0.5      100       20
# ..    ...          ...     ...          ...       ...      ...      ...
# 187     8         ARMA   AR(2)    t-student       1.0      199       41
# 188     9         ARMA   AR(2)    t-student       1.0      199       41
# 189    10         ARMA   AR(2)    t-student       1.0      199       41
# 190    11         ARMA   AR(2)    t-student       1.0      199       41
# 191    12         ARMA   AR(2)    t-student       1.0      199       41
#
#      N_Total   Size  Block Bootstrapping  Sieve Bootstrap      LSPM     LSPMW  \
# 0        120  N=120             0.493890         0.424474  0.455536  0.462322
# 1        120  N=120             0.476243         0.403837  0.410773  0.517116
# 2        120  N=120             0.498223         0.417476  0.445635  0.440651
# 3        120  N=120             0.508040         0.396053  0.397258  0.408042
# 4        120  N=120             0.507409         0.420893  0.601281  0.718812
# ..       ...    ...                  ...              ...       ...       ...
# 187      240  N=240             0.566583         0.520853  0.523217  0.538235
# 188      240  N=240             0.529101         0.526067  0.546045  0.527037
# 189      240  N=240             0.558530         0.532165  0.639913  0.582923
# 190      240  N=240             0.664364         0.510363  0.549916  0.681942
# 191      240  N=240             0.610746         0.573246  0.867362  0.575140
#
#         AREPD      MCPS   AV-MCPS    DeepAR  EnCQR-LSTM
# 0    0.433660  0.451231  0.455897  0.418297    0.549429
# 1    0.423487  0.423096  0.439292  0.404954    0.495167
# 2    0.449427  0.521762  0.546676  0.413417    0.578143
# 3    0.455494  0.502816  0.573068  0.396237    0.599805
# 4    0.463135  0.622775  0.613513  0.412144    0.430230
# ..        ...       ...       ...       ...         ...
# 187  0.575056  0.546168  0.602396  0.520559    0.537767
# 188  0.551861  0.579758  0.555190  0.530497    0.547665
# 189  0.551401  0.592930  0.704671  0.538823    0.663982
# 190  0.611275  0.645836  0.898306  0.536457    0.784582
# 191  0.605295  0.603483  0.612807  0.577523    0.572511
#
# [192 rows x 18 columns]

# %%
from runner import main_comparacion_todos_procesos

main_comparacion_todos_procesos()
# Out:
# ================================================================================
# 🚀 INICIANDO PIPELINE UNIFICADO - TAMAÑOS CRECIENTES
# ================================================================================
#
# 📋 Configuración:
#   • 3 tipos de procesos (ARMA, ARIMA, SETAR)
#   • 7 configuraciones por proceso = 21 total
#   • 5 tamaños diferentes (120, 240, 360, 600, 1200)
#   • Proporción fija: 83% train / 17% calib
#   • 5 distribuciones de ruido
#   • 4 niveles de varianza
#   • 12 pasos de predicción por escenario
#   • TOTAL ESCENARIOS: 21 × 5 × 5 × 4 = 2,100
#   • TOTAL FILAS: 2,100 × 12 = 25,200
#
#
# ================================================================================
# 📊 PROCESANDO: ARMA
# ================================================================================
#
#
# 🔍 Generando escenarios para ARMA:
#    • Configs: 7
#    • Tamaños: 5
#    • Distribuciones: 5
#    • Varianzas: 4
#    • ESPERADOS: 700 escenarios
#    • Filas esperadas: 8400
#
# ✅ Generados 700 escenarios
#
#
# ============================================================
# 🚀 PIPELINE TAMAÑOS CRECIENTES - ARMA
# ============================================================
# 📊 Total escenarios: 700
# 📦 Batches: 35 (tamaño 20)
# 👷 Workers: 12 de 16 cores
# 💾 Guardado cada 3 batches
# ============================================================
#
# 🔄 Batch 1/35... ✅ 240 filas
# 🔄 Batch 2/35... ✅ 480 filas
# 🔄 Batch 3/35... ✅ 720 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 4/35... ✅ 960 filas
# 🔄 Batch 5/35... ✅ 1200 filas
# 🔄 Batch 6/35... ✅ 1440 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 7/35... ✅ 1680 filas
# 🔄 Batch 8/35... ✅ 1920 filas
# 🔄 Batch 9/35... ✅ 2160 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 10/35... ✅ 2400 filas
# 🔄 Batch 11/35... ✅ 2640 filas
# 🔄 Batch 12/35... ✅ 2880 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 13/35... ✅ 3120 filas
# 🔄 Batch 14/35... ✅ 3360 filas
# 🔄 Batch 15/35... ✅ 3600 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 16/35... ✅ 3840 filas
# 🔄 Batch 17/35... ✅ 4080 filas
# 🔄 Batch 18/35... ✅ 4320 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 19/35... ✅ 4560 filas
# 🔄 Batch 20/35... ✅ 4800 filas
# 🔄 Batch 21/35... ✅ 5040 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 22/35... ✅ 5280 filas
# 🔄 Batch 23/35... ✅ 5520 filas
# 🔄 Batch 24/35... ✅ 5760 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 25/35... ✅ 6000 filas
# 🔄 Batch 26/35... ✅ 6240 filas
# 🔄 Batch 27/35... ✅ 6480 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 28/35... ✅ 6720 filas
# 🔄 Batch 29/35... ✅ 6960 filas
# 🔄 Batch 30/35... ✅ 7200 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 31/35... ✅ 7440 filas
# 🔄 Batch 32/35... ✅ 7680 filas
# 🔄 Batch 33/35... ✅ 7920 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
# 🔄 Batch 34/35... ✅ 8160 filas
# 🔄 Batch 35/35... ✅ 8400 filas
# 💾 Checkpoint: RESULTADOS_TAMANOS_ARMA.xlsx
#
# 🎉 Completado: 8400 filas → RESULTADOS_TAMANOS_ARMA.xlsx
#
# ✅ ARMA completado: 8400 filas
#
#
# ================================================================================
# 📊 PROCESANDO: ARIMA
# ================================================================================
#
#
# 🔍 Generando escenarios para ARIMA:
#    • Configs: 7
#    • Tamaños: 5
#    • Distribuciones: 5
#    • Varianzas: 4
#    • ESPERADOS: 700 escenarios
#    • Filas esperadas: 8400
#
# ✅ Generados 700 escenarios
#
#
# ============================================================
# 🚀 PIPELINE TAMAÑOS CRECIENTES - ARIMA
# ============================================================
# 📊 Total escenarios: 700
# 📦 Batches: 35 (tamaño 20)
# 👷 Workers: 12 de 16 cores
# 💾 Guardado cada 3 batches
# ============================================================
#
# 🔄 Batch 1/35... ✅ 240 filas
# 🔄 Batch 2/35...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from runner import main_comparacion_todos_procesos
# ----> 3 main_comparacion_todos_procesos()
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base\runner.py:882, in main_comparacion_todos_procesos()
#     873 print(f"{'='*80}\n")
#     875 pipeline = Pipeline140_TamanosCrecientes(
#     876     n_boot=1000,
#     877     seed=42,
#     878     verbose=False,
#     879     proceso_tipo=proceso_tipo
#     880 )
# --> 882 df_proceso = pipeline.run_all(
#     883     excel_filename=f"RESULTADOS_TAMANOS_{proceso_tipo}.xlsx",
#     884     batch_size=20,
#     885     max_workers=12,
#     886     save_frequency=3
#     887 )
#     889 all_results.append(df_proceso)
#     890 print(f"✅ {proceso_tipo} completado: {len(df_proceso)} filas\n")
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base\pipeline.py:1564, in Pipeline140_TamanosCrecientes.run_all(self, excel_filename, batch_size, max_workers, save_frequency)
#    1560 batch = tasks[start_idx:end_idx]
#    1562 print(f"🔄 Batch {i+1}/{num_batches}... ", end='', flush=True)
# -> 1564 batch_results = Parallel(n_jobs=max_workers, backend='loky', verbose=0)(
#    1565     delayed(self._run_scenario_wrapper)(t) for t in batch
#    1566 )
#    1568 for result_list in batch_results:
#    1569     all_results.extend(result_list)
#
# File c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:
