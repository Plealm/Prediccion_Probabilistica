# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_test_tamanos_reducido

main_test_tamanos_reducido()
# Out:
# ================================================================================
# TEST REDUCIDO - TAMAÑOS CRECIENTES (TODOS LOS PROCESOS)
# ================================================================================
#
# ============================================================
# EJECUTANDO ARMA...
# ============================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO ARMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
#
# 📊 CONFIGURACIÓN:
#   • Tamaños de entrenamiento: [100, 200]
#   • Tamaños de calibración: [20, 40]
#   • Combinaciones de tamaños: 4
#   • Configuraciones ARMA: 2
#   • Distribuciones: 1
#   • Varianzas: 1
#   • ESCENARIOS BASE TOTALES: 8
#   • FILAS ESPERADAS: ~104
# ================================================================================
#
#
# 🚀 Lote 1/2 (Escenarios 1 a 4)...
# 🚀 Lote 2/2 (Escenarios 5 a 8)...
# ================================================================================
# ✅ COMPLETADO - 104 filas generadas
# ================================================================================
#
# ============================================================
# EJECUTANDO ARIMA...
# ============================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO ARIMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
#
# 📊 CONFIGURACIÓN:
#   • Tamaños de entrenamiento: [100, 200]
#   • Tamaños de calibración: [20, 40]
#   • Combinaciones de tamaños: 4
#   • Configuraciones ARIMA: 2
#   • Distribuciones: 1
#   • Varianzas: 1
#   • ESCENARIOS BASE TOTALES: 8
#   • FILAS ESPERADAS: ~104
# ================================================================================
#
#
# 🚀 Lote 1/2 (Escenarios 1 a 4)...
# 🚀 Lote 2/2 (Escenarios 5 a 8)...
# ================================================================================
# ✅ COMPLETADO - 104 filas generadas
# ================================================================================
#
# ============================================================
# EJECUTANDO SETAR...
# ============================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO SETAR
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
#
# 📊 CONFIGURACIÓN:
#   • Tamaños de entrenamiento: [100, 200]
#   • Tamaños de calibración: [20, 40]
#   • Combinaciones de tamaños: 4
#   • Configuraciones SETAR: 2
#   • Distribuciones: 1
#   • Varianzas: 1
#   • ESCENARIOS BASE TOTALES: 8
#   • FILAS ESPERADAS: ~104
# ================================================================================
#
#
# 🚀 Lote 1/2 (Escenarios 1 a 4)...
# 🚀 Lote 2/2 (Escenarios 5 a 8)...
# ================================================================================
# ✅ COMPLETADO - 104 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS COMPARATIVO DE LOS TRES PROCESOS
# ================================================================================
#
# ============================================================
# PROCESO: ARMA
# ============================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
#
# ================================================================================
# 📊 1. RANKING GLOBAL POR TAMAÑO TOTAL DE DATOS
# ================================================================================
#
# ======================================================================
# N_Total = 120
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      MCPS                      0.648322
# 2      DeepAR                    0.653663
# 3      AREPD                     0.662183
# 4      AV-MCPS                   0.668801
# 5      Block Bootstrapping       0.674016
#
# ======================================================================
# N_Total = 140
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      MCPS                      0.645789
# 2      Sieve Bootstrap           0.651616
# 3      DeepAR                    0.675430
# 4      AV-MCPS                   0.714904
# 5      LSPM                      0.904144
#
# ======================================================================
# N_Total = 220
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      DeepAR                    0.611422
# 2      Sieve Bootstrap           0.619634
# 3      LSPM                      0.754364
# 4      LSPMW                     0.771726
# 5      AV-MCPS                   0.905863
#
# ======================================================================
# N_Total = 240
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.471408
# 2      DeepAR                    0.486963
# 3      LSPM                      0.583276
# 4      LSPMW                     0.625772
# 5      AV-MCPS                   0.773139
#
# ================================================================================
# 📈 2. IMPACTO DE N_TRAIN EN EL DESEMPEÑO
# ================================================================================
#
# ======================================================================
# N_Calib = 20 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200
# ---------------------------------------------------
# AREPD                     0.66218  1.68500
# AV-MCPS                   0.66880  0.90586
# Block Bootstrapping       0.67402  1.34692
# DeepAR                    0.65366  0.61142
# EnCQR-LSTM                1.10867  0.94244
# LSPM                      0.80627  0.75436
# LSPMW                     0.81713  0.77173
# MCPS                      0.64832  0.97054
# Sieve Bootstrap           0.69814  0.61963
#
# ======================================================================
# N_Calib = 40 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200
# ---------------------------------------------------
# AREPD                     1.30571  1.10303
# AV-MCPS                   0.71490  0.77314
# Block Bootstrapping       1.10786  1.23825
# DeepAR                    0.67543  0.48696
# EnCQR-LSTM                1.25458  0.97712
# LSPM                      0.90414  0.58328
# LSPMW                     0.94860  0.62577
# MCPS                      0.64579  0.80238
# Sieve Bootstrap           0.65162  0.47141
#
# ================================================================================
# 📈 3. IMPACTO DE N_CALIB EN EL DESEMPEÑO
# ================================================================================
#
# ======================================================================
# N_Train = 100 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40
# -------------------------------------------------
# AREPD                     0.66218  1.30571
# AV-MCPS                   0.66880  0.71490
# Block Bootstrapping       0.67402  1.10786
# DeepAR                    0.65366  0.67543
# EnCQR-LSTM                1.10867  1.25458
# LSPM                      0.80627  0.90414
# LSPMW                     0.81713  0.94860
# MCPS                      0.64832  0.64579
# Sieve Bootstrap           0.69814  0.65162
#
# ======================================================================
# N_Train = 200 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40
# -------------------------------------------------
# AREPD                     1.68500  1.10303
# AV-MCPS                   0.90586  0.77314
# Block Bootstrapping       1.34692  1.23825
# DeepAR                    0.61142  0.48696
# EnCQR-LSTM                0.94244  0.97712
# LSPM                      0.75436  0.58328
# LSPMW                     0.77173  0.62577
# MCPS                      0.97054  0.80238
# Sieve Bootstrap           0.61963  0.47141
#
# ================================================================================
# 🎯 4. MEJOR COMBINACIÓN (N_TRAIN, N_CALIB) POR MODELO
# ================================================================================
#
# Modelo                    Mejor N_Train   Mejor N_Calib   CRPS
# ---------------------------------------------------------------------------
# AREPD                     100             20              0.662183
# AV-MCPS                   100             20              0.668801
# Block Bootstrapping       100             20              0.674016
# DeepAR                    200             40              0.486963
# EnCQR-LSTM                200             20              0.942439
# LSPM                      200             40              0.583276
# LSPMW                     200             40              0.625772
# MCPS                      100             40              0.645789
# Sieve Bootstrap           200             40              0.471408
#
# ================================================================================
# 💹 5. MEJORA MARGINAL AL INCREMENTAR DATOS
# ================================================================================
#
# --- Mejora al incrementar N_Train (N_Calib fijo) ---
#
# N_Calib = 20:
# Modelo                    100→200
# ------------------------------------------------------------
# AREPD                     -154.5%
# AV-MCPS                   -35.4%
# Block Bootstrapping       -99.8%
# DeepAR                     +6.5%
# EnCQR-LSTM                +15.0%
# LSPM                       +6.4%
# LSPMW                      +5.6%
# MCPS                      -49.7%
# Sieve Bootstrap           +11.2%
#
# N_Calib = 40:
# Modelo                    100→200
# ------------------------------------------------------------
# AREPD                     +15.5%
# AV-MCPS                    -8.1%
# Block Bootstrapping       -11.8%
# DeepAR                    +27.9%
# EnCQR-LSTM                +22.1%
# LSPM                      +35.5%
# LSPMW                     +34.0%
# MCPS                      -24.2%
# Sieve Bootstrap           +27.7%
#
# ================================================================================
# 🎚️ 6. ANÁLISIS DE SATURACIÓN (¿Cuándo más datos no ayudan?)
# ================================================================================
#
# Criterio: Mejora < 2% al incrementar datos = SATURADO
#
#
# AREPD:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# AV-MCPS:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# Block Bootstrapping:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# DeepAR:
#
# EnCQR-LSTM:
#
# LSPM:
#
# LSPMW:
#
# MCPS:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# Sieve Bootstrap:
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✅ MEJOR MODELO GLOBAL:
#    → DeepAR: CRPS = 0.606870
#
# ❌ PEOR MODELO GLOBAL:
#    → AREPD: CRPS = 1.188980
#
# 🎯 MEJOR TAMAÑO TOTAL DE DATOS:
#    → N_Total = 120: CRPS promedio = 0.748578
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ============================================================
# PROCESO: ARIMA
# ============================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
#
# ================================================================================
# 📊 1. RANKING GLOBAL POR TAMAÑO TOTAL DE DATOS
# ================================================================================
#
# ======================================================================
# N_Total = 120
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.688124
# 2      DeepAR                    0.996057
# 3      AV-MCPS                   1.029349
# 4      LSPM                      1.061637
# 5      LSPMW                     1.068823
#
# ======================================================================
# N_Total = 140
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.650725
# 2      AV-MCPS                   0.952895
# 3      LSPM                      1.024143
# 4      LSPMW                     1.076510
# 5      DeepAR                    1.376952
#
# ======================================================================
# N_Total = 220
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.626975
# 2      LSPM                      1.078066
# 3      LSPMW                     1.116948
# 4      MCPS                      1.444075
# 5      AV-MCPS                   1.726211
#
# ======================================================================
# N_Total = 240
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.478215
# 2      LSPM                      0.725292
# 3      LSPMW                     0.732858
# 4      MCPS                      4.356896
# 5      EnCQR-LSTM                4.771558
#
# ================================================================================
# 📈 2. IMPACTO DE N_TRAIN EN EL DESEMPEÑO
# ================================================================================
#
# ======================================================================
# N_Calib = 20 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200
# ---------------------------------------------------
# AREPD                     5.34960  7.09171
# AV-MCPS                   1.02935  1.72621
# Block Bootstrapping       6.49645  7.88135
# DeepAR                    0.99606  1.75169
# EnCQR-LSTM                3.43490  2.69892
# LSPM                      1.06164  1.07807
# LSPMW                     1.06882  1.11695
# MCPS                      1.18339  1.44407
# Sieve Bootstrap           0.68812  0.62698
#
# ======================================================================
# N_Calib = 40 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200
# ---------------------------------------------------
# AREPD                     9.75487  18.52176
# AV-MCPS                   0.95289  7.76355
# Block Bootstrapping       10.53224  19.80189
# DeepAR                    1.37695  7.91029
# EnCQR-LSTM                4.72682  4.77156
# LSPM                      1.02414  0.72529
# LSPMW                     1.07651  0.73286
# MCPS                      1.69197  4.35690
# Sieve Bootstrap           0.65072  0.47822
#
# ================================================================================
# 📈 3. IMPACTO DE N_CALIB EN EL DESEMPEÑO
# ================================================================================
#
# ======================================================================
# N_Train = 100 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40
# -------------------------------------------------
# AREPD                     5.34960  9.75487
# AV-MCPS                   1.02935  0.95289
# Block Bootstrapping       6.49645  10.53224
# DeepAR                    0.99606  1.37695
# EnCQR-LSTM                3.43490  4.72682
# LSPM                      1.06164  1.02414
# LSPMW                     1.06882  1.07651
# MCPS                      1.18339  1.69197
# Sieve Bootstrap           0.68812  0.65072
#
# ======================================================================
# N_Train = 200 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40
# -------------------------------------------------
# AREPD                     7.09171  18.52176
# AV-MCPS                   1.72621  7.76355
# Block Bootstrapping       7.88135  19.80189
# DeepAR                    1.75169  7.91029
# EnCQR-LSTM                2.69892  4.77156
# LSPM                      1.07807  0.72529
# LSPMW                     1.11695  0.73286
# MCPS                      1.44407  4.35690
# Sieve Bootstrap           0.62698  0.47822
#
# ================================================================================
# 🎯 4. MEJOR COMBINACIÓN (N_TRAIN, N_CALIB) POR MODELO
# ================================================================================
#
# Modelo                    Mejor N_Train   Mejor N_Calib   CRPS
# ---------------------------------------------------------------------------
# AREPD                     100             20              5.349595
# AV-MCPS                   100             40              0.952895
# Block Bootstrapping       100             20              6.496447
# DeepAR                    100             20              0.996057
# EnCQR-LSTM                200             20              2.698921
# LSPM                      200             40              0.725292
# LSPMW                     200             40              0.732858
# MCPS                      100             20              1.183395
# Sieve Bootstrap           200             40              0.478215
#
# ================================================================================
# 💹 5. MEJORA MARGINAL AL INCREMENTAR DATOS
# ================================================================================
#
# --- Mejora al incrementar N_Train (N_Calib fijo) ---
#
# N_Calib = 20:
# Modelo                    100→200
# ------------------------------------------------------------
# AREPD                     -32.6%
# AV-MCPS                   -67.7%
# Block Bootstrapping       -21.3%
# DeepAR                    -75.9%
# EnCQR-LSTM                +21.4%
# LSPM                       -1.5%
# LSPMW                      -4.5%
# MCPS                      -22.0%
# Sieve Bootstrap            +8.9%
#
# N_Calib = 40:
# Modelo                    100→200
# ------------------------------------------------------------
# AREPD                     -89.9%
# AV-MCPS                   -714.7%
# Block Bootstrapping       -88.0%
# DeepAR                    -474.5%
# EnCQR-LSTM                 -0.9%
# LSPM                      +29.2%
# LSPMW                     +31.9%
# MCPS                      -157.5%
# Sieve Bootstrap           +26.5%
#
# ================================================================================
# 🎚️ 6. ANÁLISIS DE SATURACIÓN (¿Cuándo más datos no ayudan?)
# ================================================================================
#
# Criterio: Mejora < 2% al incrementar datos = SATURADO
#
#
# AREPD:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# AV-MCPS:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# Block Bootstrapping:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# DeepAR:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# EnCQR-LSTM:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=40)
#
# LSPM:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# LSPMW:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# MCPS:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# Sieve Bootstrap:
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✅ MEJOR MODELO GLOBAL:
#    → Sieve Bootstrap: CRPS = 0.611010
#
# ❌ PEOR MODELO GLOBAL:
#    → Block Bootstrapping: CRPS = 11.177984
#
# 🎯 MEJOR TAMAÑO TOTAL DE DATOS:
#    → N_Total = 120: CRPS promedio = 2.367592
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ============================================================
# PROCESO: SETAR
# ============================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
#
# ================================================================================
# 📊 1. RANKING GLOBAL POR TAMAÑO TOTAL DE DATOS
# ================================================================================
#
# ======================================================================
# N_Total = 120
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      DeepAR                    0.839891
# 2      Sieve Bootstrap           0.939778
# 3      AV-MCPS                   0.959629
# 4      MCPS                      0.976692
# 5      Block Bootstrapping       1.133330
#
# ======================================================================
# N_Total = 140
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      MCPS                      0.697050
# 2      Sieve Bootstrap           0.738543
# 3      AV-MCPS                   0.750885
# 4      DeepAR                    0.751868
# 5      Block Bootstrapping       0.752405
#
# ======================================================================
# N_Total = 220
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      DeepAR                    0.606318
# 2      AV-MCPS                   0.650220
# 3      Block Bootstrapping       0.661388
# 4      Sieve Bootstrap           0.684217
# 5      LSPM                      0.684379
#
# ======================================================================
# N_Total = 240
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      DeepAR                    0.477267
# 2      Block Bootstrapping       0.524755
# 3      Sieve Bootstrap           0.551550
# 4      AREPD                     0.556222
# 5      LSPM                      0.560422
#
# ================================================================================
# 📈 2. IMPACTO DE N_TRAIN EN EL DESEMPEÑO
# ================================================================================
#
# ======================================================================
# N_Calib = 20 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200
# ---------------------------------------------------
# AREPD                     1.18689  0.84322
# AV-MCPS                   0.95963  0.65022
# Block Bootstrapping       1.13333  0.66139
# DeepAR                    0.83989  0.60632
# EnCQR-LSTM                1.25563  0.85028
# LSPM                      1.42916  0.68438
# LSPMW                     1.40600  0.69291
# MCPS                      0.97669  0.75326
# Sieve Bootstrap           0.93978  0.68422
#
# ======================================================================
# N_Calib = 40 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200
# ---------------------------------------------------
# AREPD                     0.85013  0.55622
# AV-MCPS                   0.75088  0.63209
# Block Bootstrapping       0.75240  0.52475
# DeepAR                    0.75187  0.47727
# EnCQR-LSTM                1.07962  0.90416
# LSPM                      0.90545  0.56042
# LSPMW                     0.94576  0.58759
# MCPS                      0.69705  0.64978
# Sieve Bootstrap           0.73854  0.55155
#
# ================================================================================
# 📈 3. IMPACTO DE N_CALIB EN EL DESEMPEÑO
# ================================================================================
#
# ======================================================================
# N_Train = 100 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40
# -------------------------------------------------
# AREPD                     1.18689  0.85013
# AV-MCPS                   0.95963  0.75088
# Block Bootstrapping       1.13333  0.75240
# DeepAR                    0.83989  0.75187
# EnCQR-LSTM                1.25563  1.07962
# LSPM                      1.42916  0.90545
# LSPMW                     1.40600  0.94576
# MCPS                      0.97669  0.69705
# Sieve Bootstrap           0.93978  0.73854
#
# ======================================================================
# N_Train = 200 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40
# -------------------------------------------------
# AREPD                     0.84322  0.55622
# AV-MCPS                   0.65022  0.63209
# Block Bootstrapping       0.66139  0.52475
# DeepAR                    0.60632  0.47727
# EnCQR-LSTM                0.85028  0.90416
# LSPM                      0.68438  0.56042
# LSPMW                     0.69291  0.58759
# MCPS                      0.75326  0.64978
# Sieve Bootstrap           0.68422  0.55155
#
# ================================================================================
# 🎯 4. MEJOR COMBINACIÓN (N_TRAIN, N_CALIB) POR MODELO
# ================================================================================
#
# Modelo                    Mejor N_Train   Mejor N_Calib   CRPS
# ---------------------------------------------------------------------------
# AREPD                     200             40              0.556222
# AV-MCPS                   200             40              0.632092
# Block Bootstrapping       200             40              0.524755
# DeepAR                    200             40              0.477267
# EnCQR-LSTM                200             20              0.850285
# LSPM                      200             40              0.560422
# LSPMW                     200             40              0.587588
# MCPS                      200             40              0.649780
# Sieve Bootstrap           200             40              0.551550
#
# ================================================================================
# 💹 5. MEJORA MARGINAL AL INCREMENTAR DATOS
# ================================================================================
#
# --- Mejora al incrementar N_Train (N_Calib fijo) ---
#
# N_Calib = 20:
# Modelo                    100→200
# ------------------------------------------------------------
# AREPD                     +29.0%
# AV-MCPS                   +32.2%
# Block Bootstrapping       +41.6%
# DeepAR                    +27.8%
# EnCQR-LSTM                +32.3%
# LSPM                      +52.1%
# LSPMW                     +50.7%
# MCPS                      +22.9%
# Sieve Bootstrap           +27.2%
#
# N_Calib = 40:
# Modelo                    100→200
# ------------------------------------------------------------
# AREPD                     +34.6%
# AV-MCPS                   +15.8%
# Block Bootstrapping       +30.3%
# DeepAR                    +36.5%
# EnCQR-LSTM                +16.3%
# LSPM                      +38.1%
# LSPMW                     +37.9%
# MCPS                       +6.8%
# Sieve Bootstrap           +25.3%
#
# ================================================================================
# 🎚️ 6. ANÁLISIS DE SATURACIÓN (¿Cuándo más datos no ayudan?)
# ================================================================================
#
# Criterio: Mejora < 2% al incrementar datos = SATURADO
#
#
# AREPD:
#
# AV-MCPS:
#
# Block Bootstrapping:
#
# DeepAR:
#
# EnCQR-LSTM:
#
# LSPM:
#
# LSPMW:
#
# MCPS:
#
# Sieve Bootstrap:
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✅ MEJOR MODELO GLOBAL:
#    → DeepAR: CRPS = 0.668836
#
# ❌ PEOR MODELO GLOBAL:
#    → EnCQR-LSTM: CRPS = 1.022423
#
# 🎯 MEJOR TAMAÑO TOTAL DE DATOS:
#    → N_Total = 240: CRPS promedio = 0.604870
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 199.7s
# {'ARMA':          Paso Proceso Tipo_Proceso Distribución  Varianza  N_Train  N_Calib  \
#  0           1   AR(1)         ARMA       normal       1.0      100       20
#  1           2   AR(1)         ARMA       normal       1.0      100       20
#  2           3   AR(1)         ARMA       normal       1.0      100       20
#  3           4   AR(1)         ARMA       normal       1.0      100       20
#  4           5   AR(1)         ARMA       normal       1.0      100       20
#  ..        ...     ...          ...          ...       ...      ...      ...
#  99          9   AR(2)         ARMA       normal       1.0      200       40
#  100        10   AR(2)         ARMA       normal       1.0      200       40
#  101        11   AR(2)         ARMA       normal       1.0      200       40
#  102        12   AR(2)         ARMA       normal       1.0      200       40
#  103  Promedio   AR(2)         ARMA       normal       1.0      200       40
#
#       N_Total  Valor_Observado  Block Bootstrapping  Sieve Bootstrap      LSPM  \
#  0        120        -0.497589             0.433274         0.389747  0.239211
#  1        120        -0.001758             0.570455         0.276200  0.233925
#  2        120        -0.456566             0.415211         0.189691  0.259870
#  3        120        -1.636515             0.485430         1.184191  0.899508
#  4        120        -2.750801             1.103271         0.238019  1.769092
#  ..       ...              ...                  ...              ...       ...
#  99       240         0.190990             0.274064         0.242156  0.516741
#  100      240        -0.336118             0.305436         0.350235  0.570012
#  101      240        -1.716152             1.240388         0.981679  1.308916
#  102      240        -0.903684             0.598072         0.233611  0.383763
#  103      240              NaN             0.546089         0.511211  0.670695
#
#          LSPMW    DeepAR     AREPD      MCPS   AV-MCPS  EnCQR-LSTM
#  0    0.231721  0.366455  0.207387  0.278004  0.296665    1.249832
#  1    0.238815  0.311880  0.463267  0.874331  0.706384    1.297048
#  2    0.266131  0.334450  0.213503  0.257859  0.287819    1.256626
#  3    0.996223  0.777572  0.556693  0.305632  0.442821    1.157275
#  4    1.876428  1.328762  1.637164  0.638139  0.601137    1.088354
#  ..        ...       ...       ...       ...       ...         ...
#  99   0.469456  0.421115  0.162743  0.298243  0.300774    0.795018
#  100  0.684655  0.372747  0.300301  1.065028  0.606156    0.727643
#  101  1.428688  0.835391  1.532372  0.956056  0.998964    0.842756
#  102  0.429988  0.208480  0.736911  0.463185  0.652854    0.669141
#  103  0.694219  0.550426  0.571093  0.635044  0.619937    0.793841
#
#  [104 rows x 18 columns],
#  'ARIMA':          Paso       Proceso Tipo_Proceso Distribución  Varianza  N_Train  \
#  100        10  SETAR-2        SETAR       normal       1.0      200       40
#  101        11  SETAR-2        SETAR       normal       1.0      200       40
#  102        12  SETAR-2        SETAR       normal       1.0      200       40
#  103  Promedio  SETAR-2        SETAR       normal       1.0      200       40
#
#       N_Total  Valor_Observado  Block Bootstrapping  Sieve Bootstrap      LSPM  \
#  0        120        -0.771263             0.254205         0.667155  0.216709
#  1        120        -0.016685             0.445793         0.461822  0.499910
#  2        120        -0.464995             0.265498         0.193432  0.306417
#  3        120        -1.504603             0.422613         1.033804  0.507797
#  4        120        -2.180699             0.926323         0.192999  1.105353
#  ..       ...              ...                  ...              ...       ...
#  99       240         1.129509             0.699451         0.703095  0.655936
#  100      240        -1.012743             0.593015         0.441464  0.590342
#  101      240        -0.781876             0.508680         0.856978  0.363737
#  102      240        -0.693756             0.428672         0.522484  0.766854
#  103      240              NaN             0.613761         0.620332  0.631101
#
#          LSPMW    DeepAR     AREPD      MCPS   AV-MCPS  EnCQR-LSTM
#  0    0.214687  0.213060  0.171520  0.268820  0.352253    0.770320
#  1    0.503291  0.584747  0.333070  0.524027  0.535639    0.836068
#  2    0.305533  0.223899  0.138911  0.203281  0.315432    0.797690
#  3    0.551628  0.490075  0.629624  0.422195  0.324176    0.715652
#  4    1.194712  0.585793  1.251428  0.800808  0.786422    0.758628
#  ..        ...       ...       ...       ...       ...         ...
#  99   0.693984  0.199939  0.624217  0.395374  0.909704    1.122880
#  100  0.618748  0.318815  0.788071  0.422684  1.029637    0.852413
#  101  0.385667  0.941654  0.598547  0.470390  0.287189    0.876621
#  102  0.823043  0.418320  0.525108  0.384559  0.504909    0.886431
#  103  0.645348  0.520867  0.643005  0.581402  0.696075    0.996598
#
#  [104 rows x 18 columns]}

# %%
from runner import main_comparacion_todos_procesos

main_comparacion_todos_procesos()
# Out:
# ================================================================================
# ANÁLISIS COMPARATIVO COMPLETO - ARMA vs ARIMA vs SETAR
# ================================================================================
# ================================================================================
# ANÁLISIS TAMAÑOS CRECIENTES - PROCESOS ARMA
# ================================================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO ARMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 20
#
# 📊 CONFIGURACIÓN:
#   • Tamaños de entrenamiento: [100, 200, 300, 500, 1000]
#   • Tamaños de calibración: [20, 40, 60, 100, 200]
#   • Combinaciones de tamaños: 25
#   • Configuraciones ARMA: 7
#   • Distribuciones: 5
#   • Varianzas: 4
#   • ESCENARIOS BASE TOTALES: 3500
#   • FILAS ESPERADAS: ~45500
# ================================================================================
#
#
# 🚀 Lote 1/175 (Escenarios 1 a 20)...
# 🚀 Lote 2/175 (Escenarios 21 a 40)...
# 🚀 Lote 3/175 (Escenarios 41 a 60)...
# 🚀 Lote 4/175 (Escenarios 61 a 80)...
# 🚀 Lote 5/175 (Escenarios 81 a 100)...
# 🚀 Lote 6/175 (Escenarios 101 a 120)...
# 🚀 Lote 7/175 (Escenarios 121 a 140)...
# 🚀 Lote 8/175 (Escenarios 141 a 160)...
# 🚀 Lote 9/175 (Escenarios 161 a 180)...
# 🚀 Lote 10/175 (Escenarios 181 a 200)...
# 🚀 Lote 11/175 (Escenarios 201 a 220)...
# 🚀 Lote 163/175 (Escenarios 3241 a 3260)...
# 🚀 Lote 164/175 (Escenarios 3261 a 3280)...
# 🚀 Lote 165/175 (Escenarios 3281 a 3300)...
# 🚀 Lote 166/175 (Escenarios 3301 a 3320)...
# 🚀 Lote 167/175 (Escenarios 3321 a 3340)...
# 🚀 Lote 168/175 (Escenarios 3341 a 3360)...
# 🚀 Lote 169/175 (Escenarios 3361 a 3380)...
# 🚀 Lote 170/175 (Escenarios 3381 a 3400)...
# 🚀 Lote 171/175 (Escenarios 3401 a 3420)...
# 🚀 Lote 172/175 (Escenarios 3421 a 3440)...
# 🚀 Lote 173/175 (Escenarios 3441 a 3460)...
# 🚀 Lote 174/175 (Escenarios 3461 a 3480)...
# 🚀 Lote 175/175 (Escenarios 3481 a 3500)...
# ================================================================================
# ✅ COMPLETADO - 45500 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
#
# ================================================================================
# 📊 1. RANKING GLOBAL POR TAMAÑO TOTAL DE DATOS
# ================================================================================
#
# ======================================================================
# N_Total = 120
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      DeepAR                    0.596603
# 2      Sieve Bootstrap           0.608901
# 3      MCPS                      0.742972
# 4      LSPM                      0.748521
# 5      LSPMW                     0.770353
#
# ======================================================================
# N_Total = 140
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.593338
# 2      DeepAR                    0.600690
# 3      MCPS                      0.720903
# 4      AV-MCPS                   0.737756
# 5      LSPM                      0.790663
#
# ======================================================================
# N_Total = 160
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.585138
# 2      DeepAR                    0.585230
# 3      MCPS                      0.737862
# 4      AV-MCPS                   0.743885
# 5      LSPM                      0.775898
#
# ======================================================================
# N_Total = 200
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.586548
# 2      DeepAR                    0.604501
# 3      MCPS                      0.771131
# 4      AV-MCPS                   0.772122
# 5      LSPM                      0.788232
#
# ======================================================================
# N_Total = 220
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.570102
# 2      DeepAR                    0.579753
# 3      MCPS                      0.718083
# 4      AV-MCPS                   0.718781
# 5      LSPM                      0.776496
#
# ======================================================================
# N_Total = 240
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.558602
# 2      DeepAR                    0.575258
# 3      MCPS                      0.692414
# 4      AV-MCPS                   0.706830
# 5      LSPM                      0.758115
#
# ======================================================================
# N_Total = 260
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.544335
# 2      DeepAR                    0.562691
# 3      MCPS                      0.692937
# 4      AV-MCPS                   0.718636
# 5      LSPM                      0.761898
#
# ======================================================================
# N_Total = 300
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.550507
# 2      DeepAR                    0.567165
# 3      MCPS                      0.675496
# 4      AV-MCPS                   0.689919
# 5      LSPM                      0.758450
#
# ======================================================================
# N_Total = 320
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.572111
# 2      DeepAR                    0.574024
# 3      MCPS                      0.671698
# 4      AV-MCPS                   0.698490
# 5      LSPM                      0.786668
#
# ======================================================================
# N_Total = 340
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      DeepAR                    0.569764
# 2      Sieve Bootstrap           0.574663
# 3      MCPS                      0.678157
# 4      AV-MCPS                   0.693675
# 5      LSPM                      0.791449
#
# ======================================================================
# N_Total = 360
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.568313
# 2      DeepAR                    0.573824
# 3      MCPS                      0.657527
# 4      AV-MCPS                   0.677576
# 5      LSPM                      0.786126
#
# ======================================================================
# N_Total = 400
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.531148
# 2      DeepAR                    0.534131
# 3      MCPS                      0.609104
# 4      AV-MCPS                   0.637601
# 5      LSPM                      0.743672
#
# ======================================================================
# N_Total = 500
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.536239
# 2      DeepAR                    0.544610
# 3      MCPS                      0.610783
# 4      AV-MCPS                   0.621787
# 5      LSPM                      0.778332
#
# ======================================================================
# N_Total = 520
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.549290
# 2      DeepAR                    0.563058
# 3      MCPS                      0.615199
# 4      AV-MCPS                   0.644883
# 5      LSPM                      0.763548
#
# ======================================================================
# N_Total = 540
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.540077
# 2      DeepAR                    0.553864
# 3      MCPS                      0.607550
# 4      AV-MCPS                   0.637542
# 5      LSPM                      0.755169
#
# ======================================================================
# N_Total = 560
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.538380
# 2      DeepAR                    0.562891
# 3      MCPS                      0.630877
# 4      AV-MCPS                   0.649513
# 5      LSPM                      0.777140
#
# ======================================================================
# N_Total = 600
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.534546
# 2      DeepAR                    0.547074
# 3      MCPS                      0.604082
# 4      AV-MCPS                   0.645969
# 5      LSPM                      0.761509
#
# ======================================================================
# N_Total = 700
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.549906
# 2      DeepAR                    0.565072
# 3      MCPS                      0.616750
# 4      AV-MCPS                   0.657569
# 5      LSPM                      0.788778
#
# ======================================================================
# N_Total = 1020
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.527406
# 2      DeepAR                    0.547567
# 3      MCPS                      0.589321
# 4      AV-MCPS                   0.643828
# 5      LSPM                      0.746337
#
# ======================================================================
# N_Total = 1040
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.552197
# 2      DeepAR                    0.572474
# 3      MCPS                      0.591941
# 4      AV-MCPS                   0.627227
# 5      EnCQR-LSTM                0.781437
#
# ======================================================================
# N_Total = 1060
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.536450
# 2      DeepAR                    0.553047
# 3      MCPS                      0.591701
# 4      AV-MCPS                   0.655010
# 5      EnCQR-LSTM                0.773868
#
# ======================================================================
# N_Total = 1100
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.530196
# 2      DeepAR                    0.551255
# 3      MCPS                      0.573464
# 4      AV-MCPS                   0.640287
# 5      EnCQR-LSTM                0.768153
#
# ======================================================================
# N_Total = 1200
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.532834
# 2      DeepAR                    0.538835
# 3      MCPS                      0.556350
# 4      AV-MCPS                   0.596168
# 5      LSPM                      0.732574
#
# ================================================================================
# 📈 2. IMPACTO DE N_TRAIN EN EL DESEMPEÑO
# ================================================================================
#
# ======================================================================
# N_Calib = 20 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200    N_Train=300    N_Train=500    N_Train=1000
# ------------------------------------------------------------------------------------------
# AREPD                     0.92609  0.95294  0.95398  0.91213  0.93963
# AV-MCPS                   0.77687  0.71878  0.69849  0.64488  0.64383
# Block Bootstrapping       0.87543  0.92823  0.90386  0.87940  0.93701
# DeepAR                    0.59660  0.57975  0.57402  0.56306  0.54757
# EnCQR-LSTM                1.15755  1.08355  0.99903  0.91087  0.76371
# LSPM                      0.74852  0.77650  0.78667  0.76355  0.74634
# LSPMW                     0.77035  0.79593  0.81215  0.79294  0.77173
# MCPS                      0.74297  0.71808  0.67170  0.61520  0.58932
# Sieve Bootstrap           0.60890  0.57010  0.57211  0.54929  0.52741
#
# ======================================================================
# N_Calib = 40 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200    N_Train=300    N_Train=500    N_Train=1000
# ------------------------------------------------------------------------------------------
# AREPD                     0.89189  0.94839  0.92827  0.96354  0.93566
# AV-MCPS                   0.73776  0.70683  0.69368  0.63754  0.62723
# Block Bootstrapping       0.88211  0.92015  0.88821  0.89045  0.89896
# DeepAR                    0.60069  0.57526  0.56976  0.55386  0.57247
# EnCQR-LSTM                1.16101  1.03705  0.97574  0.89648  0.78144
# LSPM                      0.79066  0.75812  0.79145  0.75517  0.79458
# LSPMW                     0.81455  0.78249  0.81607  0.77375  0.82007
# MCPS                      0.72090  0.69241  0.67816  0.60755  0.59194
# Sieve Bootstrap           0.59334  0.55860  0.57466  0.54008  0.55220
#
# ======================================================================
# N_Calib = 60 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200    N_Train=300    N_Train=500    N_Train=1000
# ------------------------------------------------------------------------------------------
# AREPD                     0.90667  0.96121  0.89954  0.93512  0.95399
# AV-MCPS                   0.74388  0.71864  0.67758  0.64951  0.65501
# Block Bootstrapping       0.89494  0.94669  0.88677  0.95810  0.94121
# DeepAR                    0.58523  0.56269  0.57382  0.56289  0.55305
# EnCQR-LSTM                1.10696  1.06932  0.97828  0.89017  0.77387
# LSPM                      0.77590  0.76190  0.78613  0.77714  0.77749
# LSPMW                     0.79723  0.78702  0.81053  0.79881  0.80079
# MCPS                      0.73786  0.69294  0.65753  0.63088  0.59170
# Sieve Bootstrap           0.58514  0.54433  0.56831  0.53838  0.53645
#
# ======================================================================
# N_Calib = 100 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200    N_Train=300    N_Train=500    N_Train=1000
# ------------------------------------------------------------------------------------------
# AREPD                     0.93698  0.94073  0.87972  0.93095  0.94337
# AV-MCPS                   0.77212  0.69525  0.63563  0.64597  0.64029
# Block Bootstrapping       0.91635  0.91286  0.83247  0.90928  0.88525
# DeepAR                    0.60450  0.56887  0.53415  0.54707  0.55125
# EnCQR-LSTM                1.10377  1.01410  0.94532  0.87760  0.76815
# LSPM                      0.78823  0.76265  0.73210  0.76151  0.77774
# LSPMW                     0.81316  0.78642  0.75668  0.79356  0.80449
# MCPS                      0.77113  0.68229  0.60759  0.60408  0.57346
# Sieve Bootstrap           0.58655  0.54962  0.52952  0.53455  0.53020
#
# ======================================================================
# N_Calib = 200 (fijo)
# ======================================================================
#
# Modelo                    N_Train=100    N_Train=200    N_Train=300    N_Train=500    N_Train=1000
# ------------------------------------------------------------------------------------------
# AREPD                     0.95931  0.91479  0.93059  1.01857  0.89846
# AV-MCPS                   0.68459  0.63957  0.62179  0.65757  0.59617
# Block Bootstrapping       0.94568  0.85316  0.88742  0.95265  0.89572
# DeepAR                    0.56546  0.53411  0.54461  0.56507  0.53884
# EnCQR-LSTM                1.02192  0.94397  0.92695  0.85560  0.74550
# LSPM                      0.75425  0.75525  0.77833  0.78878  0.73257
# LSPMW                     0.77580  0.77742  0.80234  0.81674  0.75576
# MCPS                      0.66870  0.61062  0.61078  0.61675  0.55635
# Sieve Bootstrap           0.55140  0.53278  0.53624  0.54991  0.53283
#
# ================================================================================
# 📈 3. IMPACTO DE N_CALIB EN EL DESEMPEÑO
# ================================================================================
#
# ======================================================================
# N_Train = 100 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40    N_Calib=60    N_Calib=100   N_Calib=200
# -------------------------------------------------------------------------------------
# AREPD                     0.92609  0.89189  0.90667  0.93698  0.95931
# AV-MCPS                   0.77687  0.73776  0.74388  0.77212  0.68459
# Block Bootstrapping       0.87543  0.88211  0.89494  0.91635  0.94568
# DeepAR                    0.59660  0.60069  0.58523  0.60450  0.56546
# EnCQR-LSTM                1.15755  1.16101  1.10696  1.10377  1.02192
# LSPM                      0.74852  0.79066  0.77590  0.78823  0.75425
# LSPMW                     0.77035  0.81455  0.79723  0.81316  0.77580
# MCPS                      0.74297  0.72090  0.73786  0.77113  0.66870
# Sieve Bootstrap           0.60890  0.59334  0.58514  0.58655  0.55140
#
# ======================================================================
# N_Train = 200 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40    N_Calib=60    N_Calib=100   N_Calib=200
# -------------------------------------------------------------------------------------
# AREPD                     0.95294  0.94839  0.96121  0.94073  0.91479
# AV-MCPS                   0.71878  0.70683  0.71864  0.69525  0.63957
# Block Bootstrapping       0.92823  0.92015  0.94669  0.91286  0.85316
# DeepAR                    0.57975  0.57526  0.56269  0.56887  0.53411
# EnCQR-LSTM                1.08355  1.03705  1.06932  1.01410  0.94397
# LSPM                      0.77650  0.75812  0.76190  0.76265  0.75525
# LSPMW                     0.79593  0.78249  0.78702  0.78642  0.77742
# MCPS                      0.71808  0.69241  0.69294  0.68229  0.61062
# Sieve Bootstrap           0.57010  0.55860  0.54433  0.54962  0.53278
#
# ======================================================================
# N_Train = 300 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40    N_Calib=60    N_Calib=100   N_Calib=200
# -------------------------------------------------------------------------------------
# AREPD                     0.95398  0.92827  0.89954  0.87972  0.93059
# AV-MCPS                   0.69849  0.69368  0.67758  0.63563  0.62179
# Block Bootstrapping       0.90386  0.88821  0.88677  0.83247  0.88742
# DeepAR                    0.57402  0.56976  0.57382  0.53415  0.54461
# EnCQR-LSTM                0.99903  0.97574  0.97828  0.94532  0.92695
# LSPM                      0.78667  0.79145  0.78613  0.73210  0.77833
# LSPMW                     0.81215  0.81607  0.81053  0.75668  0.80234
# MCPS                      0.67170  0.67816  0.65753  0.60759  0.61078
# Sieve Bootstrap           0.57211  0.57466  0.56831  0.52952  0.53624
#
# ======================================================================
# N_Train = 500 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40    N_Calib=60    N_Calib=100   N_Calib=200
# -------------------------------------------------------------------------------------
# AREPD                     0.91213  0.96354  0.93512  0.93095  1.01857
# AV-MCPS                   0.64488  0.63754  0.64951  0.64597  0.65757
# Block Bootstrapping       0.87940  0.89045  0.95810  0.90928  0.95265
# DeepAR                    0.56306  0.55386  0.56289  0.54707  0.56507
# EnCQR-LSTM                0.91087  0.89648  0.89017  0.87760  0.85560
# LSPM                      0.76355  0.75517  0.77714  0.76151  0.78878
# LSPMW                     0.79294  0.77375  0.79881  0.79356  0.81674
# MCPS                      0.61520  0.60755  0.63088  0.60408  0.61675
# Sieve Bootstrap           0.54929  0.54008  0.53838  0.53455  0.54991
#
# ======================================================================
# N_Train = 1000 (fijo)
# ======================================================================
#
# Modelo                    N_Calib=20    N_Calib=40    N_Calib=60    N_Calib=100   N_Calib=200
# -------------------------------------------------------------------------------------
# AREPD                     0.93963  0.93566  0.95399  0.94337  0.89846
# AV-MCPS                   0.64383  0.62723  0.65501  0.64029  0.59617
# Block Bootstrapping       0.93701  0.89896  0.94121  0.88525  0.89572
# DeepAR                    0.54757  0.57247  0.55305  0.55125  0.53884
# EnCQR-LSTM                0.76371  0.78144  0.77387  0.76815  0.74550
# LSPM                      0.74634  0.79458  0.77749  0.77774  0.73257
# LSPMW                     0.77173  0.82007  0.80079  0.80449  0.75576
# MCPS                      0.58932  0.59194  0.59170  0.57346  0.55635
# Sieve Bootstrap           0.52741  0.55220  0.53645  0.53020  0.53283
#
# ================================================================================
# 🎯 4. MEJOR COMBINACIÓN (N_TRAIN, N_CALIB) POR MODELO
# ================================================================================
#
# Modelo                    Mejor N_Train   Mejor N_Calib   CRPS
# ---------------------------------------------------------------------------
# AREPD                     300             100             0.879716
# AV-MCPS                   1000            200             0.596168
# Block Bootstrapping       300             100             0.832469
# DeepAR                    200             200             0.534110
# EnCQR-LSTM                1000            200             0.745501
# LSPM                      300             100             0.732096
# LSPMW                     1000            200             0.755760
# MCPS                      1000            200             0.556350
# Sieve Bootstrap           1000            20              0.527406
#
# ================================================================================
# 💹 5. MEJORA MARGINAL AL INCREMENTAR DATOS
# ================================================================================
#
# --- Mejora al incrementar N_Train (N_Calib fijo) ---
#
# N_Calib = 20:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      -2.9%   -0.1%   +4.4%   -3.0%
# AV-MCPS                    +7.5%   +2.8%   +7.7%   +0.2%
# Block Bootstrapping        -6.0%   +2.6%   +2.7%   -6.6%
# DeepAR                     +2.8%   +1.0%   +1.9%   +2.8%
# EnCQR-LSTM                 +6.4%   +7.8%   +8.8%  +16.2%
# LSPM                       -3.7%   -1.3%   +2.9%   +2.3%
# LSPMW                      -3.3%   -2.0%   +2.4%   +2.7%
# MCPS                       +3.3%   +6.5%   +8.4%   +4.2%
# Sieve Bootstrap            +6.4%   -0.4%   +4.0%   +4.0%
#
# N_Calib = 40:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      -6.3%   +2.1%   -3.8%   +2.9%
# AV-MCPS                    +4.2%   +1.9%   +8.1%   +1.6%
# Block Bootstrapping        -4.3%   +3.5%   -0.3%   -1.0%
# DeepAR                     +4.2%   +1.0%   +2.8%   -3.4%
# EnCQR-LSTM                +10.7%   +5.9%   +8.1%  +12.8%
# LSPM                       +4.1%   -4.4%   +4.6%   -5.2%
# LSPMW                      +3.9%   -4.3%   +5.2%   -6.0%
# MCPS                       +4.0%   +2.1%  +10.4%   +2.6%
# Sieve Bootstrap            +5.9%   -2.9%   +6.0%   -2.2%
#
# N_Calib = 60:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      -6.0%   +6.4%   -4.0%   -2.0%
# AV-MCPS                    +3.4%   +5.7%   +4.1%   -0.8%
# Block Bootstrapping        -5.8%   +6.3%   -8.0%   +1.8%
# DeepAR                     +3.9%   -2.0%   +1.9%   +1.7%
# EnCQR-LSTM                 +3.4%   +8.5%   +9.0%  +13.1%
# LSPM                       +1.8%   -3.2%   +1.1%   -0.0%
# LSPMW                      +1.3%   -3.0%   +1.4%   -0.2%
# MCPS                       +6.1%   +5.1%   +4.1%   +6.2%
# Sieve Bootstrap            +7.0%   -4.4%   +5.3%   +0.4%
#
# N_Calib = 100:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      -0.4%   +6.5%   -5.8%   -1.3%
# AV-MCPS                   +10.0%   +8.6%   -1.6%   +0.9%
# Block Bootstrapping        +0.4%   +8.8%   -9.2%   +2.6%
# DeepAR                     +5.9%   +6.1%   -2.4%   -0.8%
# EnCQR-LSTM                 +8.1%   +6.8%   +7.2%  +12.5%
# LSPM                       +3.2%   +4.0%   -4.0%   -2.1%
# LSPMW                      +3.3%   +3.8%   -4.9%   -1.4%
# MCPS                      +11.5%  +10.9%   +0.6%   +5.1%
# Sieve Bootstrap            +6.3%   +3.7%   -0.9%   +0.8%
#
# N_Calib = 200:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      +4.6%   -1.7%   -9.5%  +11.8%
# AV-MCPS                    +6.6%   +2.8%   -5.8%   +9.3%
# Block Bootstrapping        +9.8%   -4.0%   -7.4%   +6.0%
# DeepAR                     +5.5%   -2.0%   -3.8%   +4.6%
# EnCQR-LSTM                 +7.6%   +1.8%   +7.7%  +12.9%
# LSPM                       -0.1%   -3.1%   -1.3%   +7.1%
# LSPMW                      -0.2%   -3.2%   -1.8%   +7.5%
# MCPS                       +8.7%   -0.0%   -1.0%   +9.8%
# Sieve Bootstrap            +3.4%   -0.6%   -2.5%   +3.1%
#
# ================================================================================
# 🎚️ 6. ANÁLISIS DE SATURACIÓN (¿Cuándo más datos no ayudan?)
# ================================================================================
#
# Criterio: Mejora < 2% al incrementar datos = SATURADO
#
#
# AREPD:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# AV-MCPS:
#   ✓ Saturado en N_Train ≥ 500 (N_Calib=20)
#
# Block Bootstrapping:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# DeepAR:
#   ✓ Saturado en N_Train ≥ 200 (N_Calib=20)
#
# EnCQR-LSTM:
#   ✓ Saturado en N_Train ≥ 200 (N_Calib=200)
#
# LSPM:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# LSPMW:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# MCPS:
#   ✓ Saturado en N_Train ≥ 300 (N_Calib=100)
#
# Sieve Bootstrap:
#   ✓ Saturado en N_Train ≥ 200 (N_Calib=20)
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✅ MEJOR MODELO GLOBAL:
#    → Sieve Bootstrap: CRPS = 0.554115
#
# ❌ PEOR MODELO GLOBAL:
#    → EnCQR-LSTM: CRPS = 0.951517
#
# 🎯 MEJOR TAMAÑO TOTAL DE DATOS:
#    → N_Total = 1200: CRPS promedio = 0.694689
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 37442.6s (10.40 horas)
# ================================================================================
# ANÁLISIS TAMAÑOS CRECIENTES - PROCESOS ARIMA
# ================================================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO ARIMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 20
#
# 📊 CONFIGURACIÓN:
#   • Tamaños de entrenamiento: [100, 200, 300, 500, 1000]
#   • Tamaños de calibración: [20, 40, 60, 100, 200]
#   • Combinaciones de tamaños: 25
#   • Configuraciones ARIMA: 7
#   • Distribuciones: 5
#   • Varianzas: 4
#   • ESCENARIOS BASE TOTALES: 3500
#   • FILAS ESPERADAS: ~45500
# ================================================================================
#
#
# 🚀 Lote 1/175 (Escenarios 1 a 20)...
# 🚀 Lote 2/175 (Escenarios 21 a 40)...
# 🚀 Lote 3/175 (Escenarios 41 a 60)...
# 🚀 Lote 4/175 (Escenarios 61 a 80)...
# 🚀 Lote 157/175 (Escenarios 3121 a 3140)...
# 🚀 Lote 158/175 (Escenarios 3141 a 3160)...
# 🚀 Lote 159/175 (Escenarios 3161 a 3180)...
# 🚀 Lote 160/175 (Escenarios 3181 a 3200)...
# 🚀 Lote 161/175 (Escenarios 3201 a 3220)...
# 🚀 Lote 162/175 (Escenarios 3221 a 3240)...
# 🚀 Lote 163/175 (Escenarios 3241 a 3260)...
# 🚀 Lote 164/175 (Escenarios 3261 a 3280)...
# 🚀 Lote 165/175 (Escenarios 3281 a 3300)...
# 🚀 Lote 166/175 (Escenarios 3301 a 3320)...
# 🚀 Lote 167/175 (Escenarios 3321 a 3340)...
# 🚀 Lote 168/175 (Escenarios 3341 a 3360)...
# 🚀 Lote 169/175 (Escenarios 3361 a 3380)...
# 🚀 Lote 170/175 (Escenarios 3381 a 3400)...
# 🚀 Lote 171/175 (Escenarios 3401 a 3420)...
# 🚀 Lote 172/175 (Escenarios 3421 a 3440)...
# 🚀 Lote 173/175 (Escenarios 3441 a 3460)...
# 🚀 Lote 174/175 (Escenarios 3461 a 3480)...
# 🚀 Lote 175/175 (Escenarios 3481 a 3500)...
# ================================================================================
# ✅ COMPLETADO - 45500 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
#
# ================================================================================
# 📊 1. RANKING GLOBAL POR TAMAÑO TOTAL DE DATOS
# ================================================================================
#
# ======================================================================
# N_Total = 120
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.627935
# 2      LSPM                      1.082652
# 3      LSPMW                     1.085307
# 4      MCPS                      3.493251
# 5      AV-MCPS                   3.887096
#
# ======================================================================
# N_Total = 140
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.623796
# 2      LSPMW                     1.095530
# 3      LSPM                      1.096949
# 4      MCPS                      3.305760
# 5      AV-MCPS                   3.575881
#
# ======================================================================
# N_Total = 160
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.597881
# 2      LSPMW                     1.048824
# 3      LSPM                      1.050252
# 4      MCPS                      2.665541
# 5      AV-MCPS                   3.048872
#
# ======================================================================
# N_Total = 200
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.599290
# 2      LSPMW                     1.086196
# 3      LSPM                      1.090225
# 4      MCPS                      3.220087
# 5      AV-MCPS                   3.530867
#
# ======================================================================
# N_Total = 220
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.570032
# 2      LSPMW                     1.129244
# 3      LSPM                      1.131729
# 4      MCPS                      3.416857
# 5      DeepAR                    3.499243
#
# ======================================================================
# N_Total = 240
# ======================================================================
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.558211
# 2      LSPM                      1.074096
# 3      LSPMW                     1.077665
# 4      MCPS                      2.890951
# 5      AV-MCPS                   2.997357
#
# ...
# Block Bootstrapping       300             100             0.596628
# DeepAR                    300             100             0.546607
# EnCQR-LSTM                1000            100             0.815246
# LSPM                      300             100             0.619476
# LSPMW                     300             100             0.639554
# MCPS                      1000            60              0.566639
# Sieve Bootstrap           300             100             0.581507
#
# ================================================================================
# 💹 5. MEJORA MARGINAL AL INCREMENTAR DATOS
# ================================================================================
#
# --- Mejora al incrementar N_Train (N_Calib fijo) ---
#
# N_Calib = 20:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      +2.8%   -2.0%   -0.9%   +6.4%
# AV-MCPS                    +0.3%   +3.9%   +3.6%   +4.5%
# Block Bootstrapping        -0.4%   -0.4%   -0.1%   +3.4%
# DeepAR                     +3.8%   +0.7%   +2.6%   +4.9%
# EnCQR-LSTM                 +1.0%   -0.6%   -0.3%   +2.1%
# LSPM                       +1.4%   -3.2%   -0.7%   +4.9%
# LSPMW                      +1.4%   -4.3%   -0.7%   +5.8%
# MCPS                       -1.7%   +6.1%   +7.1%   +7.6%
# Sieve Bootstrap            +3.5%   +1.9%   +2.9%   +2.9%
#
# N_Calib = 40:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      -0.9%   -5.3%   +0.8%   -1.7%
# AV-MCPS                    -2.4%   +0.6%   +5.1%   -1.1%
# Block Bootstrapping        -1.5%   -4.4%   +1.4%   -4.2%
# DeepAR                     +0.2%   -0.5%   +4.1%   -1.3%
# EnCQR-LSTM                 +1.3%   -0.6%   +1.0%   -0.5%
# LSPM                       -1.6%   -6.2%   +3.9%   -3.6%
# LSPMW                      -1.6%   -6.1%   +4.5%   -4.0%
# MCPS                       -1.5%   +2.2%   +7.7%   +1.1%
# Sieve Bootstrap            +2.8%   -0.5%   +4.0%   -2.8%
#
# N_Calib = 60:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      +8.6%   -8.1%   +8.3%   -1.6%
# AV-MCPS                    +2.8%   -1.1%   +5.7%   +2.3%
# Block Bootstrapping        +7.3%   -6.7%   +4.0%   +3.5%
# DeepAR                     +8.3%   -3.2%   +6.0%   -0.1%
# EnCQR-LSTM                 +1.9%   -0.5%   +1.0%   +1.8%
# LSPM                       +5.0%   -6.0%   +5.1%   +2.4%
# LSPMW                      +4.5%   -6.1%   +6.5%   +1.4%
# MCPS                       +7.5%   +1.9%   +8.1%   +4.4%
# Sieve Bootstrap            +8.1%   -7.0%   +6.4%   +2.3%
#
# N_Calib = 100:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      +1.3%   +5.4%   -4.9%   +0.5%
# AV-MCPS                    +8.8%   +6.2%   -2.5%   +0.7%
# Block Bootstrapping        +2.7%   +5.9%   -4.1%   +1.4%
# DeepAR                     +5.1%   +9.0%   -1.9%   -0.5%
# EnCQR-LSTM                 +1.1%   +2.1%   -2.0%   +2.1%
# LSPM                       +2.0%   +6.8%   -3.8%   +2.2%
# LSPMW                      +1.2%   +6.4%   -4.7%   +3.0%
# MCPS                       +7.4%   +9.4%   -1.3%   +4.9%
# Sieve Bootstrap            +5.3%   +8.7%   -4.7%   +3.5%
#
# N_Calib = 200:
# Modelo                    100→200    200→300    300→500    500→1000
# ------------------------------------------------------------
# AREPD                      +0.3%   -1.4%   -3.0%   +1.3%
# AV-MCPS                    +1.7%   +1.1%   -3.7%   +4.3%
# Block Bootstrapping        +0.0%   +0.3%   -2.8%   +0.9%
# DeepAR                     +4.9%   -0.8%   -2.4%   +3.7%
# EnCQR-LSTM                 +1.3%   -0.8%   +0.3%   +0.9%
# LSPM                       +2.5%   -1.4%   -1.0%   +1.5%
# LSPMW                      +2.5%   -0.5%   -2.2%   +1.2%
# MCPS                       +5.6%   +1.8%   -1.1%   +5.1%
# Sieve Bootstrap            +3.1%   -0.7%   -2.9%   +1.2%
#
# ================================================================================
# 🎚️ 6. ANÁLISIS DE SATURACIÓN (¿Cuándo más datos no ayudan?)
# ================================================================================
#
# Criterio: Mejora < 2% al incrementar datos = SATURADO
#
#
# AREPD:
#   ✓ Saturado en N_Train ≥ 200 (N_Calib=20)
#
# AV-MCPS:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# Block Bootstrapping:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# DeepAR:
#   ✓ Saturado en N_Train ≥ 200 (N_Calib=20)
#
# EnCQR-LSTM:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# LSPM:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# LSPMW:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# MCPS:
#   ✓ Saturado en N_Train ≥ 100 (N_Calib=20)
#
# Sieve Bootstrap:
#   ✓ Saturado en N_Train ≥ 200 (N_Calib=20)
#
# ================================================================================
# 📋 7. RESUMEN EJECUTIVO
# ================================================================================
#
# ✅ MEJOR MODELO GLOBAL:
#    → DeepAR: CRPS = 0.584527
#
# ❌ PEOR MODELO GLOBAL:
#    → EnCQR-LSTM: CRPS = 0.840361
#
# 🎯 MEJOR TAMAÑO TOTAL DE DATOS:
#    → N_Total = 1060: CRPS promedio = 0.635060
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 30452.1s (8.46 horas)
#
# ================================================================================
# 📊 COMPARACIÓN FINAL: ARMA vs ARIMA vs SETAR
# ================================================================================
#
# ARMA:
#   AREPD                    : 0.934501
#   AV-MCPS                  : 0.676778
#   Block Bootstrapping      : 0.904895
#   DeepAR                   : 0.564987
#   EnCQR-LSTM               : 0.951517
#   LSPM                     : 0.768860
#   LSPMW                    : 0.793071
#   MCPS                     : 0.649636
#   Sieve Bootstrap          : 0.554115
#
# ARIMA:
#   AREPD                    : 13.048852
#   AV-MCPS                  : 3.504954
#   Block Bootstrapping      : 15.118309
#   DeepAR                   : 3.699832
#   EnCQR-LSTM               : 5.933017
#   LSPM                     : 1.086757
#   LSPMW                    : 1.087037
#   MCPS                     : 3.277991
#   Sieve Bootstrap          : 0.558294
#
# SETAR:
#   AREPD                    : 0.697065
#   AV-MCPS                  : 0.653128
#   Block Bootstrapping      : 0.631753
#   DeepAR                   : 0.584527
#   EnCQR-LSTM               : 0.840361
#   LSPM                     : 0.658552
#   LSPMW                    : 0.675374
#   MCPS                     : 0.632506
#   Sieve Bootstrap          : 0.625398
#
# ⏱  Tiempo total: 98894.9s (27.47 horas)
# {'ARMA':            Paso    Proceso Tipo_Proceso Distribución  Varianza  N_Train  \
#  0             1      AR(1)         ARMA       normal       0.2      100
#  1             2      AR(1)         ARMA       normal       0.2      100
#  2             3      AR(1)         ARMA       normal       0.2      100
#  3             4      AR(1)         ARMA       normal       0.2      100
#  4             5      AR(1)         ARMA       normal       0.2      100
#  ...         ...        ...          ...          ...       ...      ...
#  45495         9  ARMA(2,1)         ARMA      mixture       3.0     1000
#  45496        10  ARMA(2,1)         ARMA      mixture       3.0     1000
#  45497        11  ARMA(2,1)         ARMA      mixture       3.0     1000
#  45498        12  ARMA(2,1)         ARMA      mixture       3.0     1000
#  45499  Promedio  ARMA(2,1)         ARMA      mixture       3.0     1000
#
#         N_Calib  N_Total  Valor_Observado  Block Bootstrapping  \
#  0           20      120        -0.222529             0.193766
#  1           20      120        -0.000786             0.255115
#  2           20      120        -0.204182             0.185688
#  3           20      120        -0.731872             0.217091
#  4           20      120        -1.230196             0.493398
#  ...        ...      ...              ...                  ...
#  45495      200     1200        -1.556589             1.521404
#  45496      200     1200        -2.677895             1.673862
#  45497      200     1200        -3.614630             2.287898
#  45498      200     1200        -4.238544             2.561506
#  45499      200     1200              NaN             1.767352
#
#         Sieve Bootstrap      LSPM     LSPMW    DeepAR     AREPD      MCPS  \