# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_test_tamanos_reducido

main_test_tamanos_reducido()
# Out:
# ================================================================================
# TEST REDUCIDO - TAMAÑOS CRECIENTES (TODOS LOS PROCESOS)
# ================================================================================
#
# ============================================================
# EJECUTANDO ARMA...
# ============================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO ARMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
#
# 📊 CONFIGURACIÓN:
#   • Combinaciones de tamaños: 3
#     1. N_Train=100, N_Calib=20
#     2. N_Train=500, N_Calib=100
#     3. N_Train=1000, N_Calib=200
#   • Configuraciones ARMA: 2
#   • Distribuciones: 1
#   • Varianzas: 1
#   • ESCENARIOS BASE TOTALES: 6
#   • FILAS ESPERADAS: ~78
# ================================================================================
#
#
# 🚀 Lote 1/2 (Escenarios 1 a 4)...
# 🚀 Lote 2/2 (Escenarios 5 a 6)...
# ================================================================================
# ✅ COMPLETADO - 0 filas generadas
# ================================================================================
#
# ============================================================
# EJECUTANDO ARIMA...
# ============================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO ARIMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
#
# 📊 CONFIGURACIÓN:
#   • Combinaciones de tamaños: 3
#     1. N_Train=100, N_Calib=20
#     2. N_Train=500, N_Calib=100
#     3. N_Train=1000, N_Calib=200
#   • Configuraciones ARIMA: 2
#   • Distribuciones: 1
#   • Varianzas: 1
#   • ESCENARIOS BASE TOTALES: 6
#   • FILAS ESPERADAS: ~78
# ================================================================================
#
#
# 🚀 Lote 1/2 (Escenarios 1 a 4)...
# 🚀 Lote 2/2 (Escenarios 5 a 6)...
# ================================================================================
# ✅ COMPLETADO - 0 filas generadas
# ================================================================================
#
# ============================================================
# EJECUTANDO SETAR...
# ============================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO SETAR
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
#
# 📊 CONFIGURACIÓN:
#   • Combinaciones de tamaños: 3
#     1. N_Train=100, N_Calib=20
#     2. N_Train=500, N_Calib=100
#     3. N_Train=1000, N_Calib=200
#   • Configuraciones SETAR: 2
#   • Distribuciones: 1
#   • Varianzas: 1
#   • ESCENARIOS BASE TOTALES: 6
#   • FILAS ESPERADAS: ~78
# ================================================================================
#
#
# 🚀 Lote 1/2 (Escenarios 1 a 4)...
# 🚀 Lote 2/2 (Escenarios 5 a 6)...
# ================================================================================
# ✅ COMPLETADO - 0 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS COMPARATIVO DE LOS TRES PROCESOS
# ================================================================================
#
# ============================================================
# PROCESO: ARMA
# ============================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
# ⚠️ No hay datos suficientes para el análisis.
#
# ============================================================
# PROCESO: ARIMA
# ============================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
# ⚠️ No hay datos suficientes para el análisis.
#
# ============================================================
# PROCESO: SETAR
# ============================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
# ⚠️ No hay datos suficientes para el análisis.
#
# ⏱  Tiempo total: 1361.9s
# {'ARMA': Empty DataFrame
#  Columns: []
#  Index: [],
#  'ARIMA': Empty DataFrame
#  Columns: []
#  Index: [],
#  'SETAR': Empty DataFrame
#  Columns: []
#  Index: []}

# %%
from runner import main_comparacion_todos_procesos

main_comparacion_todos_procesos()
# Out:
# ================================================================================
# ANÁLISIS COMPARATIVO COMPLETO - ARMA vs ARIMA vs SETAR
# ================================================================================
# ================================================================================
# ANÁLISIS TAMAÑOS CRECIENTES - PROCESOS ARMA
# ================================================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO ARMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 20
#
# 📊 CONFIGURACIÓN:
#   • Combinaciones de tamaños: 3
#     1. N_Train=100, N_Calib=20
#     2. N_Train=500, N_Calib=100
#     3. N_Train=1000, N_Calib=200
#   • Configuraciones ARMA: 7
#   • Distribuciones: 5
#   • Varianzas: 4
#   • ESCENARIOS BASE TOTALES: 420
#   • FILAS ESPERADAS: ~5460
# ================================================================================
#
#
# 🚀 Lote 1/21 (Escenarios 1 a 20)...
# 🚀 Lote 2/21 (Escenarios 21 a 40)...
# 🚀 Lote 3/21 (Escenarios 41 a 60)...
# 🚀 Lote 4/21 (Escenarios 61 a 80)...
# 🚀 Lote 5/21 (Escenarios 81 a 100)...
# 🚀 Lote 6/21 (Escenarios 101 a 120)...
# 🚀 Lote 7/21 (Escenarios 121 a 140)...
# 🚀 Lote 8/21 (Escenarios 141 a 160)...
# 🚀 Lote 9/21 (Escenarios 161 a 180)...
# 🚀 Lote 10/21 (Escenarios 181 a 200)...
# 🚀 Lote 11/21 (Escenarios 201 a 220)...
# 🚀 Lote 12/21 (Escenarios 221 a 240)...
# 🚀 Lote 13/21 (Escenarios 241 a 260)...
# 🚀 Lote 14/21 (Escenarios 261 a 280)...
# 🚀 Lote 15/21 (Escenarios 281 a 300)...
# 🚀 Lote 16/21 (Escenarios 301 a 320)...
# 🚀 Lote 17/21 (Escenarios 321 a 340)...
# 🚀 Lote 18/21 (Escenarios 341 a 360)...
# 🚀 Lote 19/21 (Escenarios 361 a 380)...
# 🚀 Lote 20/21 (Escenarios 381 a 400)...
# 🚀 Lote 21/21 (Escenarios 401 a 420)...
# ================================================================================
# ✅ COMPLETADO - 0 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
# ⚠️ No hay datos suficientes para el análisis.
#
# ⏱  Tiempo total: 19005.9s (5.28 horas)
# ================================================================================
# ANÁLISIS TAMAÑOS CRECIENTES - PROCESOS ARIMA
# ================================================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO ARIMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 20
#
# 📊 CONFIGURACIÓN:
#   • Combinaciones de tamaños: 3
#     1. N_Train=100, N_Calib=20
#     2. N_Train=500, N_Calib=100
#     3. N_Train=1000, N_Calib=200
#   • Configuraciones ARIMA: 7
#   • Distribuciones: 5
#   • Varianzas: 4
#   • ESCENARIOS BASE TOTALES: 420
#   • FILAS ESPERADAS: ~5460
# ================================================================================
#
#
# 🚀 Lote 1/21 (Escenarios 1 a 20)...
# 🚀 Lote 2/21 (Escenarios 21 a 40)...
# 🚀 Lote 3/21 (Escenarios 41 a 60)...
# 🚀 Lote 4/21 (Escenarios 61 a 80)...
# 🚀 Lote 5/21 (Escenarios 81 a 100)...
# 🚀 Lote 6/21 (Escenarios 101 a 120)...
# 🚀 Lote 7/21 (Escenarios 121 a 140)...
# 🚀 Lote 8/21 (Escenarios 141 a 160)...
# 🚀 Lote 9/21 (Escenarios 161 a 180)...
# 🚀 Lote 10/21 (Escenarios 181 a 200)...
# 🚀 Lote 11/21 (Escenarios 201 a 220)...
# 🚀 Lote 12/21 (Escenarios 221 a 240)...
# 🚀 Lote 13/21 (Escenarios 241 a 260)...
# 🚀 Lote 14/21 (Escenarios 261 a 280)...
# 🚀 Lote 15/21 (Escenarios 281 a 300)...
# 🚀 Lote 16/21 (Escenarios 301 a 320)...
# 🚀 Lote 17/21 (Escenarios 321 a 340)...
# 🚀 Lote 18/21 (Escenarios 341 a 360)...
# 🚀 Lote 19/21 (Escenarios 361 a 380)...
# 🚀 Lote 20/21 (Escenarios 381 a 400)...
# 🚀 Lote 21/21 (Escenarios 401 a 420)...
# ================================================================================
# ✅ COMPLETADO - 0 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
# ⚠️ No hay datos suficientes para el análisis.
#
# ⏱  Tiempo total: 28867.0s (8.02 horas)
# ================================================================================
# ANÁLISIS TAMAÑOS CRECIENTES - PROCESOS SETAR
# ================================================================================
# ================================================================================
# EVALUACIÓN TAMAÑOS CRECIENTES - PROCESO SETAR
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 20
#
# 📊 CONFIGURACIÓN:
#   • Combinaciones de tamaños: 3
#     1. N_Train=100, N_Calib=20
#     2. N_Train=500, N_Calib=100
#     3. N_Train=1000, N_Calib=200
#   • Configuraciones SETAR: 7
#   • Distribuciones: 5
#   • Varianzas: 4
#   • ESCENARIOS BASE TOTALES: 420
#   • FILAS ESPERADAS: ~5460
# ================================================================================
#
#
# 🚀 Lote 1/21 (Escenarios 1 a 20)...
# 🚀 Lote 2/21 (Escenarios 21 a 40)...
# 🚀 Lote 3/21 (Escenarios 41 a 60)...
# 🚀 Lote 4/21 (Escenarios 61 a 80)...
# 🚀 Lote 5/21 (Escenarios 81 a 100)...
# 🚀 Lote 6/21 (Escenarios 101 a 120)...
# 🚀 Lote 7/21 (Escenarios 121 a 140)...
# 🚀 Lote 8/21 (Escenarios 141 a 160)...
# 🚀 Lote 9/21 (Escenarios 161 a 180)...
# 🚀 Lote 10/21 (Escenarios 181 a 200)...
# 🚀 Lote 11/21 (Escenarios 201 a 220)...
# 🚀 Lote 12/21 (Escenarios 221 a 240)...
# 🚀 Lote 13/21 (Escenarios 241 a 260)...
# 🚀 Lote 14/21 (Escenarios 261 a 280)...
# 🚀 Lote 15/21 (Escenarios 281 a 300)...
# 🚀 Lote 16/21 (Escenarios 301 a 320)...
# 🚀 Lote 17/21 (Escenarios 321 a 340)...
# 🚀 Lote 18/21 (Escenarios 341 a 360)...
# 🚀 Lote 19/21 (Escenarios 361 a 380)...
# 🚀 Lote 20/21 (Escenarios 381 a 400)...
# 🚀 Lote 21/21 (Escenarios 401 a 420)...
# ================================================================================
# ✅ COMPLETADO - 0 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - TAMAÑOS CRECIENTES DE DATOS
# ================================================================================
# ⚠️ No hay datos suficientes para el análisis.
#
# ⏱  Tiempo total: 24363.5s (6.77 horas)
#
# ================================================================================
# 📊 COMPARACIÓN FINAL: ARMA vs ARIMA vs SETAR
# ================================================================================
#
# ARMA:
#
# ARIMA:
#
# SETAR:
#
# ⏱  Tiempo total: 72236.5s (20.07 horas)
# {'ARMA': Empty DataFrame
#  Columns: []
#  Index: [],
#  'ARIMA': Empty DataFrame
#  Columns: []
#  Index: [],
#  'SETAR': Empty DataFrame
#  Columns: []
#  Index: []}
