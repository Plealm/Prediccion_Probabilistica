# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_two_scenarios

main_two_scenarios()  # Descomenta para correr solo 2 escenarios
# Out:
# ================================================================================
# EVALUACIÓN CON SOLO 2 ESCENARIOS
# ================================================================================
# 🚀 Ejecutando 2 escenarios en lotes de 2...
#   -> Procesando lote 1...
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media CRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.578911
# 2      DeepAR                    0.587845
# 3      Block Bootstrapping       0.761356
# 4      MCPS                      0.768237
# 5      AV-MCPS                   0.799197
# 6      LSPMW                     0.871216
# 7      LSPM                      0.902493
# 8      AREPD                     0.941143
# 9      EnCQR-LSTM                1.303369
#
# 🎯 2. VICTORIAS (Mejor modelo por paso)
# --------------------------------------------------------------------------------
#   Sieve Bootstrap          :  12 victorias (50.0%)
#   DeepAR                   :   9 victorias (37.5%)
#   LSPM                     :   3 victorias (12.5%)
#   AREPD                    :   0 victorias (0.0%)
#   AV-MCPS                  :   0 victorias (0.0%)
#   Block Bootstrapping      :   0 victorias (0.0%)
#   EnCQR-LSTM               :   0 victorias (0.0%)
#   LSPMW                    :   0 victorias (0.0%)
#   MCPS                     :   0 victorias (0.0%)
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 166.0s
#     Paso Config    Dist  Var  Block Bootstrapping  Sieve Bootstrap      LSPM  \
# 0      1  AR(1)  normal  1.0             0.830261         0.570148  0.615483
# 1      2  AR(1)  normal  1.0             0.942134         0.600821  1.720662
# 2      3  AR(1)  normal  1.0             0.764170         0.568473  0.743473
# 3      4  AR(1)  normal  1.0             0.700135         0.580120  0.559236
# 4      5  AR(1)  normal  1.0             0.694295         0.571627  0.581667
# 5      6  AR(1)  normal  1.0             0.998034         0.586215  1.294981
# 6      7  AR(1)  normal  1.0             0.737450         0.604011  1.693066
# 7      8  AR(1)  normal  1.0             0.856492         0.555639  0.562725
# 8      9  AR(1)  normal  1.0             0.706511         0.632110  0.718202
# 9     10  AR(1)  normal  1.0             1.337945         0.587884  1.323585
# 10    11  AR(1)  normal  1.0             0.670467         0.583701  1.299661
# 11    12  AR(1)  normal  1.0             0.655595         0.568932  0.556708
# 12     1  MA(1)  normal  1.0             0.568021         0.565283  0.571040
# 13     2  MA(1)  normal  1.0             0.875993         0.592574  0.887703
# 14     3  MA(1)  normal  1.0             0.558304         0.557434  0.705938
# 15     4  MA(1)  normal  1.0             0.769890         0.583486  0.683741
# 16     5  MA(1)  normal  1.0             0.584464         0.557693  0.786229
# 17     6  MA(1)  normal  1.0             1.135863         0.587344  1.003914
# 18     7  MA(1)  normal  1.0             0.578647         0.567989  1.354605
# 19     8  MA(1)  normal  1.0             0.657971         0.574624  0.697595
# 20     9  MA(1)  normal  1.0             0.639960         0.564423  0.558780
# 21    10  MA(1)  normal  1.0             0.783364         0.572408  1.037359
# 22    11  MA(1)  normal  1.0             0.623939         0.582536  0.931511
# 23    12  MA(1)  normal  1.0             0.602629         0.578393  0.771960
#
#        LSPMW     AREPD      MCPS   AV-MCPS    DeepAR  EnCQR-LSTM
# 0   0.601019  0.586328  1.254883  1.722303  0.580896    2.409175
# 1   1.414044  1.641201  0.704902  0.608099  0.583819    1.508230
# 2   1.033924  1.212516  0.604279  0.597057  0.566868    1.295705
# 3   0.958184  1.120519  0.636892  0.597250  0.566629    1.380266
# 4   0.735580  0.849718  0.623059  0.624098  0.595886    1.706942
# 5   0.748423  0.675762  0.812613  1.430179  0.600758    2.813851
# 6   0.953507  1.111212  0.634933  0.589029  0.576328    1.490578
# 7   1.313652  1.515295  0.582345  0.648255  0.561478    1.078415
# 8   0.874625  1.011034  0.701710  1.521734  0.605334    1.468615
# 9   1.908526  2.140884  1.230323  0.793579  0.576938    0.822981
# 10  0.779132  0.889939  0.635170  0.639949  0.621222    1.561760
# 11  0.628537  0.704325  0.632514  0.595954  0.584456    1.937908
# 12  0.606156  0.600125  0.754377  0.596628  0.565157    0.937476
# 13  1.103866  1.050261  0.821947  0.968543  0.580084    1.021228
# 14  0.599162  0.595947  0.606936  0.610468  0.567423    0.910370
# 15  0.909767  0.859634  0.677663  0.624837  0.574457    0.927521
# 16  0.564747  0.593148  0.604479  0.685213  0.568261    0.927839
# 17  1.053156  1.234396  0.781803  0.776716  0.660770    1.287409
# 18  0.649542  0.624585  0.894378  0.762322  0.648102    0.924489
# 19  0.613501  0.677850  0.665840  0.711985  0.584620    1.002673
# 20  0.605250  0.669729  0.602069  0.660413  0.566504    0.991895
# 21  0.959385  0.907216  1.250636  1.123061  0.594938    0.947320
# 22  0.599953  0.646824  0.724956  0.603075  0.582054    0.994832
# 23  0.695540  0.668992  0.998987  0.689988  0.595304    0.933385

# %%
from runner import main_full_140

main_full_140()  #
# Out:
# ================================================================================
# INICIANDO SIMULACIÓN DE 140 ESCENARIOS
# ================================================================================
# 🚀 Ejecutando 140 escenarios en lotes de 10...
#   -> Procesando lote 1...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from runner import main_full_140
# ----> 3 main_full_140()  #
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base\runner.py:92, in main_full_140()
#      84 print("="*80)
#      86 pipeline = Pipeline140SinSesgos_ARMA(
#      87     n_boot=1000,
#      88     seed=42,
#      89     verbose=False
#      90 )
# ---> 92 df_final = pipeline.run_all(
#      93     excel_filename="resultados_140_FINAL_FIXED.xlsx",
#      94     batch_size=10
#      95 )
#      97 run_analysis(df_final)
#      99 elapsed = time.time() - start_time
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base\pipeline.py:152, in Pipeline140SinSesgos_ARMA.run_all(self, excel_filename, batch_size, n_jobs)
#     150 batch = tasks[i:i + batch_size]
#     151 print(f"  -> Procesando lote {i//batch_size + 1}...")
# --> 152 results = Parallel(n_jobs=n_jobs)(delayed(self._run_scenario_wrapper)(t) for t in batch)
#     153 for r in results:
#     154     all_results.extend(r)
#
# File c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:
