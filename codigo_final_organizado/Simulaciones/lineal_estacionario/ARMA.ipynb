# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
#from runner import main_two_scenarios

#main_two_scenarios()  # Descomenta para correr solo 2 escenarios

# %%
from runner import main_full_140

main_full_140()  #
# Out:
# ================================================================================
# INICIANDO SIMULACIÓN DE 140 ESCENARIOS
# ================================================================================
# ================================================================================
# EVALUACIÓN 140 ESCENARIOS - DISTRIBUCIÓN VERDADERA PARA OPTIMIZACIÓN
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 10
# ⚡ Método de optimización: Distribución Verdadera del Simulador
# ================================================================================
#
#
# 🚀 Lote 1/14 (Escenarios 1 a 10)...
# 🚀 Lote 2/14 (Escenarios 11 a 20)...
# 🚀 Lote 3/14 (Escenarios 21 a 30)...
# 🚀 Lote 4/14 (Escenarios 31 a 40)...
# 🚀 Lote 5/14 (Escenarios 41 a 50)...
# 🚀 Lote 6/14 (Escenarios 51 a 60)...
# 🚀 Lote 7/14 (Escenarios 61 a 70)...
# 🚀 Lote 8/14 (Escenarios 71 a 80)...
# 🚀 Lote 9/14 (Escenarios 81 a 90)...
# 🚀 Lote 10/14 (Escenarios 91 a 100)...
# 🚀 Lote 11/14 (Escenarios 101 a 110)...
# 🚀 Lote 12/14 (Escenarios 111 a 120)...
# 🚀 Lote 13/14 (Escenarios 121 a 130)...
# 🚀 Lote 14/14 (Escenarios 131 a 140)...
# ================================================================================
# ✅ COMPLETADO - 1540 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media CRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.539827
# 2      DeepAR                    0.546891
# 3      MCPS                      0.652429
# 4      AV-MCPS                   0.658105
# 5      LSPM                      0.746126
# 6      LSPMW                     0.763641
# 7      AREPD                     0.785948
# 8      Block Bootstrapping       0.861888
# 9      EnCQR-LSTM                1.023438
#
# 🎯 2. VICTORIAS (Mejor modelo por paso)
# --------------------------------------------------------------------------------
#   Sieve Bootstrap          : 299 victorias (21.4%)
#   DeepAR                   : 248 victorias (17.7%)
#   AREPD                    : 241 victorias (17.2%)
#   MCPS                     : 168 victorias (12.0%)
#   AV-MCPS                  : 164 victorias (11.7%)
#   LSPMW                    : 103 victorias (7.4%)
#   LSPM                     : 102 victorias (7.3%)
#   Block Bootstrapping      :  45 victorias (3.2%)
#   EnCQR-LSTM               :  30 victorias (2.1%)
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 3407.9s (0.95 horas)
#           Paso proces_simulacion Distribución  Varianza error  \
# 0            1             AR(1)       normal             0.2
# 1            2             AR(1)       normal             0.2
# 2            3             AR(1)       normal             0.2
# 3            4             AR(1)       normal             0.2
# 4            5             AR(1)       normal             0.2
# ...        ...               ...          ...             ...
# 1535         7         ARMA(2,1)      mixture             3.0
# 1536         8         ARMA(2,1)      mixture             3.0
# 1537         9         ARMA(2,1)      mixture             3.0
# 1538        10         ARMA(2,1)      mixture             3.0
# 1539  Promedio         ARMA(2,1)      mixture             3.0
#
#       Valor_Observado  Block Bootstrapping  Sieve Bootstrap      LSPM  \
# 0           -0.196414             0.184607         0.111285  0.101914
# 1           -0.108544             0.182881         0.125167  0.095749
# 2            0.560381             0.481642         0.484060  0.551660
# 3           -0.643501             0.299151         1.008342  0.317284
# 4           -0.685074             0.300597         0.112814  1.011933
# ...               ...                  ...              ...       ...
# 1535        -5.775071             4.534897         0.552934  1.292189
# 1536        -5.878083             4.409144         0.410020  1.029794
# 1537        -5.681104             4.423626         0.417529  0.435454
# 1538        -6.819559             5.280659         1.062079  0.809908
# 1539              NaN             3.418296         0.664986  1.161835
#
#          LSPMW    DeepAR     AREPD      MCPS   AV-MCPS  EnCQR-LSTM
# 0     0.106750  0.091808  0.113046  0.089052  0.105043    0.538048
# 1     0.091835  0.092555  0.091532  0.082703  0.170650    0.542241
# 2     0.531355  0.448963  0.437581  0.234233  0.405858    0.614895
# 3     0.337509  1.090218  0.443313  0.857316  1.302441    0.500295
# 4     1.032535  0.067247  0.439101  0.101435  0.175817    0.507093
# ...        ...       ...       ...       ...       ...         ...
# 1535  1.103186  1.131369  3.554248  1.175397  1.129253    1.848647
# 1536  0.891111  0.421298  3.546839  0.461378  0.552844    1.745644
# 1537  0.465581  0.380840  3.393144  0.460011  0.543637    1.835105
# 1538  0.657795  0.769367  4.337682  0.895880  1.024863    1.934877
# 1539  1.105832  0.700652  2.611124  0.691457  0.786282    1.970114
#
# [1540 rows x 14 columns]
