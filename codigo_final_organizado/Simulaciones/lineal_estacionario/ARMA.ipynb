# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
# main.py
import os
os.makedirs("resultados", exist_ok=True)

from pipeline import ejecutar_experimento_completo

resultados, serie, particiones, simulator = ejecutar_experimento_completo()
# Out:
# ================================================================================
# EVALUACIÓN RIGUROSA DE MÉTODOS BOOTSTRAP (VERSIÓN OPTIMIZADA)
# Protocolo sin sesgos para desarrollo de tesis
# ================================================================================
#
# 📊 Proceso Generador de Datos (DGP):
#    Modelo: ARMA(1,1)
#    φ = [0.7], θ = [0.5]
#    Ruido: N(0, 1.0²)
#
# 📈 Generando serie temporal...
#
# ✂️  Particiones (NO superpuestas):
#    Train:      índices   0 - 400  (n=400)
#    Validation: índices 400 - 450  (n=50)
#    Test:       índices 450 - 505  (n=55)
#
# ================================================================================
# 🔄 MÉTODO 1: CIRCULAR BLOCK BOOTSTRAP
# ================================================================================
#
# 🔍 Fase 1: Selección de hiperparámetros (Expanding Window Validation)
#    Grid: block_length = [5, 10, 15, 20, 30]
#
# ✅ Mejores hiperparámetros encontrados:
#    block_length = 10
#    CRPS validación = 0.791223
#
# 🎯 Fase 2: Evaluación final en Test Set
#    Comparación contra distribución teórica...
#
# 📊 Resultados CBB en Test:
#    ECRPS: 1.309434 ± 0.696159
#    CRPS:  1.433940 ± 0.949340
#    N predicciones: 55
#    ⏱️  Tiempo: 12.23s
#
# ================================================================================
# 📐 MÉTODO 2: SIEVE BOOTSTRAP
# ================================================================================
#
# 🔍 Fase 1: Selección de hiperparámetros (Expanding Window Validation)
#    Grid: order = [1, 2, 3, 4, 5, 6, 8]
#
# ✅ Mejores hiperparámetros encontrados:
#    order = 1
#    CRPS validación = 0.596590
#
# 🎯 Fase 2: Evaluación final en Test Set
#    Comparación contra distribución teórica...
#
# 📊 Resultados Sieve en Test:
#    ECRPS: 0.616521 ± 0.063566
#    CRPS:  0.648440 ± 0.444679
#    N predicciones: 55
#    ⏱️  Tiempo: 13.44s
#
# ================================================================================
# 🏆 COMPARACIÓN FINAL (Test Set)
# ================================================================================
#
# Método               ECRPS (↓)            CRPS (↓)             Tiempo          Hiperparámetros
# ----------------------------------------------------------------------------------------------------
# CBB                  1.309434 ± 0.6962    1.433940 ± 0.9493    12.23s          {'block_length': 10}
# Sieve                0.616521 ± 0.0636    0.648440 ± 0.4447    13.44s          {'order': 1}
#
# 🥇 Ganador: Sieve
#    Mejora: 52.92% en ECRPS respecto al otro método
#
# ⏱️  Tiempo total de ejecución: 25.67s
#
# ================================================================================
# ✓ EVALUACIÓN COMPLETA - PROTOCOLO RIGUROSO CUMPLIDO
# ================================================================================
#
# 📌 Garantías metodológicas:
#    ✓ Separación estricta train/validation/test
#    ✓ Sin mirada al futuro en validación (expanding window)
#    ✓ Comparación contra distribución teórica (ground truth)
#    ✓ Mismos datos para ambos métodos
#    ✓ Hiperparámetros optimizados independientemente
#    ✓ Resultados completamente reproducibles (seed fija)
#
# 🚀 Optimizaciones aplicadas:
#    ✓ Vectorización de métricas CRPS/ECRPS
#    ✓ Bootstrap vectorizado en Sieve
#    ✓ Submuestreo inteligente en validación
#    ✓ Reducción de muestras teóricas sin pérdida de precisión
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 os.makedirs("resultados", exist_ok=True)
#       5 from pipeline import ejecutar_experimento_completo
# ----> 7 resultados, serie, particiones, simulator = ejecutar_experimento_completo()
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base\pipeline.py:636, in ejecutar_experimento_completo()
#     633 print("   ✓ Submuestreo inteligente en validación")
#     634 print("   ✓ Reducción de muestras teóricas sin pérdida de precisión")
# --> 636 return resultados_finales, serie, particiones, simulator
#
# NameError: name 'serie' is not defined
