# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_test_proporciones_240_reducido

main_test_proporciones_240_reducido()
# Out:
# ================================================================================
# TEST REDUCIDO - PROPORCIONES 240 (TODOS LOS PROCESOS)
# ================================================================================
#
# ============================================================
# EJECUTANDO ARMA...
# ============================================================
# 🚀 Iniciando Pipeline Proporciones (ARMA): 4 escenarios.
# 📦 Procesando Lote 1/1...
#
# ============================================================
# EJECUTANDO ARIMA...
# ============================================================
# 🚀 Iniciando Pipeline Proporciones (ARIMA): 4 escenarios.
# 📦 Procesando Lote 1/1...
#
# ============================================================
# EJECUTANDO SETAR...
# ============================================================
# 🚀 Iniciando Pipeline Proporciones (SETAR): 4 escenarios.
# 📦 Procesando Lote 1/1...
#
# ================================================================================
# ANÁLISIS COMPARATIVO DE LOS TRES PROCESOS
# ================================================================================
#
# ============================================================
# PROCESO: ARMA
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 52
#   • Escenarios únicos: 4
#   • Proporciones evaluadas: ['10%', '30%']
#   • Procesos: ['AR(1)', 'AR(2)']
#   • Distribuciones: ['normal']
#   • Varianzas: [np.float64(1.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.9182 ± 0.2876
#    AV-MCPS                  : 0.7544 ± 0.1614
#    Block Bootstrapping      : 0.7322 ± 0.1305
#    DeepAR                   : 0.5979 ± 0.0139
#    EnCQR-LSTM               : 1.0671 ± 0.3371
#    LSPM                     : 0.8387 ± 0.1891
#    LSPMW                    : 0.8254 ± 0.2410
#    MCPS                     : 0.7181 ± 0.0407
#    Sieve Bootstrap          : 0.6130 ± 0.0549
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 1.5452 ± 1.2030
#    AV-MCPS                  : 0.8660 ± 0.2317
#    Block Bootstrapping      : 1.3691 ± 1.0029
#    DeepAR                   : 0.5928 ± 0.0057
#    EnCQR-LSTM               : 1.3310 ± 0.7246
#    LSPM                     : 0.7685 ± 0.0711
#    LSPMW                    : 1.3183 ± 0.8664
#    MCPS                     : 0.8050 ± 0.0647
#    Sieve Bootstrap          : 0.5746 ± 0.0067
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. DeepAR                   : 0.5979
#    2. Sieve Bootstrap          : 0.6130
#    3. MCPS                     : 0.7181
#    4. Block Bootstrapping      : 0.7322
#    5. AV-MCPS                  : 0.7544
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5746
#    2. DeepAR                   : 0.5928
#    3. LSPM                     : 0.7685
#    4. MCPS                     : 0.8050
#    5. AV-MCPS                  : 0.8660
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+68.3%)
#    AV-MCPS                  : 📉 EMPEORA (+14.8%)
#    Block Bootstrapping      : 📉 EMPEORA (+87.0%)
#    DeepAR                   : 📈 MEJORA (-0.9%)
#    EnCQR-LSTM               : 📉 EMPEORA (+24.7%)
#    LSPM                     : 📈 MEJORA (-8.4%)
#    LSPMW                    : 📉 EMPEORA (+59.7%)
#    MCPS                     : 📉 EMPEORA (+12.1%)
#    Sieve Bootstrap          : 📈 MEJORA (-6.3%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 10% (CRPS=0.9182)
#    AV-MCPS                  : 10% (CRPS=0.7544)
#    Block Bootstrapping      : 10% (CRPS=0.7322)
#    DeepAR                   : 30% (CRPS=0.5928)
#    EnCQR-LSTM               : 10% (CRPS=1.0671)
#    LSPM                     : 30% (CRPS=0.7685)
#    LSPMW                    : 10% (CRPS=0.8254)
#    MCPS                     : 10% (CRPS=0.7181)
#    Sieve Bootstrap          : 30% (CRPS=0.5746)
#
# ============================================================
# PROCESO: ARIMA
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 52
#   • Escenarios únicos: 4
#   • Proporciones evaluadas: ['10%', '30%']
#   • Procesos: ['ARIMA(0,1,0)', 'ARIMA(1,1,0)']
#   • Distribuciones: ['normal']
#   • Varianzas: [np.float64(1.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 12.3357 ± 15.1236
#    AV-MCPS                  : 4.0934 ± 4.0003
#    Block Bootstrapping      : 13.3032 ± 16.1207
#    DeepAR                   : 5.9280 ± 7.4660
#    EnCQR-LSTM               : 6.0248 ± 6.0491
#    LSPM                     : 1.0828 ± 0.1074
#    LSPMW                    : 1.7003 ± 0.7857
#    MCPS                     : 4.6764 ± 5.1642
#    Sieve Bootstrap          : 0.5967 ± 0.0317
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 2.0584 ± 0.2947
#    AV-MCPS                  : 0.8972 ± 0.0647
#    Block Bootstrapping      : 2.3275 ± 0.9719
#    DeepAR                   : 0.5902 ± 0.0077
#    EnCQR-LSTM               : 3.8044 ± 2.3521
#    LSPM                     : 1.1438 ± 0.3934
#    LSPMW                    : 3.1811 ± 1.0094
#    MCPS                     : 0.7794 ± 0.0413
#    Sieve Bootstrap          : 0.5745 ± 0.0067
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.5967
#    2. LSPM                     : 1.0828
#    3. LSPMW                    : 1.7003
#    4. AV-MCPS                  : 4.0934
#    5. MCPS                     : 4.6764
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5745
#    2. DeepAR                   : 0.5902
#    3. MCPS                     : 0.7794
#    4. AV-MCPS                  : 0.8972
#    5. LSPM                     : 1.1438
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📈 MEJORA (-83.3%)
#    AV-MCPS                  : 📈 MEJORA (-78.1%)
#    Block Bootstrapping      : 📈 MEJORA (-82.5%)
#    DeepAR                   : 📈 MEJORA (-90.0%)
#    EnCQR-LSTM               : 📈 MEJORA (-36.9%)
#    LSPM                     : 📉 EMPEORA (+5.6%)
#    LSPMW                    : 📉 EMPEORA (+87.1%)
#    MCPS                     : 📈 MEJORA (-83.3%)
#    Sieve Bootstrap          : 📈 MEJORA (-3.7%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 30% (CRPS=2.0584)
#    AV-MCPS                  : 30% (CRPS=0.8972)
#    Block Bootstrapping      : 30% (CRPS=2.3275)
#    DeepAR                   : 30% (CRPS=0.5902)
#    EnCQR-LSTM               : 30% (CRPS=3.8044)
#    LSPM                     : 10% (CRPS=1.0828)
#    LSPMW                    : 10% (CRPS=1.7003)
#    MCPS                     : 30% (CRPS=0.7794)
#    Sieve Bootstrap          : 30% (CRPS=0.5745)
#
# ============================================================
# PROCESO: SETAR
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 52
#   • Escenarios únicos: 4
#   • Proporciones evaluadas: ['10%', '30%']
#   • Procesos: ['SETAR-1', 'SETAR-2']
#   • Distribuciones: ['normal']
#   • Varianzas: [np.float64(1.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.8806 ± 0.2962
#    AV-MCPS                  : 0.7585 ± 0.0431
#    Block Bootstrapping      : 0.8442 ± 0.2666
#    DeepAR                   : 0.6635 ± 0.0567
#    EnCQR-LSTM               : 1.0146 ± 0.2202
#    LSPM                     : 1.0077 ± 0.3875
#    LSPMW                    : 0.8910 ± 0.1854
#    MCPS                     : 0.7965 ± 0.0069
#    Sieve Bootstrap          : 0.6837 ± 0.1121
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.6822 ± 0.0431
#    AV-MCPS                  : 0.8316 ± 0.1765
#    Block Bootstrapping      : 0.6866 ± 0.0740
#    DeepAR                   : 0.6375 ± 0.0351
#    EnCQR-LSTM               : 0.9916 ± 0.1262
#    LSPM                     : 0.7087 ± 0.0998
#    LSPMW                    : 0.7788 ± 0.1657
#    MCPS                     : 0.7309 ± 0.0689
#    Sieve Bootstrap          : 0.7055 ± 0.0732
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. DeepAR                   : 0.6635
#    2. Sieve Bootstrap          : 0.6837
#    3. AV-MCPS                  : 0.7585
#    4. MCPS                     : 0.7965
#    5. Block Bootstrapping      : 0.8442
#
# 🏆 Proporción: 30%
#    1. DeepAR                   : 0.6375
#    2. AREPD                    : 0.6822
#    3. Block Bootstrapping      : 0.6866
#    4. Sieve Bootstrap          : 0.7055
#    5. LSPM                     : 0.7087
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📈 MEJORA (-22.5%)
#    AV-MCPS                  : 📉 EMPEORA (+9.6%)
#    Block Bootstrapping      : 📈 MEJORA (-18.7%)
#    DeepAR                   : 📈 MEJORA (-3.9%)
#    EnCQR-LSTM               : 📈 MEJORA (-2.3%)
#    LSPM                     : 📈 MEJORA (-29.7%)
#    LSPMW                    : 📈 MEJORA (-12.6%)
#    MCPS                     : 📈 MEJORA (-8.2%)
#    Sieve Bootstrap          : 📉 EMPEORA (+3.2%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 30% (CRPS=0.6822)
#    AV-MCPS                  : 10% (CRPS=0.7585)
#    Block Bootstrapping      : 30% (CRPS=0.6866)
#    DeepAR                   : 30% (CRPS=0.6375)
#    EnCQR-LSTM               : 30% (CRPS=0.9916)
#    LSPM                     : 30% (CRPS=0.7087)
#    LSPMW                    : 30% (CRPS=0.7788)
#    MCPS                     : 30% (CRPS=0.7309)
#    Sieve Bootstrap          : 10% (CRPS=0.6837)
#
# ⏱  Tiempo total test: 583.6s
# {'ARMA':         Paso Proceso Distribución  Varianza  N_Train  N_Calib Prop_Calib  \
#  0          1   AR(1)       normal       1.0      216       24        10%
#  1          2   AR(1)       normal       1.0      216       24        10%
#  2          3   AR(1)       normal       1.0      216       24        10%
#  3          4   AR(1)       normal       1.0      216       24        10%
#  4          5   AR(1)       normal       1.0      216       24        10%
#  5          6   AR(1)       normal       1.0      216       24        10%
#  6          7   AR(1)       normal       1.0      216       24        10%
#  7          8   AR(1)       normal       1.0      216       24        10%
#  8          9   AR(1)       normal       1.0      216       24        10%
#  9         10   AR(1)       normal       1.0      216       24        10%
#  10        11   AR(1)       normal       1.0      216       24        10%
#  11        12   AR(1)       normal       1.0      216       24        10%
#  12  Promedio   AR(1)       normal       1.0      216       24        10%
#  13         1   AR(2)       normal       1.0      216       24        10%
#  14         2   AR(2)       normal       1.0      216       24        10%
#  15         3   AR(2)       normal       1.0      216       24        10%
#  16         4   AR(2)       normal       1.0      216       24        10%
#  17         5   AR(2)       normal       1.0      216       24        10%
#  18         6   AR(2)       normal       1.0      216       24        10%
#  19         7   AR(2)       normal       1.0      216       24        10%
#  20         8   AR(2)       normal       1.0      216       24        10%
#  21         9   AR(2)       normal       1.0      216       24        10%
#  22        10   AR(2)       normal       1.0      216       24        10%
#  23        11   AR(2)       normal       1.0      216       24        10%
#  24        12   AR(2)       normal       1.0      216       24        10%
#  25  Promedio   AR(2)       normal       1.0      216       24        10%
#  26         1   AR(1)       normal       1.0      168       72        30%
#  27         2   AR(1)       normal       1.0      168       72        30%
#  40  0.675353  0.605254  0.582453    0.801594
#  41  0.893573  0.607132  0.570008    0.792653
#  42  0.871128  0.889971  0.622030    0.935962
#  43  0.659593  0.614838  0.573086    0.773211
#  44  0.626467  0.659739  0.568865    0.802278
#  45  0.668649  0.809978  0.580101    0.778354
#  46  0.762631  0.732615  0.592646    0.792965
#  47  0.665315  0.688748  0.587469    0.766326
#  48  0.711811  0.684742  0.617098    0.754325
#  49  0.606665  0.615220  0.623161    0.870965
#  50  1.201197  0.898824  0.575338    0.969515
#  51  0.759179  0.702176  0.588824    0.818644  ,
#  'ARIMA':         Paso       Proceso Distribución  Varianza  N_Train  N_Calib  \
#  0          1  ARIMA(0,1,0)       normal       1.0      216       24
#  1          2  ARIMA(0,1,0)       normal       1.0      216       24
#  2          3  ARIMA(0,1,0)       normal       1.0      216       24
#  3          4  ARIMA(0,1,0)       normal       1.0      216       24
#  4          5  ARIMA(0,1,0)       normal       1.0      216       24
#  5          6  ARIMA(0,1,0)       normal       1.0      216       24
#  6          7  ARIMA(0,1,0)       normal       1.0      216       24
#  7          8  ARIMA(0,1,0)       normal       1.0      216       24
#  8          9  ARIMA(0,1,0)       normal       1.0      216       24
#  9         10  ARIMA(0,1,0)       normal       1.0      216       24
#  10        11  ARIMA(0,1,0)       normal       1.0      216       24
#  11        12  ARIMA(0,1,0)       normal       1.0      216       24
#  12  Promedio  ARIMA(0,1,0)       normal       1.0      216       24
#  13         1  ARIMA(1,1,0)       normal       1.0      216       24
#  14         2  ARIMA(1,1,0)       normal       1.0      216       24
#  15         3  ARIMA(1,1,0)       normal       1.0      216       24
#  16         4  ARIMA(1,1,0)       normal       1.0      216       24
#  17         5  ARIMA(1,1,0)       normal       1.0      216       24
#  18         6  ARIMA(1,1,0)       normal       1.0      216       24
#  19         7  ARIMA(1,1,0)       normal       1.0      216       24
#  20         8  ARIMA(1,1,0)       normal       1.0      216       24
#  21         9  ARIMA(1,1,0)       normal       1.0      216       24
#  22        10  ARIMA(1,1,0)       normal       1.0      216       24
#  23        11  ARIMA(1,1,0)       normal       1.0      216       24
#  24        12  ARIMA(1,1,0)       normal       1.0      216       24
#  25  Promedio  ARIMA(1,1,0)       normal       1.0      216       24
#  26         1  ARIMA(0,1,0)       normal       1.0      168       72
#  27         2  ARIMA(0,1,0)       normal       1.0      168       72
#  28         3  ARIMA(0,1,0)       normal       1.0      168       72
#  29         4  ARIMA(0,1,0)       normal       1.0      168       72
#  30         5  ARIMA(0,1,0)       normal       1.0      168       72
#  31         6  ARIMA(0,1,0)       normal       1.0      168       72
#  32         7  ARIMA(0,1,0)       normal       1.0      168       72
#  33         8  ARIMA(0,1,0)       normal       1.0      168       72
#  34         9  ARIMA(0,1,0)       normal       1.0      168       72
#  35        10  ARIMA(0,1,0)       normal       1.0      168       72
#  36        11  ARIMA(0,1,0)       normal       1.0      168       72
#  37        12  ARIMA(0,1,0)       normal       1.0      168       72
#  38  Promedio  ARIMA(0,1,0)       normal       1.0      168       72
#  39         1  ARIMA(1,1,0)       normal       1.0      168       72
#   • 5 proporciones de calibración (10%, 20%, 30%, 40%, 50%)
#   • 7 configuraciones por proceso
#   • 5 distribuciones de ruido
#   • 4 niveles de varianza
#   • TOTAL: ~2100 escenarios base × 13 pasos = ~27,300 filas
#
#
# ================================================================================
# 1/3: EJECUTANDO ARMA...
# ================================================================================
# ================================================================================
# ANÁLISIS PROPORCIONES VARIABLES (N=240) - PROCESOS ARMA
# ================================================================================
# 🚀 Iniciando Pipeline Proporciones (ARMA): 200 escenarios.
# 📦 Procesando Lote 1/10...
# 📦 Procesando Lote 2/10...
# 📦 Procesando Lote 3/10...
# 📦 Procesando Lote 4/10...
# 📦 Procesando Lote 5/10...
# 📦 Procesando Lote 6/10...
# 📦 Procesando Lote 7/10...
# 📦 Procesando Lote 8/10...
# 📦 Procesando Lote 9/10...
# 📦 Procesando Lote 10/10...
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 2600
#   • Escenarios únicos: 200
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['AR(1)', 'AR(2)']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.9823 ± 0.7248
#    AV-MCPS                  : 0.6969 ± 0.3358
#    Block Bootstrapping      : 0.9499 ± 0.6976
#    DeepAR                   : 0.5784 ± 0.2874
#    EnCQR-LSTM               : 1.1019 ± 0.6072
#    LSPM                     : 0.7387 ± 0.3745
#    LSPMW                    : 1.0372 ± 0.7426
#    MCPS                     : 0.7043 ± 0.3489
#    Sieve Bootstrap          : 0.5472 ± 0.2742
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 0.9702 ± 0.6552
#    AV-MCPS                  : 0.7043 ± 0.3494
#    Block Bootstrapping      : 0.9467 ± 0.6992
#    DeepAR                   : 0.5781 ± 0.2934
#    EnCQR-LSTM               : 1.1051 ± 0.6553
#    LSPM                     : 0.7147 ± 0.3543
#    LSPMW                    : 1.0544 ± 0.6913
#    MCPS                     : 0.7197 ± 0.3827
#    Sieve Bootstrap          : 0.5482 ± 0.2742
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.9315 ± 0.7162
#    AV-MCPS                  : 0.7089 ± 0.4801
#    Block Bootstrapping      : 0.9016 ± 0.7314
#    DeepAR                   : 0.5863 ± 0.3163
#    EnCQR-LSTM               : 1.1070 ± 0.6847
#    LSPM                     : 0.7162 ± 0.3643
#    LSPMW                    : 0.9167 ± 0.5811
#    MCPS                     : 0.6856 ± 0.3305
#    Sieve Bootstrap          : 0.5444 ± 0.2745
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 0.9604 ± 0.6659
#    AV-MCPS                  : 0.6985 ± 0.3445
#    Block Bootstrapping      : 0.9560 ± 0.6685
#    DeepAR                   : 0.5740 ± 0.2867
#    EnCQR-LSTM               : 1.1530 ± 0.7420
#    LSPM                     : 0.7197 ± 0.3878
#    LSPMW                    : 1.0770 ± 1.0063
#    MCPS                     : 0.7060 ± 0.3506
#    Sieve Bootstrap          : 0.5464 ± 0.2777
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 1.0365 ± 1.0499
#    AV-MCPS                  : 0.7500 ± 0.4951
#    Block Bootstrapping      : 1.0247 ± 1.0500
#    DeepAR                   : 0.5795 ± 0.3006
#    EnCQR-LSTM               : 1.0784 ± 0.6574
#    LSPM                     : 0.7409 ± 0.3839
#    LSPMW                    : 1.1894 ± 1.0864
#    MCPS                     : 0.7459 ± 0.4346
#    Sieve Bootstrap          : 0.5461 ± 0.2804
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.5472
#    2. DeepAR                   : 0.5784
#    3. AV-MCPS                  : 0.6969
#    4. MCPS                     : 0.7043
#    5. LSPM                     : 0.7387
#
# 🏆 Proporción: 20%
#    1. Sieve Bootstrap          : 0.5482
#    2. DeepAR                   : 0.5781
#    3. AV-MCPS                  : 0.7043
#    4. LSPM                     : 0.7147
#    5. MCPS                     : 0.7197
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5444
#    2. DeepAR                   : 0.5863
#    3. MCPS                     : 0.6856
#    4. AV-MCPS                  : 0.7089
#    5. LSPM                     : 0.7162
#
# 🏆 Proporción: 40%
#    1. Sieve Bootstrap          : 0.5464
#    2. DeepAR                   : 0.5740
#    3. AV-MCPS                  : 0.6985
#    4. MCPS                     : 0.7060
#    5. LSPM                     : 0.7197
#
# 🏆 Proporción: 50%
#    1. Sieve Bootstrap          : 0.5461
#    2. DeepAR                   : 0.5795
#    3. LSPM                     : 0.7409
#    4. MCPS                     : 0.7459
#    5. AV-MCPS                  : 0.7500
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+5.5%)
#    AV-MCPS                  : 📉 EMPEORA (+7.6%)
#    Block Bootstrapping      : 📉 EMPEORA (+7.9%)
#    DeepAR                   : 📉 EMPEORA (+0.2%)
#    EnCQR-LSTM               : 📈 MEJORA (-2.1%)
#    LSPM                     : 📉 EMPEORA (+0.3%)
#    LSPMW                    : 📉 EMPEORA (+14.7%)
#    MCPS                     : 📉 EMPEORA (+5.9%)
#    Sieve Bootstrap          : 📈 MEJORA (-0.2%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 30% (CRPS=0.9315)
#    AV-MCPS                  : 10% (CRPS=0.6969)
#    Block Bootstrapping      : 30% (CRPS=0.9016)
#    DeepAR                   : 40% (CRPS=0.5740)
#    EnCQR-LSTM               : 50% (CRPS=1.0784)
#    LSPM                     : 20% (CRPS=0.7147)
#    LSPMW                    : 30% (CRPS=0.9167)
#    MCPS                     : 30% (CRPS=0.6856)
#    Sieve Bootstrap          : 30% (CRPS=0.5444)
#
# ⏱  Tiempo total: 5170.4s (1.44 horas)
#
# ================================================================================
# 2/3: EJECUTANDO ARIMA...
# ================================================================================
# ================================================================================
# ANÁLISIS PROPORCIONES VARIABLES (N=240) - PROCESOS ARIMA
# ================================================================================
# 🚀 Iniciando Pipeline Proporciones (ARIMA): 200 escenarios.
# 📦 Procesando Lote 1/10...
# 📦 Procesando Lote 2/10...
# 📦 Procesando Lote 3/10...
# 📦 Procesando Lote 4/10...
# 📦 Procesando Lote 5/10...
# 📦 Procesando Lote 6/10...
# 📦 Procesando Lote 7/10...
# 📦 Procesando Lote 8/10...
# 📦 Procesando Lote 9/10...
# 📦 Procesando Lote 10/10...
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 2600
#   • Escenarios únicos: 200
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['ARIMA(0,1,0)', 'ARIMA(1,1,0)']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 5.1256 ± 6.1163
#    AV-MCPS                  : 1.8038 ± 2.2141
#    Block Bootstrapping      : 5.7895 ± 6.4151
#    DeepAR                   : 1.3374 ± 2.1625
#    EnCQR-LSTM               : 3.8757 ± 2.7736
#    LSPM                     : 0.9500 ± 0.5136
#    LSPMW                    : 2.4677 ± 1.9335
#    MCPS                     : 1.8948 ± 2.9079
#    Sieve Bootstrap          : 0.5492 ± 0.2783
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 7.2923 ± 7.7085
#    AV-MCPS                  : 2.5800 ± 2.6816
#    Block Bootstrapping      : 7.8801 ± 7.9169
#    DeepAR                   : 2.6982 ± 5.7387
#    EnCQR-LSTM               : 4.5702 ± 2.9549
#    LSPM                     : 0.9557 ± 0.5144
#    LSPMW                    : 2.6986 ± 2.1481
#    MCPS                     : 2.4493 ± 2.6052
#    Sieve Bootstrap          : 0.5454 ± 0.2726
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 8.1006 ± 10.9517
#    AV-MCPS                  : 2.1421 ± 2.5048
#    Block Bootstrapping      : 8.7932 ± 11.7549
#    DeepAR                   : 2.7213 ± 6.3043
#    EnCQR-LSTM               : 3.8382 ± 2.4559
#    LSPM                     : 0.9504 ± 0.5131
#    LSPMW                    : 2.5521 ± 2.5911
#    MCPS                     : 2.3565 ± 3.4233
#    Sieve Bootstrap          : 0.5444 ± 0.2714
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 6.4894 ± 7.2418
#    AV-MCPS                  : 1.9965 ± 2.4921
#    Block Bootstrapping      : 7.2489 ± 7.8712
#    DeepAR                   : 1.4300 ± 2.7739
#    EnCQR-LSTM               : 4.0281 ± 3.1631
#    LSPM                     : 0.9307 ± 0.5000
#    LSPMW                    : 2.3740 ± 2.2200
#    MCPS                     : 2.0839 ± 2.9483
#    Sieve Bootstrap          : 0.5502 ± 0.2816
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 7.0525 ± 7.1333
#    AV-MCPS                  : 2.2702 ± 2.6642
#    Block Bootstrapping      : 7.6376 ± 7.4661
#    DeepAR                   : 2.1813 ± 4.2266
#    EnCQR-LSTM               : 4.9081 ± 4.0522
#    LSPM                     : 0.9888 ± 0.5427
#    LSPMW                    : 2.9115 ± 2.2616
#    MCPS                     : 2.0764 ± 2.5637
#    Sieve Bootstrap          : 0.5482 ± 0.2783
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.5492
#    2. LSPM                     : 0.9500
#    3. DeepAR                   : 1.3374
#    4. AV-MCPS                  : 1.8038
#    5. MCPS                     : 1.8948
#
# 🏆 Proporción: 20%
#    1. Sieve Bootstrap          : 0.5454
#    2. LSPM                     : 0.9557
#    3. MCPS                     : 2.4493
#    4. AV-MCPS                  : 2.5800
#    5. DeepAR                   : 2.6982
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5444
#    2. LSPM                     : 0.9504
#    3. AV-MCPS                  : 2.1421
#    4. MCPS                     : 2.3565
#    5. LSPMW                    : 2.5521
#
# 🏆 Proporción: 40%
#    1. Sieve Bootstrap          : 0.5502
#    2. LSPM                     : 0.9307
#    3. DeepAR                   : 1.4300
#    4. AV-MCPS                  : 1.9965
#    5. MCPS                     : 2.0839
#
# 🏆 Proporción: 50%
#    1. Sieve Bootstrap          : 0.5482
#    2. LSPM                     : 0.9888
#    3. MCPS                     : 2.0764
#    4. DeepAR                   : 2.1813
#    5. AV-MCPS                  : 2.2702
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+37.6%)
#    AV-MCPS                  : 📉 EMPEORA (+25.9%)
#    Block Bootstrapping      : 📉 EMPEORA (+31.9%)
#    DeepAR                   : 📉 EMPEORA (+63.1%)
#    EnCQR-LSTM               : 📉 EMPEORA (+26.6%)
#    LSPM                     : 📉 EMPEORA (+4.1%)
#    LSPMW                    : 📉 EMPEORA (+18.0%)
#    MCPS                     : 📉 EMPEORA (+9.6%)
#    Sieve Bootstrap          : 📈 MEJORA (-0.2%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 10% (CRPS=5.1256)
#    AV-MCPS                  : 10% (CRPS=1.8038)
#    Block Bootstrapping      : 10% (CRPS=5.7895)
#    DeepAR                   : 10% (CRPS=1.3374)
#    EnCQR-LSTM               : 30% (CRPS=3.8382)
#    LSPM                     : 40% (CRPS=0.9307)
#    LSPMW                    : 40% (CRPS=2.3740)
#    MCPS                     : 10% (CRPS=1.8948)
#    Sieve Bootstrap          : 30% (CRPS=0.5444)
#
# ⏱  Tiempo total: 6099.1s (1.69 horas)
#
# ================================================================================
# 3/3: EJECUTANDO SETAR...
# ================================================================================
# ================================================================================
# ANÁLISIS PROPORCIONES VARIABLES (N=240) - PROCESOS SETAR
# ================================================================================
# 🚀 Iniciando Pipeline Proporciones (SETAR): 200 escenarios.
# 📦 Procesando Lote 1/10...
# 📦 Procesando Lote 2/10...
# 📦 Procesando Lote 3/10...
# 📦 Procesando Lote 4/10...
# 📦 Procesando Lote 5/10...
# 📦 Procesando Lote 6/10...
# 📦 Procesando Lote 7/10...
# 📦 Procesando Lote 8/10...
# 📦 Procesando Lote 9/10...
# 📦 Procesando Lote 10/10...
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 2600
#   • Escenarios únicos: 200
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['SETAR-1', 'SETAR-2']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.7035 ± 0.3948
#    AV-MCPS                  : 0.7099 ± 0.3556
#    Block Bootstrapping      : 0.6657 ± 0.3626
#    DeepAR                   : 0.6322 ± 0.3519
#    EnCQR-LSTM               : 0.9001 ± 0.4777
#    LSPM                     : 0.7129 ± 0.4347
#    LSPMW                    : 0.7246 ± 0.4645
#    MCPS                     : 0.7211 ± 0.3457
#    Sieve Bootstrap          : 0.6471 ± 0.3326
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 0.7114 ± 0.3748
#    AV-MCPS                  : 0.7046 ± 0.3444
#    Block Bootstrapping      : 0.6646 ± 0.3418
#    DeepAR                   : 0.6167 ± 0.3193
#    EnCQR-LSTM               : 0.8884 ± 0.4531
#    LSPM                     : 0.6928 ± 0.3700
#    LSPMW                    : 0.7166 ± 0.3788
#    MCPS                     : 0.7258 ± 0.3729
#    Sieve Bootstrap          : 0.6388 ± 0.3205
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.7116 ± 0.3753
#    AV-MCPS                  : 0.7102 ± 0.3715
#    Block Bootstrapping      : 0.6667 ± 0.3721
#    DeepAR                   : 0.6332 ± 0.3703
#    EnCQR-LSTM               : 0.9144 ± 0.5004
#    LSPM                     : 0.6986 ± 0.4152
#    LSPMW                    : 0.7243 ± 0.4177
#    MCPS                     : 0.7229 ± 0.3711
#    Sieve Bootstrap          : 0.6445 ± 0.3503
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 0.7157 ± 0.4085
#    AV-MCPS                  : 0.7175 ± 0.4199
#    Block Bootstrapping      : 0.6615 ± 0.3675
#    DeepAR                   : 0.6266 ± 0.3455
#    EnCQR-LSTM               : 0.8973 ± 0.4873
#    LSPM                     : 0.6791 ± 0.3785
#    LSPMW                    : 0.7240 ± 0.4419
#    MCPS                     : 0.7448 ± 0.4257
#    Sieve Bootstrap          : 0.6405 ± 0.3309
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 0.7242 ± 0.3917
#    AV-MCPS                  : 0.7094 ± 0.3892
#    Block Bootstrapping      : 0.6620 ± 0.3528
#    DeepAR                   : 0.6187 ± 0.3119
#    EnCQR-LSTM               : 0.9053 ± 0.4785
#    LSPM                     : 0.6949 ± 0.3799
#    LSPMW                    : 0.7350 ± 0.3990
#    MCPS                     : 0.7415 ± 0.4090
#    Sieve Bootstrap          : 0.6458 ± 0.3370
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. DeepAR                   : 0.6322
#    2. Sieve Bootstrap          : 0.6471
#    3. Block Bootstrapping      : 0.6657
#    4. AREPD                    : 0.7035
#    5. AV-MCPS                  : 0.7099
#
# 🏆 Proporción: 20%
#    1. DeepAR                   : 0.6167
#    2. Sieve Bootstrap          : 0.6388
#    3. Block Bootstrapping      : 0.6646
#    4. LSPM                     : 0.6928
#    5. AV-MCPS                  : 0.7046
#
# 🏆 Proporción: 30%
#    1. DeepAR                   : 0.6332
#    2. Sieve Bootstrap          : 0.6445
#    3. Block Bootstrapping      : 0.6667
#    4. LSPM                     : 0.6986
#    5. AV-MCPS                  : 0.7102
#
# 🏆 Proporción: 40%
#    1. DeepAR                   : 0.6266
#    2. Sieve Bootstrap          : 0.6405
#    3. Block Bootstrapping      : 0.6615
#    4. LSPM                     : 0.6791
#    5. AREPD                    : 0.7157
#
# 🏆 Proporción: 50%
#    1. DeepAR                   : 0.6187
#    2. Sieve Bootstrap          : 0.6458
#    3. Block Bootstrapping      : 0.6620
#    4. LSPM                     : 0.6949
#    5. AV-MCPS                  : 0.7094
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+2.9%)
#    AV-MCPS                  : 📈 MEJORA (-0.1%)
#    Block Bootstrapping      : 📈 MEJORA (-0.6%)
#    DeepAR                   : 📈 MEJORA (-2.1%)
#    EnCQR-LSTM               : 📉 EMPEORA (+0.6%)
#    LSPM                     : 📈 MEJORA (-2.5%)
#    LSPMW                    : 📉 EMPEORA (+1.4%)
#    MCPS                     : 📉 EMPEORA (+2.8%)
#    Sieve Bootstrap          : 📈 MEJORA (-0.2%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 10% (CRPS=0.7035)
#    AV-MCPS                  : 20% (CRPS=0.7046)
#    Block Bootstrapping      : 40% (CRPS=0.6615)
#    DeepAR                   : 20% (CRPS=0.6167)
#    EnCQR-LSTM               : 20% (CRPS=0.8884)
#    LSPM                     : 40% (CRPS=0.6791)
#    LSPMW                    : 20% (CRPS=0.7166)
#    MCPS                     : 10% (CRPS=0.7211)
#    Sieve Bootstrap          : 20% (CRPS=0.6388)
#
# ⏱  Tiempo total: 4545.3s (1.26 horas)
#
# ================================================================================
# ANÁLISIS COMPARATIVO FINAL - TODOS LOS PROCESOS
# ================================================================================
#
# ✅ Resultados combinados guardados en: resultados_PROPORCIONES_240_TODOS.xlsx
#
# ============================================================
# PROCESO: ARMA
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 2600
#   • Escenarios únicos: 200
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['AR(1)', 'AR(2)']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.9823 ± 0.7248
#    AV-MCPS                  : 0.6969 ± 0.3358
#    Block Bootstrapping      : 0.9499 ± 0.6976
#    DeepAR                   : 0.5784 ± 0.2874
#    EnCQR-LSTM               : 1.1019 ± 0.6072
#    LSPM                     : 0.7387 ± 0.3745
#    LSPMW                    : 1.0372 ± 0.7426
#    MCPS                     : 0.7043 ± 0.3489
#    Sieve Bootstrap          : 0.5472 ± 0.2742
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 0.9702 ± 0.6552
#    AV-MCPS                  : 0.7043 ± 0.3494
#    Block Bootstrapping      : 0.9467 ± 0.6992
#    DeepAR                   : 0.5781 ± 0.2934
#    EnCQR-LSTM               : 1.1051 ± 0.6553
#    LSPM                     : 0.7147 ± 0.3543
#    LSPMW                    : 1.0544 ± 0.6913
#    MCPS                     : 0.7197 ± 0.3827
#    Sieve Bootstrap          : 0.5482 ± 0.2742
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.9315 ± 0.7162
#    AV-MCPS                  : 0.7089 ± 0.4801
#    Block Bootstrapping      : 0.9016 ± 0.7314
#    DeepAR                   : 0.5863 ± 0.3163
#    EnCQR-LSTM               : 1.1070 ± 0.6847
#    LSPM                     : 0.7162 ± 0.3643
#    LSPMW                    : 0.9167 ± 0.5811
#    MCPS                     : 0.6856 ± 0.3305
#    Sieve Bootstrap          : 0.5444 ± 0.2745
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 0.9604 ± 0.6659
#    AV-MCPS                  : 0.6985 ± 0.3445
#    Block Bootstrapping      : 0.9560 ± 0.6685
#    DeepAR                   : 0.5740 ± 0.2867
#    EnCQR-LSTM               : 1.1530 ± 0.7420
#    LSPM                     : 0.7197 ± 0.3878
#    LSPMW                    : 1.0770 ± 1.0063
#    MCPS                     : 0.7060 ± 0.3506
#    Sieve Bootstrap          : 0.5464 ± 0.2777
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 1.0365 ± 1.0499
#    AV-MCPS                  : 0.7500 ± 0.4951
#    Block Bootstrapping      : 1.0247 ± 1.0500
#    DeepAR                   : 0.5795 ± 0.3006
#    EnCQR-LSTM               : 1.0784 ± 0.6574
#    LSPM                     : 0.7409 ± 0.3839
#    LSPMW                    : 1.1894 ± 1.0864
#    MCPS                     : 0.7459 ± 0.4346
#    Sieve Bootstrap          : 0.5461 ± 0.2804
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.5472
#    2. DeepAR                   : 0.5784
#    3. AV-MCPS                  : 0.6969
#    4. MCPS                     : 0.7043
#    5. LSPM                     : 0.7387
#
# 🏆 Proporción: 20%
#    1. Sieve Bootstrap          : 0.5482
#    2. DeepAR                   : 0.5781
#    3. AV-MCPS                  : 0.7043
#    4. LSPM                     : 0.7147
#    5. MCPS                     : 0.7197
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5444
#    2. DeepAR                   : 0.5863
#    3. MCPS                     : 0.6856
#    4. AV-MCPS                  : 0.7089
#    5. LSPM                     : 0.7162
#
# 🏆 Proporción: 40%
#    1. Sieve Bootstrap          : 0.5464
#    2. DeepAR                   : 0.5740
#    3. AV-MCPS                  : 0.6985
#    4. MCPS                     : 0.7060
#    5. LSPM                     : 0.7197
#
# 🏆 Proporción: 50%
#    1. Sieve Bootstrap          : 0.5461
#    2. DeepAR                   : 0.5795
#    3. LSPM                     : 0.7409
#    4. MCPS                     : 0.7459
#    5. AV-MCPS                  : 0.7500
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+5.5%)
#    AV-MCPS                  : 📉 EMPEORA (+7.6%)
#    Block Bootstrapping      : 📉 EMPEORA (+7.9%)
#    DeepAR                   : 📉 EMPEORA (+0.2%)
#    EnCQR-LSTM               : 📈 MEJORA (-2.1%)
#    LSPM                     : 📉 EMPEORA (+0.3%)
#    LSPMW                    : 📉 EMPEORA (+14.7%)
#    MCPS                     : 📉 EMPEORA (+5.9%)
#    Sieve Bootstrap          : 📈 MEJORA (-0.2%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 30% (CRPS=0.9315)
#    AV-MCPS                  : 10% (CRPS=0.6969)
#    Block Bootstrapping      : 30% (CRPS=0.9016)
#    DeepAR                   : 40% (CRPS=0.5740)
#    EnCQR-LSTM               : 50% (CRPS=1.0784)
#    LSPM                     : 20% (CRPS=0.7147)
#    LSPMW                    : 30% (CRPS=0.9167)
#    MCPS                     : 30% (CRPS=0.6856)
#    Sieve Bootstrap          : 30% (CRPS=0.5444)
#
# ============================================================
# PROCESO: ARIMA
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 2600
#   • Escenarios únicos: 200
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['ARIMA(0,1,0)', 'ARIMA(1,1,0)']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 5.1256 ± 6.1163
#    AV-MCPS                  : 1.8038 ± 2.2141
#    Block Bootstrapping      : 5.7895 ± 6.4151
#    DeepAR                   : 1.3374 ± 2.1625
#    EnCQR-LSTM               : 3.8757 ± 2.7736
#    LSPM                     : 0.9500 ± 0.5136
#    LSPMW                    : 2.4677 ± 1.9335
#    MCPS                     : 1.8948 ± 2.9079
#    Sieve Bootstrap          : 0.5492 ± 0.2783
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 7.2923 ± 7.7085
#    AV-MCPS                  : 2.5800 ± 2.6816
#    Block Bootstrapping      : 7.8801 ± 7.9169
#    DeepAR                   : 2.6982 ± 5.7387
#    EnCQR-LSTM               : 4.5702 ± 2.9549
#    LSPM                     : 0.9557 ± 0.5144
#    LSPMW                    : 2.6986 ± 2.1481
#    MCPS                     : 2.4493 ± 2.6052
#    Sieve Bootstrap          : 0.5454 ± 0.2726
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 8.1006 ± 10.9517
#    AV-MCPS                  : 2.1421 ± 2.5048
#    Block Bootstrapping      : 8.7932 ± 11.7549
#    DeepAR                   : 2.7213 ± 6.3043
#    EnCQR-LSTM               : 3.8382 ± 2.4559
#    LSPM                     : 0.9504 ± 0.5131
#    LSPMW                    : 2.5521 ± 2.5911
#    MCPS                     : 2.3565 ± 3.4233
#    Sieve Bootstrap          : 0.5444 ± 0.2714
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 6.4894 ± 7.2418
#    AV-MCPS                  : 1.9965 ± 2.4921
#    Block Bootstrapping      : 7.2489 ± 7.8712
#    DeepAR                   : 1.4300 ± 2.7739
#    EnCQR-LSTM               : 4.0281 ± 3.1631
#    LSPM                     : 0.9307 ± 0.5000
#    LSPMW                    : 2.3740 ± 2.2200
#    MCPS                     : 2.0839 ± 2.9483
#    Sieve Bootstrap          : 0.5502 ± 0.2816
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 7.0525 ± 7.1333
#    AV-MCPS                  : 2.2702 ± 2.6642
#    Block Bootstrapping      : 7.6376 ± 7.4661
#    DeepAR                   : 2.1813 ± 4.2266
#    EnCQR-LSTM               : 4.9081 ± 4.0522
#    LSPM                     : 0.9888 ± 0.5427
#    LSPMW                    : 2.9115 ± 2.2616
#    MCPS                     : 2.0764 ± 2.5637
#    Sieve Bootstrap          : 0.5482 ± 0.2783
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.5492
#    2. LSPM                     : 0.9500
#    3. DeepAR                   : 1.3374
#    4. AV-MCPS                  : 1.8038
#    5. MCPS                     : 1.8948
#
# 🏆 Proporción: 20%
#    1. Sieve Bootstrap          : 0.5454
#    2. LSPM                     : 0.9557
#    3. MCPS                     : 2.4493
#    4. AV-MCPS                  : 2.5800
#    5. DeepAR                   : 2.6982
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5444
#    2. LSPM                     : 0.9504
#    3. AV-MCPS                  : 2.1421
#    4. MCPS                     : 2.3565
#    5. LSPMW                    : 2.5521
#
# 🏆 Proporción: 40%
#    1. Sieve Bootstrap          : 0.5502
#    2. LSPM                     : 0.9307
#    3. DeepAR                   : 1.4300
#    4. AV-MCPS                  : 1.9965
#    5. MCPS                     : 2.0839
#
# 🏆 Proporción: 50%
#    1. Sieve Bootstrap          : 0.5482
#    2. LSPM                     : 0.9888
#    3. MCPS                     : 2.0764
#    4. DeepAR                   : 2.1813
#    5. AV-MCPS                  : 2.2702
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+37.6%)
#    AV-MCPS                  : 📉 EMPEORA (+25.9%)
#    Block Bootstrapping      : 📉 EMPEORA (+31.9%)
#    DeepAR                   : 📉 EMPEORA (+63.1%)
#    EnCQR-LSTM               : 📉 EMPEORA (+26.6%)
#    LSPM                     : 📉 EMPEORA (+4.1%)
#    LSPMW                    : 📉 EMPEORA (+18.0%)
#    MCPS                     : 📉 EMPEORA (+9.6%)
#    Sieve Bootstrap          : 📈 MEJORA (-0.2%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 10% (CRPS=5.1256)
#    AV-MCPS                  : 10% (CRPS=1.8038)
#    Block Bootstrapping      : 10% (CRPS=5.7895)
#    DeepAR                   : 10% (CRPS=1.3374)
#    EnCQR-LSTM               : 30% (CRPS=3.8382)
#    LSPM                     : 40% (CRPS=0.9307)
#    LSPMW                    : 40% (CRPS=2.3740)
#    MCPS                     : 10% (CRPS=1.8948)
#    Sieve Bootstrap          : 30% (CRPS=0.5444)
#
# ============================================================
# PROCESO: SETAR
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 2600
#   • Escenarios únicos: 200
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['SETAR-1', 'SETAR-2']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.7035 ± 0.3948
#    AV-MCPS                  : 0.7099 ± 0.3556
#    Block Bootstrapping      : 0.6657 ± 0.3626
#    DeepAR                   : 0.6322 ± 0.3519
#    EnCQR-LSTM               : 0.9001 ± 0.4777
#    LSPM                     : 0.7129 ± 0.4347
#    LSPMW                    : 0.7246 ± 0.4645
#    MCPS                     : 0.7211 ± 0.3457
#    Sieve Bootstrap          : 0.6471 ± 0.3326
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 0.7114 ± 0.3748
#    AV-MCPS                  : 0.7046 ± 0.3444
#    Block Bootstrapping      : 0.6646 ± 0.3418
#    DeepAR                   : 0.6167 ± 0.3193
#    EnCQR-LSTM               : 0.8884 ± 0.4531
#    LSPM                     : 0.6928 ± 0.3700
#    LSPMW                    : 0.7166 ± 0.3788
#    MCPS                     : 0.7258 ± 0.3729
#    Sieve Bootstrap          : 0.6388 ± 0.3205
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.7116 ± 0.3753
#    AV-MCPS                  : 0.7102 ± 0.3715
#    Block Bootstrapping      : 0.6667 ± 0.3721
#    DeepAR                   : 0.6332 ± 0.3703
#    EnCQR-LSTM               : 0.9144 ± 0.5004
#    LSPM                     : 0.6986 ± 0.4152
#    LSPMW                    : 0.7243 ± 0.4177
#    MCPS                     : 0.7229 ± 0.3711
#    Sieve Bootstrap          : 0.6445 ± 0.3503
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 0.7157 ± 0.4085
#    AV-MCPS                  : 0.7175 ± 0.4199
#    Block Bootstrapping      : 0.6615 ± 0.3675
#    DeepAR                   : 0.6266 ± 0.3455
#    EnCQR-LSTM               : 0.8973 ± 0.4873
#    LSPM                     : 0.6791 ± 0.3785
#    LSPMW                    : 0.7240 ± 0.4419
#    MCPS                     : 0.7448 ± 0.4257
#    Sieve Bootstrap          : 0.6405 ± 0.3309
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 0.7242 ± 0.3917
#    AV-MCPS                  : 0.7094 ± 0.3892
#    Block Bootstrapping      : 0.6620 ± 0.3528
#    DeepAR                   : 0.6187 ± 0.3119
#    EnCQR-LSTM               : 0.9053 ± 0.4785
#    LSPM                     : 0.6949 ± 0.3799
#    LSPMW                    : 0.7350 ± 0.3990
#    MCPS                     : 0.7415 ± 0.4090
#    Sieve Bootstrap          : 0.6458 ± 0.3370
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. DeepAR                   : 0.6322
#    2. Sieve Bootstrap          : 0.6471
#    3. Block Bootstrapping      : 0.6657
#    4. AREPD                    : 0.7035
#    5. AV-MCPS                  : 0.7099
#
# 🏆 Proporción: 20%
#    1. DeepAR                   : 0.6167
#    2. Sieve Bootstrap          : 0.6388
#    3. Block Bootstrapping      : 0.6646
#    4. LSPM                     : 0.6928
#    5. AV-MCPS                  : 0.7046
#
# 🏆 Proporción: 30%
#    1. DeepAR                   : 0.6332
#    2. Sieve Bootstrap          : 0.6445
#    3. Block Bootstrapping      : 0.6667
#    4. LSPM                     : 0.6986
#    5. AV-MCPS                  : 0.7102
#
# 🏆 Proporción: 40%
#    1. DeepAR                   : 0.6266
#    2. Sieve Bootstrap          : 0.6405
#    3. Block Bootstrapping      : 0.6615
#    4. LSPM                     : 0.6791
#    5. AREPD                    : 0.7157
#
# 🏆 Proporción: 50%
#    1. DeepAR                   : 0.6187
#    2. Sieve Bootstrap          : 0.6458
#    3. Block Bootstrapping      : 0.6620
#    4. LSPM                     : 0.6949
#    5. AV-MCPS                  : 0.7094
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+2.9%)
#    AV-MCPS                  : 📈 MEJORA (-0.1%)
#    Block Bootstrapping      : 📈 MEJORA (-0.6%)
#    DeepAR                   : 📈 MEJORA (-2.1%)
#    EnCQR-LSTM               : 📉 EMPEORA (+0.6%)
#    LSPM                     : 📈 MEJORA (-2.5%)
#    LSPMW                    : 📉 EMPEORA (+1.4%)
#    MCPS                     : 📉 EMPEORA (+2.8%)
#    Sieve Bootstrap          : 📈 MEJORA (-0.2%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 10% (CRPS=0.7035)
#    AV-MCPS                  : 20% (CRPS=0.7046)
#    Block Bootstrapping      : 40% (CRPS=0.6615)
#    DeepAR                   : 20% (CRPS=0.6167)
#    EnCQR-LSTM               : 20% (CRPS=0.8884)
#    LSPM                     : 40% (CRPS=0.6791)
#    LSPMW                    : 20% (CRPS=0.7166)
#    MCPS                     : 10% (CRPS=0.7211)
#    Sieve Bootstrap          : 20% (CRPS=0.6388)
#
# ================================================================================
# COMPARACIÓN ENTRE PROCESOS
# ================================================================================
#
# ============================================================
# ANÁLISIS COMPARATIVO ENTRE TIPOS DE PROCESOS
# ============================================================
#
# 📊 Resumen General:
#   • Total de escenarios: 600
#   • Tipos de procesos: ['ARIMA', 'ARMA', 'SETAR']
#   • Proporciones: ['10%', '20%', '30%', '40%', '50%']
#
# ============================================================
# DESEMPEÑO PROMEDIO POR TIPO DE PROCESO
# ============================================================
#
# 🔹 ARIMA
#    --------------------------------------------------
#    AREPD                    : 6.8121 ± 7.9823
#    AV-MCPS                  : 2.1585 ± 2.5053
#    Block Bootstrapping      : 7.4698 ± 8.4536
#    DeepAR                   : 2.0736 ± 4.5306
#    EnCQR-LSTM               : 4.2440 ± 3.1240
#    LSPM                     : 0.9551 ± 0.5121
#    LSPMW                    : 2.6008 ± 2.2264
#    MCPS                     : 2.1722 ± 2.8839
#    Sieve Bootstrap          : 0.5475 ± 0.2737
#
# 🔹 ARMA
#    --------------------------------------------------
#    AREPD                    : 0.9762 ± 0.7693
#    AV-MCPS                  : 0.7117 ± 0.4036
#    Block Bootstrapping      : 0.9558 ± 0.7754
#    DeepAR                   : 0.5793 ± 0.2941
#    EnCQR-LSTM               : 1.1091 ± 0.6644
#    LSPM                     : 0.7260 ± 0.3696
#    LSPMW                    : 1.0550 ± 0.8398
#    MCPS                     : 0.7123 ± 0.3681
#    Sieve Bootstrap          : 0.5465 ± 0.2734
#
# 🔹 SETAR
#    --------------------------------------------------
#    AREPD                    : 0.7133 ± 0.3854
#    AV-MCPS                  : 0.7103 ± 0.3733
#    Block Bootstrapping      : 0.6641 ± 0.3559
#    DeepAR                   : 0.6255 ± 0.3371
#    EnCQR-LSTM               : 0.9011 ± 0.4749
#    LSPM                     : 0.6957 ± 0.3926
#    LSPMW                    : 0.7249 ± 0.4173
#    MCPS                     : 0.7312 ± 0.3822
#    Sieve Bootstrap          : 0.6433 ± 0.3310
#
# ============================================================
# MEJOR MODELO POR TIPO DE PROCESO
# ============================================================
#
# 🏆 ARIMA
#    1. Sieve Bootstrap          : 0.5475
#    2. LSPM                     : 0.9551
#    3. DeepAR                   : 2.0736
#    4. AV-MCPS                  : 2.1585
#    5. MCPS                     : 2.1722
#
# 🏆 ARMA
#    1. Sieve Bootstrap          : 0.5465
#    2. DeepAR                   : 0.5793
#    3. AV-MCPS                  : 0.7117
#    4. MCPS                     : 0.7123
#    5. LSPM                     : 0.7260
#
# 🏆 SETAR
#    1. DeepAR                   : 0.6255
#    2. Sieve Bootstrap          : 0.6433
#    3. Block Bootstrapping      : 0.6641
#    4. LSPM                     : 0.6957
#    5. AV-MCPS                  : 0.7103
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO Y TIPO DE PROCESO
# ============================================================
#
# 📈 ARIMA
#    AREPD                    : 10% (CRPS=5.1256)
#    AV-MCPS                  : 10% (CRPS=1.8038)
#    Block Bootstrapping      : 10% (CRPS=5.7895)
#    DeepAR                   : 10% (CRPS=1.3374)
#    EnCQR-LSTM               : 30% (CRPS=3.8382)
#    LSPM                     : 40% (CRPS=0.9307)
#    LSPMW                    : 40% (CRPS=2.3740)
#    MCPS                     : 10% (CRPS=1.8948)
#    Sieve Bootstrap          : 30% (CRPS=0.5444)
#
# 📈 ARMA
#    AREPD                    : 30% (CRPS=0.9315)
#    AV-MCPS                  : 10% (CRPS=0.6969)
#    Block Bootstrapping      : 30% (CRPS=0.9016)
#    DeepAR                   : 40% (CRPS=0.5740)
#    EnCQR-LSTM               : 50% (CRPS=1.0784)
#    LSPM                     : 20% (CRPS=0.7147)
#    LSPMW                    : 30% (CRPS=0.9167)
#    MCPS                     : 30% (CRPS=0.6856)
#    Sieve Bootstrap          : 30% (CRPS=0.5444)
#
# 📈 SETAR
#    AREPD                    : 10% (CRPS=0.7035)
#    AV-MCPS                  : 20% (CRPS=0.7046)
#    Block Bootstrapping      : 40% (CRPS=0.6615)
#    DeepAR                   : 20% (CRPS=0.6167)
#    EnCQR-LSTM               : 20% (CRPS=0.8884)
#    LSPM                     : 40% (CRPS=0.6791)
#    LSPMW                    : 20% (CRPS=0.7166)
#    MCPS                     : 10% (CRPS=0.7211)
#    Sieve Bootstrap          : 20% (CRPS=0.6388)
#
# ============================================================
# CONSISTENCIA DE MODELOS ENTRE PROCESOS
# ============================================================
#
# (Modelos que mantienen buen desempeño en todos los tipos de proceso)
#    AREPD                    : Promedio=7.0 (ARMA=7, ARIMA=8, SETAR=6)
#    AV-MCPS                  : Promedio=4.0 (ARMA=3, ARIMA=4, SETAR=5)
#    Block Bootstrapping      : Promedio=6.0 (ARMA=6, ARIMA=9, SETAR=3)
#    DeepAR                   : Promedio=2.0 (ARMA=2, ARIMA=3, SETAR=1)
#    EnCQR-LSTM               : Promedio=8.3 (ARMA=9, ARIMA=7, SETAR=9)
#    LSPM                     : Promedio=3.7 (ARMA=5, ARIMA=2, SETAR=4)
#    LSPMW                    : Promedio=7.0 (ARMA=8, ARIMA=6, SETAR=7)
#    MCPS                     : Promedio=5.7 (ARMA=4, ARIMA=5, SETAR=8)
#    Sieve Bootstrap          : Promedio=1.3 (ARMA=1, ARIMA=1, SETAR=2)
#
# ⏱  Tiempo total del experimento: 15901.1s (4.42 horas)
# ({'ARMA':           Paso Proceso Distribución  Varianza  N_Train  N_Calib Prop_Calib  \
#   0            1   AR(1)       normal       0.2      216       24        10%
#   1            2   AR(1)       normal       0.2      216       24        10%
#   2            3   AR(1)       normal       0.2      216       24        10%
#   3            4   AR(1)       normal       0.2      216       24        10%
#   4            5   AR(1)       normal       0.2      216       24        10%
#   ...        ...     ...          ...       ...      ...      ...        ...
#   2595         9   AR(2)      mixture       3.0      120      120        50%
#   2596        10   AR(2)      mixture       3.0      120      120        50%
#   2597        11   AR(2)      mixture       3.0      120      120        50%
#   2598        12   AR(2)      mixture       3.0      120      120        50%
#   2599  Promedio   AR(2)      mixture       3.0      120      120        50%
#
#         Block Bootstrapping  Sieve Bootstrap      LSPM     LSPMW     AREPD  \
#   0                0.371304         0.254896  0.275252  0.268784  0.262214
#   1                0.421335         0.281073  0.769504  0.632380  0.733967
#   2                0.341747         0.252637  0.332491  0.462385  0.542254
#   3                0.313110         0.251039  0.250098  0.428513  0.501111
#   4                0.310498         0.273395  0.260130  0.328962  0.380005
#   ...                   ...              ...       ...       ...       ...
#   2595             1.027379         0.955959  1.382014  1.617573  1.063062
#   2596             1.097449         1.023159  0.955220  1.728663  1.077321
#   2597             1.034802         0.948762  1.214305  1.048038  1.341969
#   2598             1.103232         0.973367  1.516665  1.776501  1.103009
#   2599             1.139504         0.994576  1.301878  1.504350  1.286068
#
#             MCPS   AV-MCPS    DeepAR  EnCQR-LSTM
#   0     0.540742  0.872673  0.255786    0.650826
#   1     0.317100  0.264980  0.296837    0.587991
#   2     0.263475  0.262237  0.275845    0.589076
#   3     0.282582  0.271336  0.253525    0.590071
#   4     0.273787  0.282548  0.257857    0.601785
#   ...        ...       ...       ...         ...
#   2595  1.149335  1.179223  0.989770    1.369004
#   2596  1.080891  1.561789  0.986540    1.401905
#   2597  1.034421  0.983949  0.975654    1.264288
#   2598  1.065499  1.029362  0.998376    1.421217
#   2599  1.239242  1.096857  1.002843    1.384588
#
#   [2600 rows x 16 columns],
#   'ARIMA':           Paso       Proceso Distribución  Varianza  N_Train  N_Calib  \
#   0            1  ARIMA(0,1,0)       normal       0.2      216       24
#   1            2  ARIMA(0,1,0)       normal       0.2      216       24
#   2            3  ARIMA(0,1,0)       normal       0.2      216       24
#   3            4  ARIMA(0,1,0)       normal       0.2      216       24
#   4            5  ARIMA(0,1,0)       normal       0.2      216       24
#   ...        ...           ...          ...       ...      ...      ...
#   2595         9  ARIMA(1,1,0)      mixture       3.0      120      120
#   2596        10  ARIMA(1,1,0)      mixture       3.0      120      120
#   2597        11  ARIMA(1,1,0)      mixture       3.0      120      120
#   2598        12  ARIMA(1,1,0)      mixture       3.0      120      120
#   2599  Promedio  ARIMA(1,1,0)      mixture       3.0      120      120
#
#        Prop_Calib  Block Bootstrapping  Sieve Bootstrap      LSPM      LSPMW  \
#   0           10%             1.448123         0.284411  0.325670   0.295330
#   1           10%             0.665733         0.285418  0.721413   0.602653
#   2           10%             0.753090         0.260598  0.358065   0.469523
#   3           10%             0.813548         0.252102  0.252954   0.460463
#   4           10%             0.848629         0.280990  0.275114   0.360354
#   ...         ...                  ...              ...       ...        ...
#   2595        50%            12.889674         0.976799  1.669452  11.339507
#   2596        50%            14.663887         1.133303  1.832893  13.401627
#   2597        50%            13.141113         1.000507  1.085982  12.004284
#   2598        50%            16.557700         0.975887  2.907391  15.325305
#   2599        50%            10.723377         1.024420  2.104910   8.623391
#
#             AREPD       MCPS    AV-MCPS    DeepAR  EnCQR-LSTM
#   0      1.339529   0.293839   0.279351  0.354861    0.826696
#   1      0.562442   0.472409   0.674982  0.309777    0.708904
#   2      0.658564   0.385249   0.538738  0.279279    0.731095
#   3      0.662871   0.393906   0.558272  0.257107    0.738702
#   4      0.773325   0.580636   0.583107  0.277144    0.760600
#   ...         ...        ...        ...       ...         ...
#   2595  13.011055   5.437757   6.748199  1.187528   12.215434
#   2596  14.989522   7.992030   8.836379  1.443004   13.532881
#   2597  13.497726   7.331162   8.349602  1.109047   12.105337
#   2598  16.719416  10.600936  11.887282  1.677152   14.522326
#   2599  10.463227   4.095630   4.805135  1.158244   11.226987
#
#   [2600 rows x 16 columns],
#   'SETAR':           Paso  Proceso Distribución  Varianza  N_Train  N_Calib Prop_Calib  \
#   0            1  SETAR-1       normal       0.2      216       24        10%
#   1            2  SETAR-1       normal       0.2      216       24        10%
#   2            3  SETAR-1       normal       0.2      216       24        10%
#   3            4  SETAR-1       normal       0.2      216       24        10%
#   4            5  SETAR-1       normal       0.2      216       24        10%
#   ...        ...      ...          ...       ...      ...      ...        ...
#   2595         9  SETAR-2      mixture       3.0      120      120        50%
#   2596        10  SETAR-2      mixture       3.0      120      120        50%
#   2597        11  SETAR-2      mixture       3.0      120      120        50%
#   2598        12  SETAR-2      mixture       3.0      120      120        50%
#   2599  Promedio  SETAR-2      mixture       3.0      120      120        50%
#
#         Block Bootstrapping  Sieve Bootstrap      LSPM     LSPMW     AREPD  \
#   0                0.284582         0.261351  0.255122  0.255288  0.292179
#   1                0.352075         0.262778  0.406568  0.488843  0.350904
#   2                0.252220         0.252967  0.294265  0.292029  0.255206
#   3                0.255080         0.252864  0.255738  0.261049  0.262744
#   4                0.293056         0.299519  0.279039  0.254052  0.306874
#   ...                   ...              ...       ...       ...       ...
#   2595             1.010354         0.989801  1.056463  1.395844  1.075701
#   2596             1.143779         1.059194  1.218364  2.029244  1.427948
#   2597             1.230824         1.097308  1.692351  1.010096  1.039661
#   2598             1.686704         1.664863  1.685875  1.097256  1.360951
#   2599             1.449991         1.310569  1.706179  1.773846  1.498652
#
#             MCPS   AV-MCPS    DeepAR  EnCQR-LSTM
#   0     0.382332  0.299583  0.264438    0.391472
#   1     0.276486  0.285030  0.324325    0.395147
#   2     0.294381  0.273307  0.254843    0.369803
#   3     0.322465  0.275458  0.251693    0.379285
#   4     0.287355  0.272801  0.256431    0.398465
#   ...        ...       ...       ...         ...
#   2595  1.152531  1.098377  0.996711    1.643036
#   2596  0.985525  1.224490  1.019050    1.531076
#   2597  1.049044  1.140465  1.042451    1.899311
#   2598  1.122079  1.347735  1.038930    2.201920
#   2599  1.247221  1.252233  1.092209    1.813623
#
#   [2600 rows x 16 columns]},
#            Paso  Proceso Distribución  Varianza  N_Train  N_Calib Prop_Calib  \
#  0            1    AR(1)       normal       0.2      216       24        10%
#  1            2    AR(1)       normal       0.2      216       24        10%
#  2            3    AR(1)       normal       0.2      216       24        10%
#  3            4    AR(1)       normal       0.2      216       24        10%
#  4            5    AR(1)       normal       0.2      216       24        10%
#  ...        ...      ...          ...       ...      ...      ...        ...
#  7795         9  SETAR-2      mixture       3.0      120      120        50%
#  7796        10  SETAR-2      mixture       3.0      120      120        50%
#  7797        11  SETAR-2      mixture       3.0      120      120        50%
#  7798        12  SETAR-2      mixture       3.0      120      120        50%
#  7799  Promedio  SETAR-2      mixture       3.0      120      120        50%
#
#        Block Bootstrapping  Sieve Bootstrap      LSPM     LSPMW     AREPD  \
#  0                0.371304         0.254896  0.275252  0.268784  0.262214
#  1                0.421335         0.281073  0.769504  0.632380  0.733967
#  2                0.341747         0.252637  0.332491  0.462385  0.542254
#  3                0.313110         0.251039  0.250098  0.428513  0.501111
#  4                0.310498         0.273395  0.260130  0.328962  0.380005
#  ...                   ...              ...       ...       ...       ...
#  7795             1.010354         0.989801  1.056463  1.395844  1.075701
#  7796             1.143779         1.059194  1.218364  2.029244  1.427948
#  7797             1.230824         1.097308  1.692351  1.010096  1.039661
#  7798             1.686704         1.664863  1.685875  1.097256  1.360951
#  7799             1.449991         1.310569  1.706179  1.773846  1.498652
#
#            MCPS   AV-MCPS    DeepAR  EnCQR-LSTM Tipo_Proceso
#  0     0.540742  0.872673  0.255786    0.650826         ARMA
#  1     0.317100  0.264980  0.296837    0.587991         ARMA
#  2     0.263475  0.262237  0.275845    0.589076         ARMA
#  3     0.282582  0.271336  0.253525    0.590071         ARMA
#  4     0.273787  0.282548  0.257857    0.601785         ARMA
#  ...        ...       ...       ...         ...          ...
#  7795  1.152531  1.098377  0.996711    1.643036        SETAR
#  7796  0.985525  1.224490  1.019050    1.531076        SETAR
#  7797  1.049044  1.140465  1.042451    1.899311        SETAR
#  7798  1.122079  1.347735  1.038930    2.201920        SETAR
#  7799  1.247221  1.252233  1.092209    1.813623        SETAR
#
#  [7800 rows x 17 columns])
