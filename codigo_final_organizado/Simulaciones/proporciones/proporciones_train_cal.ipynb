# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_test_proporciones_240_reducido

main_test_proporciones_240_reducido()
# Out:
# ================================================================================
# 🧪 INICIANDO TEST REDUCIDO - PROPORCIONES 240
# ================================================================================
#
# Configuración del test:
#   • Proporciones: ['10%', '30%']
#   • ARMA configs: 2
#   • ARIMA configs: 2
#   • SETAR configs: 2
#   • Distribuciones: ['normal']
#   • Varianzas: [1.0]
#   • Escenarios esperados: 3 × 2 × 2 × 1 × 1 = 12 escenarios
#
# 🚀 Iniciando Pipeline Proporciones (ARMA): 4 escenarios.
# 📦 Procesando Lote 1/1...
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO - PROPORCIONES VARIABLES (N=240)
# ================================================================================
#
# 📊 Resumen General:
#   • Total de filas: 52
#   • Escenarios únicos: 4
#   • Tipos de proceso: ['ARMA']
#   • Proporciones: ['10%', '30%']
#   • Distribuciones: ['normal']
#   • Varianzas: [np.float64(1.0)]
#   • Modelos evaluados: 9
#
# ================================================================================
# 📊 1. RANKING GLOBAL POR TIPO DE PROCESO
# ================================================================================
#
# --- ARMA (n=4 escenarios) ---
#  1. Sieve Bootstrap      0.587776
#  2. DeepAR               0.614331
#  3. MCPS                 0.768410
#  4. LSPM                 0.803619
#  5. AV-MCPS              0.817906
#
# ================================================================================
# 📈 2. DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ================================================================================
#
# --- Proporción: 10% (n=2 escenarios) ---
#     N_Train=216, N_Calib=24
#  1. Sieve Bootstrap      0.598777
#  2. DeepAR               0.610186
#  3. Block Bootstrapping  0.708838
#
# --- Proporción: 30% (n=2 escenarios) ---
#     N_Train=168, N_Calib=72
#  1. Sieve Bootstrap      0.576774
#  2. DeepAR               0.618475
#  3. LSPM                 0.768517
#
# ================================================================================
# 🎯 3. MEJOR PROPORCIÓN POR MODELO
# ================================================================================
# Modelo                    Mejor Prop   CRPS         Tipo
# -----------------------------------------------------------------
# AREPD                     10%          0.918199      ARMA
# AV-MCPS                   10%          0.763024      ARMA
# Block Bootstrapping       10%          0.708838      ARMA
# DeepAR                    10%          0.610186      ARMA
# EnCQR-LSTM                10%          0.743165      ARMA
# LSPM                      30%          0.768517      ARMA
# LSPMW                     10%          0.825375      ARMA
# MCPS                      10%          0.725051      ARMA
# Sieve Bootstrap           30%          0.576774      ARMA
#
# ================================================================================
# 📊 4. TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ================================================================================
#
# --- ARMA ---
#   AREPD                    : 📉 EMPEORA (+68.3%)
#   AV-MCPS                  : 📉 EMPEORA (+14.4%)
#   Block Bootstrapping      : 📉 EMPEORA (+96.0%)
#   DeepAR                   : 📉 EMPEORA (+1.4%)
#   EnCQR-LSTM               : 📉 EMPEORA (+89.8%)
#   LSPM                     : 📈 MEJORA (-8.4%)
#   LSPMW                    : 📉 EMPEORA (+59.7%)
#   MCPS                     : 📉 EMPEORA (+12.0%)
#   Sieve Bootstrap          : 📈 MEJORA (-3.7%)
#
# ================================================================================
# 🔄 5. COMPARACIÓN ENTRE TIPOS DE PROCESOS
# ================================================================================
#
# Mejor modelo por tipo de proceso:
#   ARMA      : Sieve Bootstrap           (CRPS: 0.587776)
#
# ================================================================================
# 📋 6. RESUMEN EJECUTIVO
# ================================================================================
#
# ✅ MEJOR MODELO GLOBAL:
#    → Sieve Bootstrap: CRPS = 0.587776
#
# ❌ PEOR MODELO GLOBAL:
#    → AREPD: CRPS = 1.231684
#
# 📊 DIFERENCIA:
#    → 109.5% peor desempeño
#
# 🎯 MEJOR PROPORCIÓN GLOBAL:
#    → 10%: CRPS promedio = 0.747926
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱ Tiempo total del test: 184.1s
# 📊 Filas generadas: 52
#         Paso Proceso Distribución  Varianza  N_Train  N_Calib Prop_Calib  \
# 0          1   AR(1)       normal       1.0      216       24        10%
# 1          2   AR(1)       normal       1.0      216       24        10%
# 2          3   AR(1)       normal       1.0      216       24        10%
# 3          4   AR(1)       normal       1.0      216       24        10%
# 4          5   AR(1)       normal       1.0      216       24        10%
# 5          6   AR(1)       normal       1.0      216       24        10%
# 6          7   AR(1)       normal       1.0      216       24        10%
# 7          8   AR(1)       normal       1.0      216       24        10%
# 8          9   AR(1)       normal       1.0      216       24        10%
# 9         10   AR(1)       normal       1.0      216       24        10%
# 10        11   AR(1)       normal       1.0      216       24        10%
# 11        12   AR(1)       normal       1.0      216       24        10%
# 12  Promedio   AR(1)       normal       1.0      216       24        10%
# 13         1   AR(2)       normal       1.0      216       24        10%
# 14         2   AR(2)       normal       1.0      216       24        10%
# 15         3   AR(2)       normal       1.0      216       24        10%
# 16         4   AR(2)       normal       1.0      216       24        10%
# 17         5   AR(2)       normal       1.0      216       24        10%
# 18         6   AR(2)       normal       1.0      216       24        10%
# 19         7   AR(2)       normal       1.0      216       24        10%
# 20         8   AR(2)       normal       1.0      216       24        10%
# 21         9   AR(2)       normal       1.0      216       24        10%
# 22        10   AR(2)       normal       1.0      216       24        10%
# 23        11   AR(2)       normal       1.0      216       24        10%
# 24        12   AR(2)       normal       1.0      216       24        10%
# 25  Promedio   AR(2)       normal       1.0      216       24        10%
# 26         1   AR(1)       normal       1.0      168       72        30%
# 27         2   AR(1)       normal       1.0      168       72        30%
# 28         3   AR(1)       normal       1.0      168       72        30%
# 29         4   AR(1)       normal       1.0      168       72        30%
# 30         5   AR(1)       normal       1.0      168       72        30%
# 31         6   AR(1)       normal       1.0      168       72        30%
# 32         7   AR(1)       normal       1.0      168       72        30%
# 33         8   AR(1)       normal       1.0      168       72        30%
# 34         9   AR(1)       normal       1.0      168       72        30%
# 35        10   AR(1)       normal       1.0      168       72        30%
# 36        11   AR(1)       normal       1.0      168       72        30%
# 37        12   AR(1)       normal       1.0      168       72        30%
# 38  Promedio   AR(1)       normal       1.0      168       72        30%
# 39         1   AR(2)       normal       1.0      168       72        30%
# 40         2   AR(2)       normal       1.0      168       72        30%
# 41         3   AR(2)       normal       1.0      168       72        30%
# 42         4   AR(2)       normal       1.0      168       72        30%
# 43         5   AR(2)       normal       1.0      168       72        30%
# 44         6   AR(2)       normal       1.0      168       72        30%
# 45         7   AR(2)       normal       1.0      168       72        30%
# 46         8   AR(2)       normal       1.0      168       72        30%
# 47         9   AR(2)       normal       1.0      168       72        30%
# 48        10   AR(2)       normal       1.0      168       72        30%
# 49        11   AR(2)       normal       1.0      168       72        30%
# 50        12   AR(2)       normal       1.0      168       72        30%
# 51  Promedio   AR(2)       normal       1.0      168       72        30%
#
#     Block Bootstrapping  Sieve Bootstrap      LSPM     LSPMW     AREPD  \
CPS   AV-MCPS    DeepAR  EnCQR-LSTM
# 0   1.254883  2.012858  0.573692    1.173941
# 1   0.704902  0.597448  0.660327    0.668750
# 2   0.604279  0.587890  0.565778    0.645041
# 3   0.636892  0.618507  0.670487    0.658197
# 4   0.623059  0.642352  0.600364    0.759965
# 5   0.812613  1.640875  0.587542    1.526723
# 6   0.634933  0.577135  0.641732    0.657121
# 7   0.582345  0.657572  0.577516    0.633406
# 8   0.701710  1.130774  0.702612    0.703344
# 9   1.230323  0.926440  0.608434    0.765146
# 10  0.635170  0.593503  0.579367    0.758049
# 11  0.632514  0.589158  0.726425    0.857153
# 12  0.754468  0.881209  0.624523    0.817236
# 13  0.621171  0.619867  0.567716    0.583885
# 14  0.720181  0.711306  0.579648    0.635035
# 15  0.612904  0.584478  0.573544    0.600244
# 16  0.650262  0.586767  0.624256    0.574217
# 17  0.675775  0.624270  0.561876    0.717777
# 18  0.888414  0.834878  0.633655    1.205769
# 19  0.667776  0.573080  0.696845    0.559445
# 20  0.831587  0.606623  0.581901    0.605288
# 21  0.700901  0.652861  0.563328    0.661226
# 22  0.638315  0.727403  0.578698    0.620793
# 23  0.663303  0.606207  0.584892    0.670949
# 24  0.677008  0.610328  0.603831    0.594500
# 25  0.695633  0.644839  0.595849    0.669094
# 26  1.305879  1.104062  0.592799    1.386193
# 27  1.266211  1.448969  0.568678    3.209388
# 28  0.856423  1.000882  0.627979    2.875728
# 29  1.135169  1.336666  0.611056    2.536223
# 30  0.591377  1.500444  0.560482    3.209681
# 31  0.610368  1.150487  0.596857    2.951981
# 32  0.727264  1.346642  0.585833    2.581097
# 33  0.753569  0.792502  0.664659    1.944978
# 34  0.587065  0.578897  0.715339    1.902997
# 35  0.824291  0.726037  0.939343    0.931176
# 36  1.010529  0.803573  0.681550    0.763913
# 37  0.628699  0.651919  0.577264    0.786577
# 38  0.858070  1.036757  0.643487    2.089994
# 39  0.775116  0.629231  0.587804    0.651222
# 40  0.675773  0.611437  0.583349    0.721454
# 41  0.895015  0.609146  0.583583    0.575291
# 42  0.877520  0.889064  0.640444    1.088286
# 43  0.663597  0.618618  0.569965    0.591297
# 44  0.633256  0.663139  0.572608    0.581954
# 45  0.672706  0.813571  0.578109    0.637804
# 46  0.781436  0.754260  0.580884    0.575769
# 47  0.666153  0.686492  0.595635    0.591550
# 48  0.712901  0.681847  0.619877    0.567946
# 49  0.621097  0.621924  0.625013    0.975359
# 50  1.211053  0.927120  0.584300    1.223268
# 51  0.765469  0.708821  0.593464    0.731767

# %%
from runner import main_proporciones_240_completo

main_proporciones_240_completo()
# Out:
# ================================================================================
# 🚀 INICIANDO PIPELINE UNIFICADO - PROPORCIONES 240 (TODOS LOS PROCESOS)
# ================================================================================
#
# Configuración del experimento:
#   • 3 tipos de procesos (ARMA, ARIMA, SETAR)
#   • 7 configuraciones por proceso
#   • 5 proporciones de calibración (10%, 20%, 30%, 40%, 50%)
#   • 5 distribuciones de ruido
#   • 4 niveles de varianza
#   • 12 pasos de predicción + 1 fila promedio por escenario
#   • TOTAL: 3 × 7 × 5 × 5 × 4 = 2,100 escenarios base
#   • FILAS: 2,100 × 13 = 27,300 filas
#
#
# ================================================================================
# 📊 PROCESANDO: ARMA
# ================================================================================
#
# 🚀 Iniciando Pipeline Proporciones (ARMA): 200 escenarios.
# 📦 Procesando Lote 1/10...
# 📦 Procesando Lote 2/10...
# 📦 Procesando Lote 3/10...
# 📦 Procesando Lote 4/10...
# 📦 Procesando Lote 5/10...
# 📦 Procesando Lote 6/10...
