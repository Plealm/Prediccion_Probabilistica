# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_test_proporciones_240_reducido

main_test_proporciones_240_reducido()
# Out:
# ================================================================================
# TEST REDUCIDO - PROPORCIONES 240 (TODOS LOS PROCESOS)
# ================================================================================
#
# ============================================================
# EJECUTANDO ARMA...
# ============================================================
# ================================================================================
# EVALUACIÓN PROPORCIONES VARIABLES (N=240) - PROCESO ARMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
#
# 📊 CONFIGURACIÓN:
#   • Tamaño total fijo: 240 datos
#   • Proporciones de calibración: 2
#     1. 10% calib (24) + 90% train (216)
#     2. 30% calib (72) + 70% train (168)
#   • Configuraciones ARMA: 2
#   • Distribuciones: 1
#   • Varianzas: 1
#   • ESCENARIOS BASE TOTALES: 4
#   • FILAS ESPERADAS: ~52
# ================================================================================
#
#
# 🚀 Lote 1/1 (Escenarios 1 a 4)...
# ================================================================================
# ✅ COMPLETADO - 52 filas generadas
# ================================================================================
#
# ============================================================
# EJECUTANDO ARIMA...
# ============================================================
# ================================================================================
# EVALUACIÓN PROPORCIONES VARIABLES (N=240) - PROCESO ARIMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
#
# 📊 CONFIGURACIÓN:
#   • Tamaño total fijo: 240 datos
#   • Proporciones de calibración: 2
#     1. 10% calib (24) + 90% train (216)
#     2. 30% calib (72) + 70% train (168)
#   • Configuraciones ARIMA: 2
#   • Distribuciones: 1
#   • Varianzas: 1
#   • ESCENARIOS BASE TOTALES: 4
#   • FILAS ESPERADAS: ~52
# ================================================================================
#
#
# 🚀 Lote 1/1 (Escenarios 1 a 4)...
# ================================================================================
# ✅ COMPLETADO - 52 filas generadas
# ================================================================================
#
# ============================================================
# EJECUTANDO SETAR...
# ============================================================
# ================================================================================
# EVALUACIÓN PROPORCIONES VARIABLES (N=240) - PROCESO SETAR
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 4
#
# 📊 CONFIGURACIÓN:
#   • Tamaño total fijo: 240 datos
#   • Proporciones de calibración: 2
#     1. 10% calib (24) + 90% train (216)
#     2. 30% calib (72) + 70% train (168)
#   • Configuraciones SETAR: 2
#   • Distribuciones: 1
#   • Varianzas: 1
#   • ESCENARIOS BASE TOTALES: 4
#   • FILAS ESPERADAS: ~52
# ================================================================================
#
#
# 🚀 Lote 1/1 (Escenarios 1 a 4)...
# ================================================================================
# ✅ COMPLETADO - 52 filas generadas
# ================================================================================
#
# ================================================================================
# ANÁLISIS COMPARATIVO DE LOS TRES PROCESOS
# ================================================================================
#
# ============================================================
# PROCESO: ARMA
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 52
#   • Escenarios únicos: 4
#   • Proporciones evaluadas: ['10%', '30%']
#   • Procesos: ['AR(1)', 'AR(2)']
#   • Distribuciones: ['normal']
#   • Varianzas: [np.float64(1.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.5916 ± 0.2443
#    AV-MCPS                  : 0.6963 ± 0.1807
#    Block Bootstrapping      : 0.5771 ± 0.1723
#    DeepAR                   : 0.6605 ± 0.2557
#    EnCQR-LSTM               : 1.0300 ± 0.2516
#    LSPM                     : 0.6632 ± 0.2259
#    LSPMW                    : 0.5910 ± 0.2350
#    MCPS                     : 0.7003 ± 0.1815
#    Sieve Bootstrap          : 0.6121 ± 0.2266
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.5457 ± 0.1376
#    AV-MCPS                  : 0.5728 ± 0.1035
#    Block Bootstrapping      : 0.6015 ± 0.0024
#    DeepAR                   : 0.5500 ± 0.0284
#    EnCQR-LSTM               : 0.9896 ± 0.1150
#    LSPM                     : 0.6801 ± 0.0906
#    LSPMW                    : 0.6547 ± 0.1228
#    MCPS                     : 0.5340 ± 0.0624
#    Sieve Bootstrap          : 0.6353 ± 0.1784
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Block Bootstrapping      : 0.5771
#    2. LSPMW                    : 0.5910
#    3. AREPD                    : 0.5916
#    4. Sieve Bootstrap          : 0.6121
#    5. DeepAR                   : 0.6605
#
# 🏆 Proporción: 30%
#    1. MCPS                     : 0.5340
#    2. AREPD                    : 0.5457
#    3. DeepAR                   : 0.5500
#    4. AV-MCPS                  : 0.5728
#    5. Block Bootstrapping      : 0.6015
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📈 MEJORA (-7.8%)
#    AV-MCPS                  : 📈 MEJORA (-17.7%)
#    Block Bootstrapping      : 📉 EMPEORA (+4.2%)
#    DeepAR                   : 📈 MEJORA (-16.7%)
#    EnCQR-LSTM               : 📈 MEJORA (-3.9%)
#    LSPM                     : 📉 EMPEORA (+2.5%)
#    LSPMW                    : 📉 EMPEORA (+10.8%)
#    MCPS                     : 📈 MEJORA (-23.7%)
#    Sieve Bootstrap          : 📉 EMPEORA (+3.8%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 30% (CRPS=0.5457)
#    AV-MCPS                  : 30% (CRPS=0.5728)
#    Block Bootstrapping      : 10% (CRPS=0.5771)
#    DeepAR                   : 30% (CRPS=0.5500)
#    EnCQR-LSTM               : 30% (CRPS=0.9896)
#    LSPM                     : 10% (CRPS=0.6632)
#    LSPMW                    : 10% (CRPS=0.5910)
#    MCPS                     : 30% (CRPS=0.5340)
#    Sieve Bootstrap          : 10% (CRPS=0.6121)
#
# ============================================================
# PROCESO: ARIMA
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 52
#   • Escenarios únicos: 4
#   • Proporciones evaluadas: ['10%', '30%']
#   • Procesos: ['ARIMA(0,1,0)', 'ARIMA(1,1,0)']
#   • Distribuciones: ['normal']
#   • Varianzas: [np.float64(1.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 8.1559 ± 8.9973
#    AV-MCPS                  : 2.5478 ± 2.2520
#    Block Bootstrapping      : 8.9010 ± 9.4448
#    DeepAR                   : 0.7916 ± 0.0411
#    EnCQR-LSTM               : 2.9549 ± 1.9333
#    LSPM                     : 0.8538 ± 0.0101
#    LSPMW                    : 2.8375 ± 2.4420
#    MCPS                     : 3.3671 ± 3.1241
#    Sieve Bootstrap          : 0.6373 ± 0.2053
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 1.4488 ± 0.7305
#    AV-MCPS                  : 1.1269 ± 0.6697
#    Block Bootstrapping      : 3.2952 ± 2.3459
#    DeepAR                   : 0.7745 ± 0.0474
#    EnCQR-LSTM               : 5.4383 ± 2.5206
#    LSPM                     : 0.8713 ± 0.1877
#    LSPMW                    : 3.7596 ± 4.5741
#    MCPS                     : 0.9618 ± 0.3255
#    Sieve Bootstrap          : 0.5664 ± 0.0702
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.6373
#    2. DeepAR                   : 0.7916
#    3. LSPM                     : 0.8538
#    4. AV-MCPS                  : 2.5478
#    5. LSPMW                    : 2.8375
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5664
#    2. DeepAR                   : 0.7745
#    3. LSPM                     : 0.8713
#    4. MCPS                     : 0.9618
#    5. AV-MCPS                  : 1.1269
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📈 MEJORA (-82.2%)
#    AV-MCPS                  : 📈 MEJORA (-55.8%)
#    Block Bootstrapping      : 📈 MEJORA (-63.0%)
#    DeepAR                   : 📈 MEJORA (-2.2%)
#    EnCQR-LSTM               : 📉 EMPEORA (+84.0%)
#    LSPM                     : 📉 EMPEORA (+2.1%)
#    LSPMW                    : 📉 EMPEORA (+32.5%)
#    MCPS                     : 📈 MEJORA (-71.4%)
#    Sieve Bootstrap          : 📈 MEJORA (-11.1%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 30% (CRPS=1.4488)
#    AV-MCPS                  : 30% (CRPS=1.1269)
#    Block Bootstrapping      : 30% (CRPS=3.2952)
#    DeepAR                   : 30% (CRPS=0.7745)
#    EnCQR-LSTM               : 10% (CRPS=2.9549)
#    LSPM                     : 10% (CRPS=0.8538)
#    LSPMW                    : 10% (CRPS=2.8375)
#    MCPS                     : 30% (CRPS=0.9618)
#    Sieve Bootstrap          : 30% (CRPS=0.5664)
#
# ============================================================
# PROCESO: SETAR
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 52
#   • Escenarios únicos: 4
#   • Proporciones evaluadas: ['10%', '30%']
#   • Procesos: ['SETAR-1', 'SETAR-2']
#   • Distribuciones: ['normal']
#   • Varianzas: [np.float64(1.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.7128 ± 0.2339
#    AV-MCPS                  : 0.6514 ± 0.2213
#    Block Bootstrapping      : 0.6838 ± 0.1420
#    DeepAR                   : 0.6611 ± 0.2562
#    EnCQR-LSTM               : 0.9775 ± 0.1244
#    LSPM                     : 0.7830 ± 0.1633
#    LSPMW                    : 0.6950 ± 0.2099
#    MCPS                     : 0.6557 ± 0.1435
#    Sieve Bootstrap          : 0.6880 ± 0.3260
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.6067 ± 0.0549
#    AV-MCPS                  : 0.7318 ± 0.0134
#    Block Bootstrapping      : 0.5436 ± 0.0627
#    DeepAR                   : 0.5201 ± 0.0237
#    EnCQR-LSTM               : 0.9477 ± 0.0630
#    LSPM                     : 0.5799 ± 0.0602
#    LSPMW                    : 0.5787 ± 0.1084
#    MCPS                     : 0.6401 ± 0.0792
#    Sieve Bootstrap          : 0.6621 ± 0.1166
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. AV-MCPS                  : 0.6514
#    2. MCPS                     : 0.6557
#    3. DeepAR                   : 0.6611
#    4. Block Bootstrapping      : 0.6838
#    5. Sieve Bootstrap          : 0.6880
#
# 🏆 Proporción: 30%
#    1. DeepAR                   : 0.5201
#    2. Block Bootstrapping      : 0.5436
#    3. LSPMW                    : 0.5787
#    4. LSPM                     : 0.5799
#    5. AREPD                    : 0.6067
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📈 MEJORA (-14.9%)
#    AV-MCPS                  : 📉 EMPEORA (+12.4%)
#    Block Bootstrapping      : 📈 MEJORA (-20.5%)
#    DeepAR                   : 📈 MEJORA (-21.3%)
#    EnCQR-LSTM               : 📈 MEJORA (-3.1%)
#    LSPM                     : 📈 MEJORA (-25.9%)
#    LSPMW                    : 📈 MEJORA (-16.7%)
#    MCPS                     : 📈 MEJORA (-2.4%)
#    Sieve Bootstrap          : 📈 MEJORA (-3.8%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 30% (CRPS=0.6067)
#    AV-MCPS                  : 10% (CRPS=0.6514)
#    Block Bootstrapping      : 30% (CRPS=0.5436)
#    DeepAR                   : 30% (CRPS=0.5201)
#    EnCQR-LSTM               : 30% (CRPS=0.9477)
#    LSPM                     : 30% (CRPS=0.5799)
#    LSPMW                    : 30% (CRPS=0.5787)
#    MCPS                     : 30% (CRPS=0.6401)
#    Sieve Bootstrap          : 30% (CRPS=0.6621)
#
# ⏱  Tiempo total test: 448.3s
# {'ARMA':         Paso Proceso Tipo_Proceso Distribución  Varianza  N_Train  N_Calib  \
#  0          1   AR(1)         ARMA       normal       1.0      216       24
#  1          2   AR(1)         ARMA       normal       1.0      216       24
#  2          3   AR(1)         ARMA       normal       1.0      216       24
#  3          4   AR(1)         ARMA       normal       1.0      216       24
#  4          5   AR(1)         ARMA       normal       1.0      216       24
#  5          6   AR(1)         ARMA       normal       1.0      216       24
#  6          7   AR(1)         ARMA       normal       1.0      216       24
#  7          8   AR(1)         ARMA       normal       1.0      216       24
#  8          9   AR(1)         ARMA       normal       1.0      216       24
#  9         10   AR(1)         ARMA       normal       1.0      216       24
#  10        11   AR(1)         ARMA       normal       1.0      216       24
#  11        12   AR(1)         ARMA       normal       1.0      216       24
#  12  Promedio   AR(1)         ARMA       normal       1.0      216       24
#  13         1   AR(2)         ARMA       normal       1.0      216       24
#  14         2   AR(2)         ARMA       normal       1.0      216       24
#  15         3   AR(2)         ARMA       normal       1.0      216       24
#  16         4   AR(2)         ARMA       normal       1.0      216       24
#  17         5   AR(2)         ARMA       normal       1.0      216       24
#  18         6   AR(2)         ARMA       normal       1.0      216       24
#  19         7   AR(2)         ARMA       normal       1.0      216       24
#  20         8   AR(2)         ARMA       normal       1.0      216       24
#  21         9   AR(2)         ARMA       normal       1.0      216       24
#  22        10   AR(2)         ARMA       normal       1.0      216       24
#  23        11   AR(2)         ARMA       normal       1.0      216       24
#  24        12   AR(2)         ARMA       normal       1.0      216       24
#  25  Promedio   AR(2)         ARMA       normal       1.0      216       24
#  26         1   AR(1)         ARMA       normal       1.0      168       72
#  27         2   AR(1)         ARMA       normal       1.0      168       72
#  28         3   AR(1)         ARMA       normal       1.0      168       72
#  29         4   AR(1)         ARMA       normal       1.0      168       72
#  30         5   AR(1)         ARMA       normal       1.0      168       72
#  31         6   AR(1)         ARMA       normal       1.0      168       72
#  32         7   AR(1)         ARMA       normal       1.0      168       72
#  33         8   AR(1)         ARMA       normal       1.0      168       72
#  34         9   AR(1)         ARMA       normal       1.0      168       72
#  35        10   AR(1)         ARMA       normal       1.0      168       72
#  36        11   AR(1)         ARMA       normal       1.0      168       72
#  37        12   AR(1)         ARMA       normal       1.0      168       72
#  38  Promedio   AR(1)         ARMA       normal       1.0      168       72
#  39         1   AR(2)         ARMA       normal       1.0      168       72
#  40         2   AR(2)         ARMA       normal       1.0      168       72
#  41         3   AR(2)         ARMA       normal       1.0      168       72
#  42         4   AR(2)         ARMA       normal       1.0      168       72
#  43         5   AR(2)         ARMA       normal       1.0      168       72
#  44         6   AR(2)         ARMA       normal       1.0      168       72
#  45         7   AR(2)         ARMA       normal       1.0      168       72
#  46         8   AR(2)         ARMA       normal       1.0      168       72
#  47         9   AR(2)         ARMA       normal       1.0      168       72
#  48        10   AR(2)         ARMA       normal       1.0      168       72
#  49        11   AR(2)         ARMA       normal       1.0      168       72
#  50        12   AR(2)         ARMA       normal       1.0      168       72
#  51  Promedio   AR(2)         ARMA       normal       1.0      168       72
#
#      N_Total Prop_Calib  Valor_Observado  Block Bootstrapping  Sieve Bootstrap  \
#  48  0.341962  0.573655  0.246519  0.554784  0.296236  0.340756    0.926086
#  49  0.292652  0.397852  0.231617  0.359548  0.167512  0.324561    0.949760
#  50  0.292635  0.334600  0.254609  0.291809  0.244290  0.242778    0.961571
#  51  0.622474  0.655372  0.536877  0.645479  0.696149  0.741309    0.992182  }

# %%
from runner import main_comparacion_proporciones_240_todos

main_comparacion_proporciones_240_todos()
# Out:
# ================================================================================
# EXPERIMENTO COMPLETO - PROPORCIONES 240 (TODOS LOS PROCESOS)
# ================================================================================
#
# Este experimento ejecutará:
#   • 3 tipos de procesos (ARMA, ARIMA, SETAR)
#   • 5 proporciones de calibración (10%, 20%, 30%, 40%, 50%)
#   • 7 configuraciones por proceso
#   • 5 distribuciones de ruido
#   • 4 niveles de varianza
#   • TOTAL: ~2100 escenarios base × 13 pasos = ~27,300 filas
#
#
# ================================================================================
# 1/3: EJECUTANDO ARMA...
# ================================================================================
# ================================================================================
# ANÁLISIS PROPORCIONES VARIABLES (N=240) - PROCESOS ARMA
# ================================================================================
# ================================================================================
# EVALUACIÓN PROPORCIONES VARIABLES (N=240) - PROCESO ARMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 20
#
# 📊 CONFIGURACIÓN:
#   • Tamaño total fijo: 240 datos
#   • Proporciones de calibración: 5
#     1. 10% calib (24) + 90% train (216)
#     2. 20% calib (48) + 80% train (192)
#     3. 30% calib (72) + 70% train (168)
#     4. 40% calib (96) + 60% train (144)
#     5. 50% calib (120) + 50% train (120)
#   • Configuraciones ARMA: 7
#   • Distribuciones: 5
#   • Varianzas: 4
#   • ESCENARIOS BASE TOTALES: 700
#   • FILAS ESPERADAS: ~9100
# ================================================================================
#
#
# 🚀 Lote 1/35 (Escenarios 1 a 20)...
# 🚀 Lote 2/35 (Escenarios 21 a 40)...
# 🚀 Lote 3/35 (Escenarios 41 a 60)...
# 🚀 Lote 4/35 (Escenarios 61 a 80)...
# 🚀 Lote 5/35 (Escenarios 81 a 100)...
# 🚀 Lote 6/35 (Escenarios 101 a 120)...
# 🚀 Lote 7/35 (Escenarios 121 a 140)...
# 🚀 Lote 8/35 (Escenarios 141 a 160)...
# 🚀 Lote 9/35 (Escenarios 161 a 180)...
# 🚀 Lote 10/35 (Escenarios 181 a 200)...
# 🚀 Lote 11/35 (Escenarios 201 a 220)...
# 🚀 Lote 12/35 (Escenarios 221 a 240)...
# 🚀 Lote 13/35 (Escenarios 241 a 260)...
# 🚀 Lote 14/35 (Escenarios 261 a 280)...
# 🚀 Lote 15/35 (Escenarios 281 a 300)...
# 🚀 Lote 16/35 (Escenarios 301 a 320)...
# 🚀 Lote 17/35 (Escenarios 321 a 340)...
# 🚀 Lote 18/35 (Escenarios 341 a 360)...
# 🚀 Lote 19/35 (Escenarios 361 a 380)...
# 🚀 Lote 20/35 (Escenarios 381 a 400)...
# 🚀 Lote 21/35 (Escenarios 401 a 420)...
# 🚀 Lote 22/35 (Escenarios 421 a 440)...
# 🚀 Lote 23/35 (Escenarios 441 a 460)...
# 🚀 Lote 24/35 (Escenarios 461 a 480)...
# 🚀 Lote 25/35 (Escenarios 481 a 500)...
# 🚀 Lote 26/35 (Escenarios 501 a 520)...
# 🚀 Lote 27/35 (Escenarios 521 a 540)...
# 🚀 Lote 28/35 (Escenarios 541 a 560)...
# 🚀 Lote 29/35 (Escenarios 561 a 580)...
# 🚀 Lote 30/35 (Escenarios 581 a 600)...
# 🚀 Lote 31/35 (Escenarios 601 a 620)...
# 🚀 Lote 32/35 (Escenarios 621 a 640)...
# 🚀 Lote 33/35 (Escenarios 641 a 660)...
# 🚀 Lote 34/35 (Escenarios 661 a 680)...
# 🚀 Lote 35/35 (Escenarios 681 a 700)...
# ================================================================================
# ✅ COMPLETADO - 9100 filas generadas
# ================================================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 9100
#   • Escenarios únicos: 700
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['AR(1)', 'AR(2)', 'ARMA(1,1)', 'ARMA(2,1)', 'ARMA(2,2)', 'MA(1)', 'MA(2)']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.8671 ± 0.6813
#    AV-MCPS                  : 0.7035 ± 0.4096
#    Block Bootstrapping      : 0.8634 ± 0.6967
#    DeepAR                   : 0.5675 ± 0.3156
#    EnCQR-LSTM               : 1.0474 ± 0.6212
#    LSPM                     : 0.7715 ± 0.4472
#    LSPMW                    : 1.0243 ± 0.8136
#    MCPS                     : 0.7109 ± 0.4428
#    Sieve Bootstrap          : 0.5366 ± 0.2854
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 0.8996 ± 0.6828
#    AV-MCPS                  : 0.7211 ± 0.4517
#    Block Bootstrapping      : 0.8708 ± 0.6231
#    DeepAR                   : 0.5862 ± 0.3449
#    EnCQR-LSTM               : 1.0616 ± 0.6433
#    LSPM                     : 0.7922 ± 0.4907
#    LSPMW                    : 1.0076 ± 0.8376
#    MCPS                     : 0.7004 ± 0.4294
#    Sieve Bootstrap          : 0.5619 ± 0.3272
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.9420 ± 0.7688
#    AV-MCPS                  : 0.7143 ± 0.4334
#    Block Bootstrapping      : 0.9014 ± 0.7280
#    DeepAR                   : 0.5792 ± 0.3586
#    EnCQR-LSTM               : 1.0986 ± 0.7521
#    LSPM                     : 0.7888 ± 0.5255
#    LSPMW                    : 1.0580 ± 0.9929
#    MCPS                     : 0.7135 ± 0.4518
#    Sieve Bootstrap          : 0.5493 ± 0.3339
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 0.9046 ± 0.7862
#    AV-MCPS                  : 0.7012 ± 0.4170
#    Block Bootstrapping      : 0.8693 ± 0.7783
#    DeepAR                   : 0.5663 ± 0.3322
#    EnCQR-LSTM               : 1.0479 ± 0.6316
#    LSPM                     : 0.7535 ± 0.4742
#    LSPMW                    : 1.1067 ± 1.0015
#    MCPS                     : 0.6886 ± 0.4264
#    Sieve Bootstrap          : 0.5448 ± 0.3205
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 0.9315 ± 0.7374
#    AV-MCPS                  : 0.7407 ± 0.4442
#    Block Bootstrapping      : 0.9109 ± 0.6899
#    DeepAR                   : 0.5858 ± 0.3198
#    EnCQR-LSTM               : 1.0825 ± 0.6413
#    LSPM                     : 0.8005 ± 0.4510
#    LSPMW                    : 1.0959 ± 0.9974
#    MCPS                     : 0.7390 ± 0.4569
#    Sieve Bootstrap          : 0.5575 ± 0.2996
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.5366
#    2. DeepAR                   : 0.5675
#    3. AV-MCPS                  : 0.7035
#    4. MCPS                     : 0.7109
#    5. LSPM                     : 0.7715
#
# 🏆 Proporción: 20%
#    1. Sieve Bootstrap          : 0.5619
#    2. DeepAR                   : 0.5862
#    3. MCPS                     : 0.7004
#    4. AV-MCPS                  : 0.7211
#    5. LSPM                     : 0.7922
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5493
#    2. DeepAR                   : 0.5792
#    3. MCPS                     : 0.7135
#    4. AV-MCPS                  : 0.7143
#    5. LSPM                     : 0.7888
#
# 🏆 Proporción: 40%
#    1. Sieve Bootstrap          : 0.5448
#    2. DeepAR                   : 0.5663
#    3. MCPS                     : 0.6886
#    4. AV-MCPS                  : 0.7012
#    5. LSPM                     : 0.7535
#
# 🏆 Proporción: 50%
#    1. Sieve Bootstrap          : 0.5575
#    2. DeepAR                   : 0.5858
#    3. MCPS                     : 0.7390
#    4. AV-MCPS                  : 0.7407
#    5. LSPM                     : 0.8005
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+7.4%)
#    AV-MCPS                  : 📉 EMPEORA (+5.3%)
#    Block Bootstrapping      : 📉 EMPEORA (+5.5%)
#    DeepAR                   : 📉 EMPEORA (+3.2%)
#    EnCQR-LSTM               : 📉 EMPEORA (+3.4%)
#    LSPM                     : 📉 EMPEORA (+3.8%)
#    LSPMW                    : 📉 EMPEORA (+7.0%)
#    MCPS                     : 📉 EMPEORA (+3.9%)
#    Sieve Bootstrap          : 📉 EMPEORA (+3.9%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 10% (CRPS=0.8671)
#    AV-MCPS                  : 40% (CRPS=0.7012)
#    Block Bootstrapping      : 10% (CRPS=0.8634)
#    DeepAR                   : 40% (CRPS=0.5663)
#    EnCQR-LSTM               : 10% (CRPS=1.0474)
#    LSPM                     : 40% (CRPS=0.7535)
#    LSPMW                    : 20% (CRPS=1.0076)
#    MCPS                     : 40% (CRPS=0.6886)
#    Sieve Bootstrap          : 10% (CRPS=0.5366)
#
# ⏱  Tiempo total: 20517.7s (5.70 horas)
#
# ================================================================================
# 2/3: EJECUTANDO ARIMA...
# ================================================================================
# ================================================================================
# ANÁLISIS PROPORCIONES VARIABLES (N=240) - PROCESOS ARIMA
# ================================================================================
# ================================================================================
# EVALUACIÓN PROPORCIONES VARIABLES (N=240) - PROCESO ARIMA
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 20
#
# 📊 CONFIGURACIÓN:
#   • Tamaño total fijo: 240 datos
#   • Proporciones de calibración: 5
#     1. 10% calib (24) + 90% train (216)
#     2. 20% calib (48) + 80% train (192)
#     3. 30% calib (72) + 70% train (168)
#     4. 40% calib (96) + 60% train (144)
#     5. 50% calib (120) + 50% train (120)
#   • Configuraciones ARIMA: 7
#   • Distribuciones: 5
#   • Varianzas: 4
#   • ESCENARIOS BASE TOTALES: 700
#   • FILAS ESPERADAS: ~9100
# ================================================================================
#
#
# 🚀 Lote 1/35 (Escenarios 1 a 20)...
# 🚀 Lote 2/35 (Escenarios 21 a 40)...
# 🚀 Lote 3/35 (Escenarios 41 a 60)...
# 🚀 Lote 4/35 (Escenarios 61 a 80)...
# 🚀 Lote 5/35 (Escenarios 81 a 100)...
# 🚀 Lote 6/35 (Escenarios 101 a 120)...
# 🚀 Lote 7/35 (Escenarios 121 a 140)...
# 🚀 Lote 8/35 (Escenarios 141 a 160)...
# 🚀 Lote 9/35 (Escenarios 161 a 180)...
# 🚀 Lote 10/35 (Escenarios 181 a 200)...
# 🚀 Lote 11/35 (Escenarios 201 a 220)...
# 🚀 Lote 12/35 (Escenarios 221 a 240)...
# 🚀 Lote 13/35 (Escenarios 241 a 260)...
# 🚀 Lote 14/35 (Escenarios 261 a 280)...
# 🚀 Lote 15/35 (Escenarios 281 a 300)...
# 🚀 Lote 16/35 (Escenarios 301 a 320)...
# 🚀 Lote 17/35 (Escenarios 321 a 340)...
# 🚀 Lote 18/35 (Escenarios 341 a 360)...
# 🚀 Lote 19/35 (Escenarios 361 a 380)...
# 🚀 Lote 20/35 (Escenarios 381 a 400)...
# 🚀 Lote 21/35 (Escenarios 401 a 420)...
# 🚀 Lote 22/35 (Escenarios 421 a 440)...
# 🚀 Lote 23/35 (Escenarios 441 a 460)...
# 🚀 Lote 24/35 (Escenarios 461 a 480)...
# 🚀 Lote 25/35 (Escenarios 481 a 500)...
# 🚀 Lote 26/35 (Escenarios 501 a 520)...
# 🚀 Lote 27/35 (Escenarios 521 a 540)...
# 🚀 Lote 28/35 (Escenarios 541 a 560)...
# 🚀 Lote 29/35 (Escenarios 561 a 580)...
# 🚀 Lote 30/35 (Escenarios 581 a 600)...
# 🚀 Lote 31/35 (Escenarios 601 a 620)...
# 🚀 Lote 32/35 (Escenarios 621 a 640)...
# 🚀 Lote 33/35 (Escenarios 641 a 660)...
# 🚀 Lote 34/35 (Escenarios 661 a 680)...
# 🚀 Lote 35/35 (Escenarios 681 a 700)...
# ================================================================================
# ✅ COMPLETADO - 9100 filas generadas
# ================================================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 9100
#   • Escenarios únicos: 700
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['ARIMA(0,1,0)', 'ARIMA(0,1,1)', 'ARIMA(0,1,2)', 'ARIMA(1,1,0)', 'ARIMA(1,1,1)', 'ARIMA(2,1,0)', 'ARIMA(2,1,2)']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 8.8259 ± 18.0531
#    AV-MCPS                  : 3.0752 ± 7.6172
#    Block Bootstrapping      : 10.1350 ± 19.1090
#    DeepAR                   : 3.0266 ± 10.8047
#    EnCQR-LSTM               : 5.0778 ± 6.4667
#    LSPM                     : 1.0910 ± 0.7075
#    LSPMW                    : 3.2726 ± 3.9372
#    MCPS                     : 2.9973 ± 9.0179
#    Sieve Bootstrap          : 0.5354 ± 0.2782
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 10.0190 ± 14.7734
#    AV-MCPS                  : 2.9661 ± 4.9593
#    Block Bootstrapping      : 11.2268 ± 16.1392
#    DeepAR                   : 3.2675 ± 8.7862
#    EnCQR-LSTM               : 4.8153 ± 5.9839
#    LSPM                     : 1.0570 ± 0.6214
#    LSPMW                    : 2.9783 ± 2.9846
#    MCPS                     : 2.6252 ± 3.8405
#    Sieve Bootstrap          : 0.5592 ± 0.3181
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 9.0045 ± 14.0320
#    AV-MCPS                  : 2.8922 ± 5.1838
#    Block Bootstrapping      : 10.0302 ± 14.7883
#    DeepAR                   : 2.7686 ± 7.9765
#    EnCQR-LSTM               : 4.7040 ± 4.7657
#    LSPM                     : 1.1170 ± 0.7811
#    LSPMW                    : 3.5719 ± 4.2416
#    MCPS                     : 2.8150 ± 5.7822
#    Sieve Bootstrap          : 0.5502 ± 0.3344
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 10.9420 ± 15.9770
#    AV-MCPS                  : 3.2417 ± 4.7175
#    Block Bootstrapping      : 11.8331 ± 16.7485
#    DeepAR                   : 4.0012 ± 10.2652
#    EnCQR-LSTM               : 4.4312 ± 3.9347
#    LSPM                     : 1.0864 ± 0.7491
#    LSPMW                    : 3.5946 ± 3.6059
#    MCPS                     : 3.1051 ± 4.6298
#    Sieve Bootstrap          : 0.5430 ± 0.3194
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 9.7946 ± 14.4278
#    AV-MCPS                  : 3.1588 ± 4.2214
#    Block Bootstrapping      : 10.7883 ± 15.6521
#    DeepAR                   : 2.8011 ± 6.1881
#    EnCQR-LSTM               : 5.1785 ± 6.6242
#    LSPM                     : 1.1287 ± 0.7833
#    LSPMW                    : 3.6364 ± 4.4863
#    MCPS                     : 3.0784 ± 4.3865
#    Sieve Bootstrap          : 0.5606 ± 0.2961
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.5354
#    2. LSPM                     : 1.0910
#    3. MCPS                     : 2.9973
#    4. DeepAR                   : 3.0266
#    5. AV-MCPS                  : 3.0752
#
# 🏆 Proporción: 20%
#    1. Sieve Bootstrap          : 0.5592
#    2. LSPM                     : 1.0570
#    3. MCPS                     : 2.6252
#    4. AV-MCPS                  : 2.9661
#    5. LSPMW                    : 2.9783
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5502
#    2. LSPM                     : 1.1170
#    3. DeepAR                   : 2.7686
#    4. MCPS                     : 2.8150
#    5. AV-MCPS                  : 2.8922
#
# 🏆 Proporción: 40%
#    1. Sieve Bootstrap          : 0.5430
#    2. LSPM                     : 1.0864
#    3. MCPS                     : 3.1051
#    4. AV-MCPS                  : 3.2417
#    5. LSPMW                    : 3.5946
#
# 🏆 Proporción: 50%
#    1. Sieve Bootstrap          : 0.5606
#    2. LSPM                     : 1.1287
#    3. DeepAR                   : 2.8011
#    4. MCPS                     : 3.0784
#    5. AV-MCPS                  : 3.1588
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+11.0%)
#    AV-MCPS                  : 📉 EMPEORA (+2.7%)
#    Block Bootstrapping      : 📉 EMPEORA (+6.4%)
#    DeepAR                   : 📈 MEJORA (-7.5%)
#    EnCQR-LSTM               : 📉 EMPEORA (+2.0%)
#    LSPM                     : 📉 EMPEORA (+3.5%)
#    LSPMW                    : 📉 EMPEORA (+11.1%)
#    MCPS                     : 📉 EMPEORA (+2.7%)
#    Sieve Bootstrap          : 📉 EMPEORA (+4.7%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 10% (CRPS=8.8259)
#    AV-MCPS                  : 30% (CRPS=2.8922)
#    Block Bootstrapping      : 30% (CRPS=10.0302)
#    DeepAR                   : 30% (CRPS=2.7686)
#    EnCQR-LSTM               : 40% (CRPS=4.4312)
#    LSPM                     : 20% (CRPS=1.0570)
#    LSPMW                    : 20% (CRPS=2.9783)
#    MCPS                     : 20% (CRPS=2.6252)
#    Sieve Bootstrap          : 10% (CRPS=0.5354)
#
# ⏱  Tiempo total: 21984.3s (6.11 horas)
#
# ================================================================================
# 3/3: EJECUTANDO SETAR...
# ================================================================================
# ================================================================================
# ANÁLISIS PROPORCIONES VARIABLES (N=240) - PROCESOS SETAR
# ================================================================================
# ================================================================================
# EVALUACIÓN PROPORCIONES VARIABLES (N=240) - PROCESO SETAR
# ================================================================================
# ⚡ Usando 6 núcleos en paralelo
# ⚡ Tamaño del lote: 20
#
# 📊 CONFIGURACIÓN:
#   • Tamaño total fijo: 240 datos
#   • Proporciones de calibración: 5
#     1. 10% calib (24) + 90% train (216)
#     2. 20% calib (48) + 80% train (192)
#     3. 30% calib (72) + 70% train (168)
#     4. 40% calib (96) + 60% train (144)
#     5. 50% calib (120) + 50% train (120)
#   • Configuraciones SETAR: 7
#   • Distribuciones: 5
#   • Varianzas: 4
#   • ESCENARIOS BASE TOTALES: 700
#   • FILAS ESPERADAS: ~9100
# ================================================================================
#
#
# 🚀 Lote 1/35 (Escenarios 1 a 20)...
# 🚀 Lote 2/35 (Escenarios 21 a 40)...
# 🚀 Lote 3/35 (Escenarios 41 a 60)...
# 🚀 Lote 4/35 (Escenarios 61 a 80)...
# 🚀 Lote 5/35 (Escenarios 81 a 100)...
# 🚀 Lote 6/35 (Escenarios 101 a 120)...
# 🚀 Lote 7/35 (Escenarios 121 a 140)...
# 🚀 Lote 8/35 (Escenarios 141 a 160)...
# 🚀 Lote 9/35 (Escenarios 161 a 180)...
# 🚀 Lote 10/35 (Escenarios 181 a 200)...
# 🚀 Lote 11/35 (Escenarios 201 a 220)...
# 🚀 Lote 12/35 (Escenarios 221 a 240)...
# 🚀 Lote 13/35 (Escenarios 241 a 260)...
# 🚀 Lote 14/35 (Escenarios 261 a 280)...
# 🚀 Lote 15/35 (Escenarios 281 a 300)...
# 🚀 Lote 16/35 (Escenarios 301 a 320)...
# 🚀 Lote 17/35 (Escenarios 321 a 340)...
# 🚀 Lote 18/35 (Escenarios 341 a 360)...
# 🚀 Lote 19/35 (Escenarios 361 a 380)...
# 🚀 Lote 20/35 (Escenarios 381 a 400)...
# 🚀 Lote 21/35 (Escenarios 401 a 420)...
# 🚀 Lote 22/35 (Escenarios 421 a 440)...
# 🚀 Lote 23/35 (Escenarios 441 a 460)...
# 🚀 Lote 24/35 (Escenarios 461 a 480)...
# 🚀 Lote 25/35 (Escenarios 481 a 500)...
# 🚀 Lote 26/35 (Escenarios 501 a 520)...
# 🚀 Lote 27/35 (Escenarios 521 a 540)...
# 🚀 Lote 28/35 (Escenarios 541 a 560)...
# 🚀 Lote 29/35 (Escenarios 561 a 580)...
# 🚀 Lote 30/35 (Escenarios 581 a 600)...
# 🚀 Lote 31/35 (Escenarios 601 a 620)...
# 🚀 Lote 32/35 (Escenarios 621 a 640)...
# 🚀 Lote 33/35 (Escenarios 641 a 660)...
# 🚀 Lote 34/35 (Escenarios 661 a 680)...
# 🚀 Lote 35/35 (Escenarios 681 a 700)...
# ================================================================================
# ✅ COMPLETADO - 9100 filas generadas
# ================================================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 9100
#   • Escenarios únicos: 700
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['SETAR-1', 'SETAR-2', 'SETAR-3', 'SETAR-4', 'SETAR-5', 'SETAR-6', 'SETAR-7']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.6775 ± 0.4239
#    AV-MCPS                  : 0.6909 ± 0.3938
#    Block Bootstrapping      : 0.6398 ± 0.3848
#    DeepAR                   : 0.6030 ± 0.3363
#    EnCQR-LSTM               : 0.8381 ± 0.4377
#    LSPM                     : 0.6487 ± 0.3902
#    LSPMW                    : 0.6631 ± 0.3974
#    MCPS                     : 0.6839 ± 0.3904
#    Sieve Bootstrap          : 0.6134 ± 0.3536
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 0.6724 ± 0.4149
#    AV-MCPS                  : 0.6865 ± 0.4018
#    Block Bootstrapping      : 0.6340 ± 0.3801
#    DeepAR                   : 0.6158 ± 0.3667
#    EnCQR-LSTM               : 0.8524 ± 0.4685
#    LSPM                     : 0.6585 ± 0.4101
#    LSPMW                    : 0.6660 ± 0.3975
#    MCPS                     : 0.7004 ± 0.4037
#    Sieve Bootstrap          : 0.6253 ± 0.3788
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.6628 ± 0.4272
#    AV-MCPS                  : 0.6695 ± 0.4144
#    Block Bootstrapping      : 0.6211 ± 0.3920
#    DeepAR                   : 0.6092 ± 0.3760
#    EnCQR-LSTM               : 0.8614 ± 0.4902
#    LSPM                     : 0.6539 ± 0.4116
#    LSPMW                    : 0.6768 ± 0.4655
#    MCPS                     : 0.6834 ± 0.4330
#    Sieve Bootstrap          : 0.6138 ± 0.3906
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 0.6820 ± 0.4416
#    AV-MCPS                  : 0.6809 ± 0.4277
#    Block Bootstrapping      : 0.6386 ± 0.4192
#    DeepAR                   : 0.6049 ± 0.3752
#    EnCQR-LSTM               : 0.8360 ± 0.4645
#    LSPM                     : 0.6624 ± 0.4636
#    LSPMW                    : 0.7042 ± 0.5135
#    MCPS                     : 0.6735 ± 0.4138
#    Sieve Bootstrap          : 0.6245 ± 0.4134
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 0.6826 ± 0.4335
#    AV-MCPS                  : 0.6868 ± 0.3865
#    Block Bootstrapping      : 0.6459 ± 0.3915
#    DeepAR                   : 0.6186 ± 0.3702
#    EnCQR-LSTM               : 0.8624 ± 0.4613
#    LSPM                     : 0.6781 ± 0.4308
#    LSPMW                    : 0.6667 ± 0.3884
#    MCPS                     : 0.6684 ± 0.3527
#    Sieve Bootstrap          : 0.6246 ± 0.3772
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. DeepAR                   : 0.6030
#    2. Sieve Bootstrap          : 0.6134
#    3. Block Bootstrapping      : 0.6398
#    4. LSPM                     : 0.6487
#    5. LSPMW                    : 0.6631
#
# 🏆 Proporción: 20%
#    1. DeepAR                   : 0.6158
#    2. Sieve Bootstrap          : 0.6253
#    3. Block Bootstrapping      : 0.6340
#    4. LSPM                     : 0.6585
#    5. LSPMW                    : 0.6660
#
# 🏆 Proporción: 30%
#    1. DeepAR                   : 0.6092
#    2. Sieve Bootstrap          : 0.6138
#    3. Block Bootstrapping      : 0.6211
#    4. LSPM                     : 0.6539
#    5. AREPD                    : 0.6628
#
# 🏆 Proporción: 40%
#    1. DeepAR                   : 0.6049
#    2. Sieve Bootstrap          : 0.6245
#    3. Block Bootstrapping      : 0.6386
#    4. LSPM                     : 0.6624
#    5. MCPS                     : 0.6735
#
# 🏆 Proporción: 50%
#    1. DeepAR                   : 0.6186
#    2. Sieve Bootstrap          : 0.6246
#    3. Block Bootstrapping      : 0.6459
#    4. LSPMW                    : 0.6667
#    5. MCPS                     : 0.6684
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+0.8%)
#    AV-MCPS                  : 📈 MEJORA (-0.6%)
#    Block Bootstrapping      : 📉 EMPEORA (+1.0%)
#    DeepAR                   : 📉 EMPEORA (+2.6%)
#    EnCQR-LSTM               : 📉 EMPEORA (+2.9%)
#    LSPM                     : 📉 EMPEORA (+4.5%)
#    LSPMW                    : 📉 EMPEORA (+0.5%)
#    MCPS                     : 📈 MEJORA (-2.3%)
#    Sieve Bootstrap          : 📉 EMPEORA (+1.8%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 30% (CRPS=0.6628)
#    AV-MCPS                  : 30% (CRPS=0.6695)
#    Block Bootstrapping      : 30% (CRPS=0.6211)
#    DeepAR                   : 10% (CRPS=0.6030)
#    EnCQR-LSTM               : 40% (CRPS=0.8360)
#    LSPM                     : 10% (CRPS=0.6487)
#    LSPMW                    : 10% (CRPS=0.6631)
#    MCPS                     : 50% (CRPS=0.6684)
#    Sieve Bootstrap          : 10% (CRPS=0.6134)
#
# ⏱  Tiempo total: 15777.7s (4.38 horas)
#
# ================================================================================
# ANÁLISIS COMPARATIVO FINAL - TODOS LOS PROCESOS
# ================================================================================
#
# ✅ Resultados combinados guardados en: resultados_PROPORCIONES_240_TODOS.xlsx
#
# ============================================================
# PROCESO: ARMA
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 9100
#   • Escenarios únicos: 700
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['AR(1)', 'AR(2)', 'ARMA(1,1)', 'ARMA(2,1)', 'ARMA(2,2)', 'MA(1)', 'MA(2)']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.8671 ± 0.6813
#    AV-MCPS                  : 0.7035 ± 0.4096
#    Block Bootstrapping      : 0.8634 ± 0.6967
#    DeepAR                   : 0.5675 ± 0.3156
#    EnCQR-LSTM               : 1.0474 ± 0.6212
#    LSPM                     : 0.7715 ± 0.4472
#    LSPMW                    : 1.0243 ± 0.8136
#    MCPS                     : 0.7109 ± 0.4428
#    Sieve Bootstrap          : 0.5366 ± 0.2854
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 0.8996 ± 0.6828
#    AV-MCPS                  : 0.7211 ± 0.4517
#    Block Bootstrapping      : 0.8708 ± 0.6231
#    DeepAR                   : 0.5862 ± 0.3449
#    EnCQR-LSTM               : 1.0616 ± 0.6433
#    LSPM                     : 0.7922 ± 0.4907
#    LSPMW                    : 1.0076 ± 0.8376
#    MCPS                     : 0.7004 ± 0.4294
#    Sieve Bootstrap          : 0.5619 ± 0.3272
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.9420 ± 0.7688
#    AV-MCPS                  : 0.7143 ± 0.4334
#    Block Bootstrapping      : 0.9014 ± 0.7280
#    DeepAR                   : 0.5792 ± 0.3586
#    EnCQR-LSTM               : 1.0986 ± 0.7521
#    LSPM                     : 0.7888 ± 0.5255
#    LSPMW                    : 1.0580 ± 0.9929
#    MCPS                     : 0.7135 ± 0.4518
#    Sieve Bootstrap          : 0.5493 ± 0.3339
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 0.9046 ± 0.7862
#    AV-MCPS                  : 0.7012 ± 0.4170
#    Block Bootstrapping      : 0.8693 ± 0.7783
#    DeepAR                   : 0.5663 ± 0.3322
#    EnCQR-LSTM               : 1.0479 ± 0.6316
#    LSPM                     : 0.7535 ± 0.4742
#    LSPMW                    : 1.1067 ± 1.0015
#    MCPS                     : 0.6886 ± 0.4264
#    Sieve Bootstrap          : 0.5448 ± 0.3205
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 0.9315 ± 0.7374
#    AV-MCPS                  : 0.7407 ± 0.4442
#    Block Bootstrapping      : 0.9109 ± 0.6899
#    DeepAR                   : 0.5858 ± 0.3198
#    EnCQR-LSTM               : 1.0825 ± 0.6413
#    LSPM                     : 0.8005 ± 0.4510
#    LSPMW                    : 1.0959 ± 0.9974
#    MCPS                     : 0.7390 ± 0.4569
#    Sieve Bootstrap          : 0.5575 ± 0.2996
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.5366
#    2. DeepAR                   : 0.5675
#    3. AV-MCPS                  : 0.7035
#    4. MCPS                     : 0.7109
#    5. LSPM                     : 0.7715
#
# 🏆 Proporción: 20%
#    1. Sieve Bootstrap          : 0.5619
#    2. DeepAR                   : 0.5862
#    3. MCPS                     : 0.7004
#    4. AV-MCPS                  : 0.7211
#    5. LSPM                     : 0.7922
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5493
#    2. DeepAR                   : 0.5792
#    3. MCPS                     : 0.7135
#    4. AV-MCPS                  : 0.7143
#    5. LSPM                     : 0.7888
#
# 🏆 Proporción: 40%
#    1. Sieve Bootstrap          : 0.5448
#    2. DeepAR                   : 0.5663
#    3. MCPS                     : 0.6886
#    4. AV-MCPS                  : 0.7012
#    5. LSPM                     : 0.7535
#
# 🏆 Proporción: 50%
#    1. Sieve Bootstrap          : 0.5575
#    2. DeepAR                   : 0.5858
#    3. MCPS                     : 0.7390
#    4. AV-MCPS                  : 0.7407
#    5. LSPM                     : 0.8005
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+7.4%)
#    AV-MCPS                  : 📉 EMPEORA (+5.3%)
#    Block Bootstrapping      : 📉 EMPEORA (+5.5%)
#    DeepAR                   : 📉 EMPEORA (+3.2%)
#    EnCQR-LSTM               : 📉 EMPEORA (+3.4%)
#    LSPM                     : 📉 EMPEORA (+3.8%)
#    LSPMW                    : 📉 EMPEORA (+7.0%)
#    MCPS                     : 📉 EMPEORA (+3.9%)
#    Sieve Bootstrap          : 📉 EMPEORA (+3.9%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 10% (CRPS=0.8671)
#    AV-MCPS                  : 40% (CRPS=0.7012)
#    Block Bootstrapping      : 10% (CRPS=0.8634)
#    DeepAR                   : 40% (CRPS=0.5663)
#    EnCQR-LSTM               : 10% (CRPS=1.0474)
#    LSPM                     : 40% (CRPS=0.7535)
#    LSPMW                    : 20% (CRPS=1.0076)
#    MCPS                     : 40% (CRPS=0.6886)
#    Sieve Bootstrap          : 10% (CRPS=0.5366)
#
# ============================================================
# PROCESO: ARIMA
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 9100
#   • Escenarios únicos: 700
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['ARIMA(0,1,0)', 'ARIMA(0,1,1)', 'ARIMA(0,1,2)', 'ARIMA(1,1,0)', 'ARIMA(1,1,1)', 'ARIMA(2,1,0)', 'ARIMA(2,1,2)']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 8.8259 ± 18.0531
#    AV-MCPS                  : 3.0752 ± 7.6172
#    Block Bootstrapping      : 10.1350 ± 19.1090
#    DeepAR                   : 3.0266 ± 10.8047
#    EnCQR-LSTM               : 5.0778 ± 6.4667
#    LSPM                     : 1.0910 ± 0.7075
#    LSPMW                    : 3.2726 ± 3.9372
#    MCPS                     : 2.9973 ± 9.0179
#    Sieve Bootstrap          : 0.5354 ± 0.2782
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 10.0190 ± 14.7734
#    AV-MCPS                  : 2.9661 ± 4.9593
#    Block Bootstrapping      : 11.2268 ± 16.1392
#    DeepAR                   : 3.2675 ± 8.7862
#    EnCQR-LSTM               : 4.8153 ± 5.9839
#    LSPM                     : 1.0570 ± 0.6214
#    LSPMW                    : 2.9783 ± 2.9846
#    MCPS                     : 2.6252 ± 3.8405
#    Sieve Bootstrap          : 0.5592 ± 0.3181
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 9.0045 ± 14.0320
#    AV-MCPS                  : 2.8922 ± 5.1838
#    Block Bootstrapping      : 10.0302 ± 14.7883
#    DeepAR                   : 2.7686 ± 7.9765
#    EnCQR-LSTM               : 4.7040 ± 4.7657
#    LSPM                     : 1.1170 ± 0.7811
#    LSPMW                    : 3.5719 ± 4.2416
#    MCPS                     : 2.8150 ± 5.7822
#    Sieve Bootstrap          : 0.5502 ± 0.3344
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 10.9420 ± 15.9770
#    AV-MCPS                  : 3.2417 ± 4.7175
#    Block Bootstrapping      : 11.8331 ± 16.7485
#    DeepAR                   : 4.0012 ± 10.2652
#    EnCQR-LSTM               : 4.4312 ± 3.9347
#    LSPM                     : 1.0864 ± 0.7491
#    LSPMW                    : 3.5946 ± 3.6059
#    MCPS                     : 3.1051 ± 4.6298
#    Sieve Bootstrap          : 0.5430 ± 0.3194
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 9.7946 ± 14.4278
#    AV-MCPS                  : 3.1588 ± 4.2214
#    Block Bootstrapping      : 10.7883 ± 15.6521
#    DeepAR                   : 2.8011 ± 6.1881
#    EnCQR-LSTM               : 5.1785 ± 6.6242
#    LSPM                     : 1.1287 ± 0.7833
#    LSPMW                    : 3.6364 ± 4.4863
#    MCPS                     : 3.0784 ± 4.3865
#    Sieve Bootstrap          : 0.5606 ± 0.2961
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. Sieve Bootstrap          : 0.5354
#    2. LSPM                     : 1.0910
#    3. MCPS                     : 2.9973
#    4. DeepAR                   : 3.0266
#    5. AV-MCPS                  : 3.0752
#
# 🏆 Proporción: 20%
#    1. Sieve Bootstrap          : 0.5592
#    2. LSPM                     : 1.0570
#    3. MCPS                     : 2.6252
#    4. AV-MCPS                  : 2.9661
#    5. LSPMW                    : 2.9783
#
# 🏆 Proporción: 30%
#    1. Sieve Bootstrap          : 0.5502
#    2. LSPM                     : 1.1170
#    3. DeepAR                   : 2.7686
#    4. MCPS                     : 2.8150
#    5. AV-MCPS                  : 2.8922
#
# 🏆 Proporción: 40%
#    1. Sieve Bootstrap          : 0.5430
#    2. LSPM                     : 1.0864
#    3. MCPS                     : 3.1051
#    4. AV-MCPS                  : 3.2417
#    5. LSPMW                    : 3.5946
#
# 🏆 Proporción: 50%
#    1. Sieve Bootstrap          : 0.5606
#    2. LSPM                     : 1.1287
#    3. DeepAR                   : 2.8011
#    4. MCPS                     : 3.0784
#    5. AV-MCPS                  : 3.1588
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+11.0%)
#    AV-MCPS                  : 📉 EMPEORA (+2.7%)
#    Block Bootstrapping      : 📉 EMPEORA (+6.4%)
#    DeepAR                   : 📈 MEJORA (-7.5%)
#    EnCQR-LSTM               : 📉 EMPEORA (+2.0%)
#    LSPM                     : 📉 EMPEORA (+3.5%)
#    LSPMW                    : 📉 EMPEORA (+11.1%)
#    MCPS                     : 📉 EMPEORA (+2.7%)
#    Sieve Bootstrap          : 📉 EMPEORA (+4.7%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 10% (CRPS=8.8259)
#    AV-MCPS                  : 30% (CRPS=2.8922)
#    Block Bootstrapping      : 30% (CRPS=10.0302)
#    DeepAR                   : 30% (CRPS=2.7686)
#    EnCQR-LSTM               : 40% (CRPS=4.4312)
#    LSPM                     : 20% (CRPS=1.0570)
#    LSPMW                    : 20% (CRPS=2.9783)
#    MCPS                     : 20% (CRPS=2.6252)
#    Sieve Bootstrap          : 10% (CRPS=0.5354)
#
# ============================================================
# PROCESO: SETAR
# ============================================================
#
# ============================================================
# ANÁLISIS DE PROPORCIONES VARIABLES (N=240)
# ============================================================
#
# 📊 Resumen General:
#   • Total de filas: 9100
#   • Escenarios únicos: 700
#   • Proporciones evaluadas: ['10%', '20%', '30%', '40%', '50%']
#   • Procesos: ['SETAR-1', 'SETAR-2', 'SETAR-3', 'SETAR-4', 'SETAR-5', 'SETAR-6', 'SETAR-7']
#   • Distribuciones: ['exponential', 'mixture', 'normal', 't-student', 'uniform']
#   • Varianzas: [np.float64(0.2), np.float64(0.5), np.float64(1.0), np.float64(3.0)]
#
# ============================================================
# DESEMPEÑO PROMEDIO POR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#
# 📈 Proporción Calibración: 10%
#    (N_Train=216, N_Calib=24)
#    --------------------------------------------------
#    AREPD                    : 0.6775 ± 0.4239
#    AV-MCPS                  : 0.6909 ± 0.3938
#    Block Bootstrapping      : 0.6398 ± 0.3848
#    DeepAR                   : 0.6030 ± 0.3363
#    EnCQR-LSTM               : 0.8381 ± 0.4377
#    LSPM                     : 0.6487 ± 0.3902
#    LSPMW                    : 0.6631 ± 0.3974
#    MCPS                     : 0.6839 ± 0.3904
#    Sieve Bootstrap          : 0.6134 ± 0.3536
#
# 📈 Proporción Calibración: 20%
#    (N_Train=192, N_Calib=48)
#    --------------------------------------------------
#    AREPD                    : 0.6724 ± 0.4149
#    AV-MCPS                  : 0.6865 ± 0.4018
#    Block Bootstrapping      : 0.6340 ± 0.3801
#    DeepAR                   : 0.6158 ± 0.3667
#    EnCQR-LSTM               : 0.8524 ± 0.4685
#    LSPM                     : 0.6585 ± 0.4101
#    LSPMW                    : 0.6660 ± 0.3975
#    MCPS                     : 0.7004 ± 0.4037
#    Sieve Bootstrap          : 0.6253 ± 0.3788
#
# 📈 Proporción Calibración: 30%
#    (N_Train=168, N_Calib=72)
#    --------------------------------------------------
#    AREPD                    : 0.6628 ± 0.4272
#    AV-MCPS                  : 0.6695 ± 0.4144
#    Block Bootstrapping      : 0.6211 ± 0.3920
#    DeepAR                   : 0.6092 ± 0.3760
#    EnCQR-LSTM               : 0.8614 ± 0.4902
#    LSPM                     : 0.6539 ± 0.4116
#    LSPMW                    : 0.6768 ± 0.4655
#    MCPS                     : 0.6834 ± 0.4330
#    Sieve Bootstrap          : 0.6138 ± 0.3906
#
# 📈 Proporción Calibración: 40%
#    (N_Train=144, N_Calib=96)
#    --------------------------------------------------
#    AREPD                    : 0.6820 ± 0.4416
#    AV-MCPS                  : 0.6809 ± 0.4277
#    Block Bootstrapping      : 0.6386 ± 0.4192
#    DeepAR                   : 0.6049 ± 0.3752
#    EnCQR-LSTM               : 0.8360 ± 0.4645
#    LSPM                     : 0.6624 ± 0.4636
#    LSPMW                    : 0.7042 ± 0.5135
#    MCPS                     : 0.6735 ± 0.4138
#    Sieve Bootstrap          : 0.6245 ± 0.4134
#
# 📈 Proporción Calibración: 50%
#    (N_Train=120, N_Calib=120)
#    --------------------------------------------------
#    AREPD                    : 0.6826 ± 0.4335
#    AV-MCPS                  : 0.6868 ± 0.3865
#    Block Bootstrapping      : 0.6459 ± 0.3915
#    DeepAR                   : 0.6186 ± 0.3702
#    EnCQR-LSTM               : 0.8624 ± 0.4613
#    LSPM                     : 0.6781 ± 0.4308
#    LSPMW                    : 0.6667 ± 0.3884
#    MCPS                     : 0.6684 ± 0.3527
#    Sieve Bootstrap          : 0.6246 ± 0.3772
#
# ============================================================
# RANKING DE MODELOS POR PROPORCIÓN
# ============================================================
#
# 🏆 Proporción: 10%
#    1. DeepAR                   : 0.6030
#    2. Sieve Bootstrap          : 0.6134
#    3. Block Bootstrapping      : 0.6398
#    4. LSPM                     : 0.6487
#    5. LSPMW                    : 0.6631
#
# 🏆 Proporción: 20%
#    1. DeepAR                   : 0.6158
#    2. Sieve Bootstrap          : 0.6253
#    3. Block Bootstrapping      : 0.6340
#    4. LSPM                     : 0.6585
#    5. LSPMW                    : 0.6660
#
# 🏆 Proporción: 30%
#    1. DeepAR                   : 0.6092
#    2. Sieve Bootstrap          : 0.6138
#    3. Block Bootstrapping      : 0.6211
#    4. LSPM                     : 0.6539
#    5. AREPD                    : 0.6628
#
# 🏆 Proporción: 40%
#    1. DeepAR                   : 0.6049
#    2. Sieve Bootstrap          : 0.6245
#    3. Block Bootstrapping      : 0.6386
#    4. LSPM                     : 0.6624
#    5. MCPS                     : 0.6735
#
# 🏆 Proporción: 50%
#    1. DeepAR                   : 0.6186
#    2. Sieve Bootstrap          : 0.6246
#    3. Block Bootstrapping      : 0.6459
#    4. LSPMW                    : 0.6667
#    5. MCPS                     : 0.6684
#
# ============================================================
# TENDENCIAS: EFECTO DE AUMENTAR PROPORCIÓN DE CALIBRACIÓN
# ============================================================
#    AREPD                    : 📉 EMPEORA (+0.8%)
#    AV-MCPS                  : 📈 MEJORA (-0.6%)
#    Block Bootstrapping      : 📉 EMPEORA (+1.0%)
#    DeepAR                   : 📉 EMPEORA (+2.6%)
#    EnCQR-LSTM               : 📉 EMPEORA (+2.9%)
#    LSPM                     : 📉 EMPEORA (+4.5%)
#    LSPMW                    : 📉 EMPEORA (+0.5%)
#    MCPS                     : 📈 MEJORA (-2.3%)
#    Sieve Bootstrap          : 📉 EMPEORA (+1.8%)
#
# ============================================================
# MEJOR PROPORCIÓN POR MODELO
# ============================================================
#    AREPD                    : 30% (CRPS=0.6628)
#    AV-MCPS                  : 30% (CRPS=0.6695)
#    Block Bootstrapping      : 30% (CRPS=0.6211)
#    DeepAR                   : 10% (CRPS=0.6030)
#    EnCQR-LSTM               : 40% (CRPS=0.8360)
#    LSPM                     : 10% (CRPS=0.6487)
#    LSPMW                    : 10% (CRPS=0.6631)
#    MCPS                     : 50% (CRPS=0.6684)
#    Sieve Bootstrap          : 10% (CRPS=0.6134)
#
# ================================================================================
# COMPARACIÓN ENTRE PROCESOS
# ================================================================================
#
# ============================================================
# ANÁLISIS COMPARATIVO ENTRE PROCESOS
# ============================================================
#
# 📊 DESEMPEÑO PROMEDIO POR TIPO DE PROCESO:
# ------------------------------------------------------------
#
# ARIMA:
#   AREPD                    : 9.7172 ± 15.4952
#   AV-MCPS                  : 3.0668 ± 5.4550
#   Block Bootstrapping      : 10.8027 ± 16.5183
#   DeepAR                   : 3.1730 ± 8.9438
#   EnCQR-LSTM               : 4.8413 ± 5.6417
#   LSPM                     : 1.0960 ± 0.7293
#   LSPMW                    : 3.4108 ± 3.8837
#   MCPS                     : 2.9242 ± 5.8202
#   Sieve Bootstrap          : 0.5497 ± 0.3091
#
# ARMA:
#   AREPD                    : 0.9090 ± 0.7310
#   AV-MCPS                  : 0.7162 ± 0.4305
#   Block Bootstrapping      : 0.8832 ± 0.7033
#   DeepAR                   : 0.5770 ± 0.3337
#   EnCQR-LSTM               : 1.0676 ± 0.6580
#   LSPM                     : 0.7813 ± 0.4775
#   LSPMW                    : 1.0585 ± 0.9306
#   MCPS                     : 0.7105 ± 0.4407
#   Sieve Bootstrap          : 0.5500 ± 0.3131
#
# SETAR:
#   AREPD                    : 0.6755 ± 0.4271
#   AV-MCPS                  : 0.6829 ± 0.4040
#   Block Bootstrapping      : 0.6359 ± 0.3927
#   DeepAR                   : 0.6103 ± 0.3642
#   EnCQR-LSTM               : 0.8501 ± 0.4636
#   LSPM                     : 0.6603 ± 0.4209
#   LSPMW                    : 0.6754 ± 0.4343
#   MCPS                     : 0.6819 ± 0.3986
#   Sieve Bootstrap          : 0.6203 ± 0.3822
#
# ============================================================
# MEJOR TIPO DE PROCESO POR MODELO
# ============================================================
#   AREPD                    : SETAR (CRPS=0.6755)
#   AV-MCPS                  : SETAR (CRPS=0.6829)
#   Block Bootstrapping      : SETAR (CRPS=0.6359)
#   DeepAR                   : ARMA (CRPS=0.5770)
#   EnCQR-LSTM               : SETAR (CRPS=0.8501)
#   LSPM                     : SETAR (CRPS=0.6603)
#   LSPMW                    : SETAR (CRPS=0.6754)
#   MCPS                     : SETAR (CRPS=0.6819)
#   Sieve Bootstrap          : ARIMA (CRPS=0.5497)
#
# ============================================================
#
# ⏱  Tiempo total del experimento: 58297.6s (16.19 horas)
# ({'ARMA':           Paso    Proceso Tipo_Proceso Distribución  Varianza  N_Train  \
#   0            1      AR(1)         ARMA       normal       0.2      216
#   1            2      AR(1)         ARMA       normal       0.2      216
#   2            3      AR(1)         ARMA       normal       0.2      216
#   3            4      AR(1)         ARMA       normal       0.2      216
#   4            5      AR(1)         ARMA       normal       0.2      216
#   ...        ...        ...          ...          ...       ...      ...
#   9095         9  ARMA(2,1)         ARMA      mixture       3.0      120
#   9096        10  ARMA(2,1)         ARMA      mixture       3.0      120
#   9097        11  ARMA(2,1)         ARMA      mixture       3.0      120
#   9098        12  ARMA(2,1)         ARMA      mixture       3.0      120
#   9099  Promedio  ARMA(2,1)         ARMA      mixture       3.0      120
#
#         N_Calib  N_Total Prop_Calib  Valor_Observado  Block Bootstrapping  \
#   0          24      240        10%        -0.196414             0.187480
#   1          24      240        10%        -0.108544             0.175871
#   2          24      240        10%         0.560381             0.466653
#   3          24      240        10%        -0.643501             0.294793
#   4          24      240        10%        -0.685074             0.327845
#   ...       ...      ...        ...              ...                  ...
#   9095      120      240        50%        10.513026             8.231486
#   9096      120      240        50%         8.997340             6.869385
#   9097      120      240        50%         7.012645             4.746881
#   9098      120      240        50%         6.098371             3.743148
#   9099      120      240        50%              NaN             4.201952
#
#         Sieve Bootstrap      LSPM      LSPMW    DeepAR      AREPD      MCPS  \
#   0            0.111285  0.101913   0.106120  0.089203   0.143449  0.137235
#   1            0.125167  0.095750   0.093209  0.096484   0.130528  0.113679
#   2            0.484061  0.551665   0.439027  0.510221   0.394601  0.426854
#   3            1.008342  0.317280   0.343767  1.042646   0.347875  0.816132
#   4            0.112814  1.011927   0.378252  0.119198   0.376475  0.153565
#   ...               ...       ...        ...       ...        ...       ...
#   9095         0.813500  1.403659  11.006859  0.402016  10.620877  1.221706
#   9096         0.400614  2.366382   9.491172  0.374754   9.081933  1.341961
#   9097         0.480801  1.275569   7.506477  0.568157   7.077848  0.557650
#   9098         0.720057  0.995521   6.592203  0.315556   6.154008  0.455469
#   9099         1.050933  2.104813   5.875771  0.987011   5.627017  1.534192
#
#          AV-MCPS  EnCQR-LSTM
#   0     0.063857    0.520127
#   1     0.068728    0.528050
#   2     0.306487    0.593751
#   3     0.995231    0.480688
#   4     0.121386    0.479425
#   ...        ...         ...
#   9095  1.045023    3.502276
#   9096  0.726201    2.729228
#   9097  0.562307    2.495574
#   9098  0.565055    2.454471
#   9099  1.227842    2.968661
#
#   [9100 rows x 19 columns],
#   'ARIMA':           Paso       Proceso Tipo_Proceso Distribución  Varianza  N_Train  \
#   0            1  ARIMA(0,1,0)        ARIMA       normal       0.2      216
#   1            2  ARIMA(0,1,0)        ARIMA       normal       0.2      216
#   2            3  ARIMA(0,1,0)        ARIMA       normal       0.2      216
#   3            4  ARIMA(0,1,0)        ARIMA       normal       0.2      216
#   4            5  ARIMA(0,1,0)        ARIMA       normal       0.2      216
#   ...        ...           ...          ...          ...       ...      ...
#   9095         9  ARIMA(2,1,2)        ARIMA      mixture       3.0      120
#   9096        10  ARIMA(2,1,2)        ARIMA      mixture       3.0      120
#   9097        11  ARIMA(2,1,2)        ARIMA      mixture       3.0      120
#   9098        12  ARIMA(2,1,2)        ARIMA      mixture       3.0      120
#   9099  Promedio  ARIMA(2,1,2)        ARIMA      mixture       3.0      120
#
#         N_Calib  N_Total Prop_Calib  Valor_Observado  Block Bootstrapping  \
#   0          24      240        10%        -4.389886             0.709077
#   1          24      240        10%        -4.321658             0.656372
#   2          24      240        10%        -3.663586             0.444695
#   3          24      240        10%        -4.811431             0.947481
#   4          24      240        10%        -4.917354             1.066054
#   ...       ...      ...        ...              ...                  ...
#   9095      120      240        50%       -91.352287            31.274408
#   9096      120      240        50%       -81.410001            25.265396
#   9097      120      240        50%       -70.448014            19.000851
#   9098      120      240        50%       -62.139767            16.588710
#   9099      120      240        50%              NaN            42.767662
#
#         Sieve Bootstrap       LSPM      LSPMW     DeepAR      AREPD       MCPS  \
#   0            0.138784   0.118375   0.114452   0.186494   0.466776   0.547631
#   1            0.111333   0.098954   0.098688   0.134241   0.423482   0.668286
#   2            0.430143   0.499351   0.380699   0.262121   0.228374   1.337354
#   3            1.070075   0.312325   0.362692   1.189411   0.748747   0.681040
#   4            0.097348   1.118752   0.453224   0.132600   0.831383   0.434884
#   ...               ...        ...        ...        ...        ...        ...
#   9095         2.731597  10.684500  26.766689   5.409672  29.766053   4.718257
#   9096         1.096649  12.044984  36.708975  10.011448  23.295347  13.019400
#   9097         1.785623  10.583223  47.670962  12.896116  17.553804  11.471615
#   9098         0.771580   9.533578  55.979209   9.435961  13.878188   8.244979
#   9099         1.341569   5.362286  17.547477   7.763369  39.817097   8.670575
#
#           AV-MCPS  EnCQR-LSTM
#   0      0.315040    0.643929
#   1      0.735112    0.648767
#   2      1.235483    0.704048
#   3      0.711960    0.629044
#   4      0.387024    0.629654
#   ...         ...         ...
#   9095   7.444192   12.461667
#   9096  16.509145   15.245064
#   9097   9.859054   20.273470
#   9098   0.878280   22.983290
#   9099   8.679435   13.058063
#
#   [9100 rows x 19 columns],
#   'SETAR':           Paso  Proceso Tipo_Proceso Distribución  Varianza  N_Train  N_Calib  \
#   0            1  SETAR-1        SETAR       normal       0.2      216       24
#   1            2  SETAR-1        SETAR       normal       0.2      216       24
#   2            3  SETAR-1        SETAR       normal       0.2      216       24
#   3            4  SETAR-1        SETAR       normal       0.2      216       24
#   4            5  SETAR-1        SETAR       normal       0.2      216       24
#   ...        ...      ...          ...          ...       ...      ...      ...
#   9095         9  SETAR-7        SETAR      mixture       3.0      120      120
#   9096        10  SETAR-7        SETAR      mixture       3.0      120      120
#   9097        11  SETAR-7        SETAR      mixture       3.0      120      120
#   9098        12  SETAR-7        SETAR      mixture       3.0      120      120
#   9099  Promedio  SETAR-7        SETAR      mixture       3.0      120      120
#
#         N_Total Prop_Calib  Valor_Observado  Block Bootstrapping  \
#   0         240        10%        -0.209939             0.124299
#   1         240        10%        -0.057736             0.160343
#   2         240        10%         0.623430             0.651808
#   3         240        10%        -1.459559             0.874321
#   4         240        10%        -0.981658             0.477221
#   ...       ...        ...              ...                  ...
#   9095      240        50%        -1.139719             0.543098
#   9096      240        50%        -0.282699             0.473915
#   9097      240        50%        -2.885798             1.827067
#   9098      240        50%         0.402417             0.582085
#   9099      240        50%              NaN             1.268969
#
#         Sieve Bootstrap      LSPM     LSPMW    DeepAR     AREPD      MCPS  \
#   0            0.104363  0.112721  0.096599  0.107740  0.048960  0.130963
#   1            0.186784  0.129896  0.099903  0.127857  0.115119  0.129846
#   2            0.617420  0.635002  0.620065  0.575820  0.768318  0.574646
#   3            1.334081  0.983876  1.026935  1.244294  1.060178  0.947311
#   4            0.116730  0.769106  0.553399  0.105479  0.585533  0.219993
#   ...               ...       ...       ...       ...       ...       ...
#   9095         0.568336  0.555495  0.657164  0.971570  0.648093  0.811098
#   9096         0.449997  0.435687  0.440760  0.470721  0.321953  0.669606
#   9097         1.618159  1.286196  2.019981  1.961071  2.079825  2.138784
#   9098         0.846525  0.766294  0.563690  0.825132  0.379107  0.580851
#   9099         1.224497  1.294402  1.220840  1.343638  1.310213  1.388178
#
#          AV-MCPS  EnCQR-LSTM
#   0     0.173368    0.344248
#   1     0.064557    0.357324
#   2     0.639678    0.494003
#   3     0.993485    0.771801
#   4     0.455057    0.355355
#   ...        ...         ...
#   9095  0.287723    1.158839
#   9096  0.687284    1.202479
#   9097  2.127657    1.502034
#   9098  1.742299    1.242602
#   9099  1.392074    1.382679
#
#   [9100 rows x 19 columns]},
#             Paso  Proceso Tipo_Proceso Distribución  Varianza  N_Train  \
#  0             1    AR(1)         ARMA       normal       0.2      216
#  1             2    AR(1)         ARMA       normal       0.2      216
#  2             3    AR(1)         ARMA       normal       0.2      216
#  3             4    AR(1)         ARMA       normal       0.2      216
#  4             5    AR(1)         ARMA       normal       0.2      216
#  ...         ...      ...          ...          ...       ...      ...
#  27295         9  SETAR-7        SETAR      mixture       3.0      120
#  27296        10  SETAR-7        SETAR      mixture       3.0      120
#  27297        11  SETAR-7        SETAR      mixture       3.0      120
#  27298        12  SETAR-7        SETAR      mixture       3.0      120
#  27299  Promedio  SETAR-7        SETAR      mixture       3.0      120
#
#         N_Calib  N_Total Prop_Calib  Valor_Observado  Block Bootstrapping  \
#  0           24      240        10%        -0.196414             0.187480
#  1           24      240        10%        -0.108544             0.175871
#  2           24      240        10%         0.560381             0.466653
#  3           24      240        10%        -0.643501             0.294793
#  4           24      240        10%        -0.685074             0.327845
#  ...        ...      ...        ...              ...                  ...
#  27295      120      240        50%        -1.139719             0.543098
#  27296      120      240        50%        -0.282699             0.473915
#  27297      120      240        50%        -2.885798             1.827067
#  27298      120      240        50%         0.402417             0.582085
#  27299      120      240        50%              NaN             1.268969
#
#         Sieve Bootstrap      LSPM     LSPMW    DeepAR     AREPD      MCPS  \
#  0             0.111285  0.101913  0.106120  0.089203  0.143449  0.137235
#  1             0.125167  0.095750  0.093209  0.096484  0.130528  0.113679
#  2             0.484061  0.551665  0.439027  0.510221  0.394601  0.426854
#  3             1.008342  0.317280  0.343767  1.042646  0.347875  0.816132
#  4             0.112814  1.011927  0.378252  0.119198  0.376475  0.153565
#  ...                ...       ...       ...       ...       ...       ...
#  27295         0.568336  0.555495  0.657164  0.971570  0.648093  0.811098
#  27296         0.449997  0.435687  0.440760  0.470721  0.321953  0.669606
#  27297         1.618159  1.286196  2.019981  1.961071  2.079825  2.138784
#  27298         0.846525  0.766294  0.563690  0.825132  0.379107  0.580851
#  27299         1.224497  1.294402  1.220840  1.343638  1.310213  1.388178
#
#          AV-MCPS  EnCQR-LSTM
#  0      0.063857    0.520127
#  1      0.068728    0.528050
#  2      0.306487    0.593751
#  3      0.995231    0.480688
#  4      0.121386    0.479425
#  ...         ...         ...
#  27295  0.287723    1.158839
#  27296  0.687284    1.202479
#  27297  2.127657    1.502034
#  27298  1.742299    1.242602
#  27299  1.392074    1.382679
#
#  [27300 rows x 19 columns])
