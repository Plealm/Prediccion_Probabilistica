# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import test_proporciones_240_rapido

test_proporciones_240_rapido()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from runner import test_proporciones_240_rapido
#       3 test_proporciones_240_rapido()
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base\runner.py:14
#      11 os.environ["NUMEXPR_NUM_THREADS"] = n_threads
#      12 os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# ---> 14 from pipeline import Pipeline140SinSesgos_ARMA, Pipeline140SinSesgos_ARIMA, Pipeline140SinSesgos_SETAR, Pipeline140_TamanosCrecientes, Pipeline240_ProporcionesVariables
#      15 import pandas as pd
#      16 import numpy as np
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base\pipeline.py:14
#      11 warnings.filterwarnings("ignore")
#      13 from simulacion import ARMASimulation
# ...

# %%
from runner import main_proporciones_240_completo

main_proporciones_240_completo()
# Out:
# ...
# 🚀 INICIANDO PIPELINE UNIFICADO - PROPORCIONES 240
# ...
#
# 📋 Configuración:
#   • 3 tipos de procesos (ARMA, ARIMA, SETAR)
#   • 7 configuraciones por proceso = 21 total
#   • 5 proporciones de calibración (10% a 50%)
#   • 5 distribuciones de ruido
#   • 4 niveles de varianza
#   • 12 pasos de predicción por escenario
#   • TOTAL ESCENARIOS: 21 × 5 × 5 × 4 = 2,100
#   • TOTAL FILAS: 2,100 × 12 = 25,200
#
#
# ...
# 📊 PROCESANDO: ARMA
# ...
#
#
# 🔍 Generando escenarios para ARMA:
#    • Configs: 7
#    • Proporciones: 5
#    • Distribuciones: 5
#    • Varianzas: 4
#    • ESPERADOS: 700 escenarios
#    • Filas esperadas: 8400
#
# ✅ Generados correctamente 700 escenarios
#
#
# ...
# 🚀 PIPELINE PROPORCIONES 240 - ARMA
# ...
# 📊 Total escenarios: 700
# 📦 Batches: 35 (tamaño 20)
# 👷 Workers: 12 de 16 cores
# 💾 Guardado cada 3 batches
# ...
#
# 🔄 Batch 1/35...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
from pipeline import Pipeline240_ProporcionesVariables_Fast


if __name__ == "__main__":
    
    print("\n" + "="*70)
    print("🚀 EJECUTANDO PIPELINE 240 PROPORCIONES COMPLETO")
    print("="*70 + "\n")
    
    # Crear pipeline (procesa automáticamente ARMA + ARIMA + SETAR)
    pipeline = Pipeline240_ProporcionesVariables_Fast(
        n_boot=500,      # Optimizado para velocidad
        seed=42,
        verbose=False
    )
    
    # Ejecutar todos los escenarios
    results = pipeline.run_all(
        excel_filename="RESULTADOS_PROPORCIONES_240_COMPLETO_ULTRAFAST.xlsx",
        batch_size=30,
        max_workers=None,  # Auto-detecta cores
        save_frequency=2
    )
    
    print("\n✅ Pipeline completado exitosamente!")
    print(f"📁 Archivo generado: RESULTADOS_PROPORCIONES_240_COMPLETO_ULTRAFAST.xlsx")
    print(f"📊 Total de filas: {len(results)}")
# Out:
# ...
# 🚀 EJECUTANDO PIPELINE 240 PROPORCIONES COMPLETO
# ...
#
#
# 🔍 Generando escenarios para ARMA + ARIMA + SETAR:
#    • Total configs: 21 (7+7+7)
#    • Proporciones: 5
#    • Distribuciones: 5
#    • Varianzas: 4
#    • TOTAL ESPERADO: 2100 escenarios
#    • Filas esperadas: 25200
#
#    📋 Generando ARMA: 7 configs...
#    📋 Generando ARIMA: 7 configs...
#    📋 Generando SETAR: 7 configs...
# ✅ Generados 2100 escenarios
#
#
# ...
# ⚡ PIPELINE 240 PROPORCIONES - COMPLETO (ARMA+ARIMA+SETAR) - ULTRA RÁPIDO
# ...
# 📊 Escenarios: 2100 (21 configs × 5 props × 5 dist × 4 var)
# 📦 Batches: 70 (tamaño 30)
# 👷 Workers: 13 de 16 cores
# 🔥 n_boot: 500 (500 vs 1000 = 50% menos)
# ⚡ Epochs reducidos: DeepAR 15, EnCQR 12
# 💾 Guardado cada 2 batches
# ...
#
# 🔄 Batch 1/70... ✅ 360 filas
# 🔄 Batch 2/70... ✅ 720 filas
# 💾 Checkpoint: RESULTADOS_PROPORCIONES_240_COMPLETO_ULTRAFAST.xlsx
# 🔄 Batch 3/70... ✅ 1080 filas
# 🔄 Batch 4/70... ✅ 1440 filas
# 💾 Checkpoint: RESULTADOS_PROPORCIONES_240_COMPLETO_ULTRAFAST.xlsx
# ...
