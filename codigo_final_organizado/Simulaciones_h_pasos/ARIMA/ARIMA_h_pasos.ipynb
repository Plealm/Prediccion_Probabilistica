# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones_h_pasos\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_two_scenarios_arima

main_two_scenarios_arima()
# Out:
# ================================================================================
# EVALUACIÓN CON 2 ESCENARIOS ARIMA (100 TRAYECTORIAS CADA UNO)
# ================================================================================
#
# 📊 Configuración:
#    - Escenarios: 2 (ARIMA(1,1,0) y ARIMA(0,1,1))
#    - Distribución: Normal
#    - Varianza: 1.0
#    - Trayectorias por modelo: 100
#    - Trayectorias teóricas: 1000
#
# ================================================================================
# 🚀 INICIANDO EVALUACIÓN DE 2 ESCENARIOS ARIMA
# ================================================================================
# 📊 Configuración:
#    - Trayectorias por modelo: 100
#    - Muestras teóricas por paso: 1000
#    - Pasos de predicción: 12
#    - Procesos ARIMA: 2
#    - Distribuciones: 1
#    - Varianzas: 1
#    - Procesos paralelos: 2
#    - Tamaño de lote: 10
#
# 📦 Procesando lote 1/1...
#    ✅ Lote 1 completado. Guardado intermedio en resultados_2_escenarios_trayectorias_arima.xlsx
#
# ================================================================================
# ✅ PROCESO COMPLETADO
# ================================================================================
# 📁 Resultados guardados en: resultados_2_escenarios_trayectorias_arima.xlsx
# 📊 Total de filas: 24
# 📈 Columnas: ['Paso', 'Paso_H', 'Config', 'Proceso', 'Dist', 'Distribución', 'Var', 'Varianza', 'LSPM', 'DeepAR', 'Sieve Bootstrap', 'MCPS']
#
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS - 100 TRAYECTORIAS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media ECRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    ECRPS Medio     Std
# ----------------------------------------------------------------------
# 1      LSPM                      2.799877      1.196748
# 2      Sieve Bootstrap           2.966584      1.527593
# 3      MCPS                      4.069704      1.476129
# 4      DeepAR                    7.847648      2.999258
#
# 🎯 2. VICTORIAS (Mejor modelo por cada paso-escenario)
# --------------------------------------------------------------------------------
#   LSPM                     :    9 victorias (37.5%)
#   Sieve Bootstrap          :    8 victorias (33.3%)
#   MCPS                     :    7 victorias (29.2%)
#   DeepAR                   :    0 victorias (0.0%)
#
# 📈 3. RENDIMIENTO POR HORIZONTE (Paso H)
# --------------------------------------------------------------------------------
#
# Paso   LSPM           DeepAR         Sieve BootstrapMCPS
# --------------------------------------------------------------------------------
# 1      0.795737       2.763087       0.597642       2.888951
# 2      1.179785       4.117622       1.143018       3.165289
# 3      1.967104       5.069351       1.658288       3.374480
# 4      1.962596       6.265879       2.094501       3.446484
# 5      2.847985       6.968020       2.494372       3.928988
# 6      2.606365       7.863965       2.920080       3.933360
# 7      3.156989       8.669657       3.329235       3.974376
# 8      3.465972       9.168112       3.689690       4.346991
# 9      3.415279       9.821045       4.018779       4.426402
# 10     4.013861       10.567105      4.301021       4.921780
# 11     4.068840       11.144019      4.528869       5.076963
# 12     4.118016       11.753911      4.823512       5.352383
#
# 🔄 4. RENDIMIENTO POR PROCESO ARMA
# --------------------------------------------------------------------------------
#
#   ARIMA(0,1,1):
#     LSPM                : 2.384137 (5 victorias)
#     DeepAR              : 7.968293 (0 victorias)
#     Sieve Bootstrap     : 2.376869 (7 victorias)
#     MCPS                : 5.148138 (0 victorias)
#
#   ARIMA(1,1,0):
#     LSPM                : 3.215618 (4 victorias)
#     DeepAR              : 7.727002 (0 victorias)
#     Sieve Bootstrap     : 3.556299 (1 victorias)
#     MCPS                : 2.991270 (7 victorias)
#
# 📊 5. RENDIMIENTO POR DISTRIBUCIÓN
# --------------------------------------------------------------------------------
#
#   normal:
#     LSPM                : 2.799877
#     DeepAR              : 7.847648
#     Sieve Bootstrap     : 2.966584
#     MCPS                : 4.069704
#
# 📉 6. RENDIMIENTO POR NIVEL DE VARIANZA
# --------------------------------------------------------------------------------
#
#   Varianza = 1.0:
#     LSPM                : 2.799877
#     DeepAR              : 7.847648
#     Sieve Bootstrap     : 2.966584
#     MCPS                : 4.069704
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# 📊 Generando gráficos de densidades...
#
# ⚠️ Error al generar gráficos: type object 'PlotManager' has no attribute 'plot_scenario_densities'
#    Los resultados en Excel están disponibles.
#
# ⏱  Tiempo total: 108.6s
#     Paso  Paso_H        Config       Proceso    Dist Distribución  Var  \
# 0      1       1  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 1      2       2  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 2      3       3  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 3      4       4  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 4      5       5  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 5      6       6  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 6      7       7  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 7      8       8  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 8      9       9  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 9     10      10  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 10    11      11  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 11    12      12  ARIMA(1,1,0)  ARIMA(1,1,0)  normal       normal  1.0
# 12     1       1  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 13     2       2  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 14     3       3  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 15     4       4  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 16     5       5  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 17     6       6  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 18     7       7  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 19     8       8  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 20     9       9  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 21    10      10  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 22    11      11  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
# 23    12      12  ARIMA(0,1,1)  ARIMA(0,1,1)  normal       normal  1.0
#
#     Varianza      LSPM     DeepAR  Sieve Bootstrap      MCPS
# 0        1.0  1.012451   1.008809         0.620550  0.867021
# 1        1.0  1.263296   2.547249         1.251898  1.105664
# 2        1.0  2.466478   4.049372         1.894876  1.607716
# 3        1.0  2.100826   5.333133         2.400808  2.083159
# 4        1.0  3.617075   6.514005         2.885654  2.490324
# 5        1.0  2.850719   7.542503         3.445313  2.880088
# 6        1.0  3.646159   8.634466         3.983157  3.259897
# 7        1.0  4.024428   9.596372         4.467193  3.669826
# 8        1.0  3.694564  10.500972         4.915841  3.954755
# 9        1.0  4.752253  11.343895         5.268952  4.332906
# 10       1.0  4.591272  12.372790         5.555117  4.669663
# 11       1.0  4.567895  13.280459         5.986225  4.974215
# 12       1.0  0.579022   4.517365         0.574735  4.910881
# 13       1.0  1.096274   5.687996         1.034137  5.224915
# 14       1.0  1.467730   6.089330         1.421700  5.141243
# 15       1.0  1.824365   7.198625         1.788195  4.809809
# 16       1.0  2.078895   7.422035         2.103091  5.367653
# 17       1.0  2.362011   8.185427         2.394847  4.986632
# 18       1.0  2.667820   8.704848         2.675313  4.688855
# 19       1.0  2.907517   8.739852         2.912188  5.024156
# 20       1.0  3.135994   9.141118         3.121718  4.898049
# 21       1.0  3.275470   9.790314         3.333090  5.510653
# 22       1.0  3.546407   9.915247         3.502620  5.484264
# 23       1.0  3.668137  10.227362         3.660798  5.730551

# %%
from runner import main_full_140_arima

main_full_140_arima()
# Out:
# ================================================================================
# SIMULACIÓN COMPLETA ARIMA - 140 ESCENARIOS CON 100 TRAYECTORIAS
# ================================================================================
# ================================================================================
# 🚀 INICIANDO EVALUACIÓN DE 140 ESCENARIOS ARIMA
# ================================================================================
# 📊 Configuración:
#    - Trayectorias por modelo: 100
#    - Muestras teóricas por paso: 1000
#    - Pasos de predicción: 12
#    - Procesos ARIMA: 7
#    - Distribuciones: 5
#    - Varianzas: 4
#    - Procesos paralelos: 4
#    - Tamaño de lote: 10
#
# 📦 Procesando lote 1/14...
#    ✅ Lote 1 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 2/14...
#    ✅ Lote 2 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 3/14...
#    ✅ Lote 3 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 4/14...
#    ✅ Lote 4 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 5/14...
#    ✅ Lote 5 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 6/14...
#    ✅ Lote 6 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 7/14...
#    ✅ Lote 7 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 8/14...
#    ✅ Lote 8 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 9/14...
#    ✅ Lote 9 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 10/14...
#    ✅ Lote 10 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 11/14...
#    ✅ Lote 11 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 12/14...
#    ✅ Lote 12 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 13/14...
#    ✅ Lote 13 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📦 Procesando lote 14/14...
#    ✅ Lote 14 completado. Guardado intermedio en resultados_140_trayectorias_ARIMA_FINAL.xlsx
#
# ================================================================================
# ✅ PROCESO COMPLETADO
# ================================================================================
# 📁 Resultados guardados en: resultados_140_trayectorias_ARIMA_FINAL.xlsx
# 📊 Total de filas: 1680
# 📈 Columnas: ['Paso', 'Paso_H', 'Config', 'Proceso', 'Dist', 'Distribución', 'Var', 'Varianza', 'LSPM', 'DeepAR', 'Sieve Bootstrap', 'MCPS']
#
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS - 100 TRAYECTORIAS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media ECRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    ECRPS Medio     Std
# ----------------------------------------------------------------------
# 1      Sieve Bootstrap           2.405825      2.338710
# 2      LSPM                      2.811590      3.018730
# 3      MCPS                      4.823525      7.367817
# 4      DeepAR                    7.970984      19.478564
#
# 🎯 2. VICTORIAS (Mejor modelo por cada paso-escenario)
# --------------------------------------------------------------------------------
#   Sieve Bootstrap          : 1073 victorias (63.9%)
#   LSPM                     :  395 victorias (23.5%)
#   DeepAR                   :  114 victorias (6.8%)
#   MCPS                     :   98 victorias (5.8%)
#
# 📈 3. RENDIMIENTO POR HORIZONTE (Paso H)
# --------------------------------------------------------------------------------
#
# Paso   LSPM           DeepAR         Sieve BootstrapMCPS
# --------------------------------------------------------------------------------
# 1      1.002821       3.872542       0.486049       2.520981
# 2      0.958940       4.890786       0.897482       3.078690
# 3      2.102267       5.763225       1.292882       3.529849
# 4      1.680196       6.518180       1.654240       4.060432
# 5      3.115841       7.199728       1.996865       4.307379
# 6      2.440953       7.878089       2.327139       4.854707
# 7      2.992917       8.554962       2.643865       5.217274
# 8      3.755505       9.149054       2.947641       5.486034
# 9      3.240410       9.664786       3.245641       5.801763
# 10     3.977981       10.243451      3.528925       6.064276
# 11     4.350008       10.749360      3.795161       6.333322
# 12     4.121245       11.167641      4.054009       6.627600
#
# 🔄 4. RENDIMIENTO POR PROCESO ARMA
# --------------------------------------------------------------------------------
#
#   ARIMA(0,1,0):
#     LSPM                : 1.264627 (74 victorias)
#     DeepAR              : 2.341805 (39 victorias)
#     Sieve Bootstrap     : 1.258138 (94 victorias)
#     MCPS                : 1.750618 (33 victorias)
#
#   ARIMA(0,1,1):
#     LSPM                : 2.338881 (71 victorias)
#     DeepAR              : 4.428522 (22 victorias)
#     Sieve Bootstrap     : 2.073699 (139 victorias)
#     MCPS                : 3.114639 (8 victorias)
#
#   ARIMA(0,1,2):
#     LSPM                : 2.810818 (43 victorias)
#     DeepAR              : 5.040843 (22 victorias)
#     Sieve Bootstrap     : 2.490862 (157 victorias)
#     MCPS                : 3.900911 (18 victorias)
#
#   ARIMA(1,1,0):
#     LSPM                : 2.697622 (59 victorias)
#     DeepAR              : 5.023436 (7 victorias)
#     Sieve Bootstrap     : 2.398017 (162 victorias)
#     MCPS                : 3.895445 (12 victorias)
#
#   ARIMA(1,1,1):
#     LSPM                : 2.573549 (43 victorias)
#     DeepAR              : 8.017949 (10 victorias)
#     Sieve Bootstrap     : 2.334741 (178 victorias)
#     MCPS                : 5.027922 (9 victorias)
#
#   ARIMA(2,1,0):
#     LSPM                : 1.824150 (68 victorias)
#     DeepAR              : 5.638736 (6 victorias)
#     Sieve Bootstrap     : 1.703742 (155 victorias)
#     MCPS                : 3.281428 (11 victorias)
#
#   ARIMA(2,1,2):
#     LSPM                : 6.171485 (37 victorias)
#     DeepAR              : 25.305595 (8 victorias)
#     Sieve Bootstrap     : 4.581575 (188 victorias)
#     MCPS                : 12.793715 (7 victorias)
#
# 📊 5. RENDIMIENTO POR DISTRIBUCIÓN
# --------------------------------------------------------------------------------
#
#   exponential:
#     LSPM                : 3.258067
#     DeepAR              : 5.938278
#     Sieve Bootstrap     : 2.703769
#     MCPS                : 5.327852
#
#   mixture:
#     LSPM                : 1.625198
#     DeepAR              : 4.132024
#     Sieve Bootstrap     : 1.192571
#     MCPS                : 3.194999
#
#   normal:
#     LSPM                : 2.956036
#     DeepAR              : 12.850648
#     Sieve Bootstrap     : 2.720316
#     MCPS                : 5.175536
#
#   t-student:
#     LSPM                : 2.926987
#     DeepAR              : 5.526899
#     Sieve Bootstrap     : 2.622986
#     MCPS                : 3.854589
#
#   uniform:
#     LSPM                : 3.291664
#     DeepAR              : 11.407069
#     Sieve Bootstrap     : 2.789482
#     MCPS                : 6.564652
#
# 📉 6. RENDIMIENTO POR NIVEL DE VARIANZA
# --------------------------------------------------------------------------------
#
#   Varianza = 0.2:
#     LSPM                : 1.327954
#     DeepAR              : 3.562048
#     Sieve Bootstrap     : 1.108826
#     MCPS                : 2.365917
#
#   Varianza = 0.5:
#     LSPM                : 2.041637
#     DeepAR              : 4.605896
#     Sieve Bootstrap     : 1.764197
#     MCPS                : 3.055319
#
#   Varianza = 1.0:
#     LSPM                : 2.956948
#     DeepAR              : 5.698812
#     Sieve Bootstrap     : 2.464162
#     MCPS                : 4.243257
#
#   Varianza = 3.0:
#     LSPM                : 4.919822
#     DeepAR              : 18.017179
#     Sieve Bootstrap     : 4.286113
#     MCPS                : 9.629610
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# 📊 Generando gráficos resumidos...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 from runner import main_full_140_arima
# ----> 3 main_full_140_arima()
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones_h_pasos\codigo_base\runner.py:315, in main_full_140_arima()
#     312     step_data = df_final[df_final['Paso_H'] == h][model_cols].mean().to_frame().T
#     313     results_by_step[h] = step_data
# --> 315 PlotManager.plot_ecrps_evolution(
#     316     results_by_step, model_cols,
#     317     save_path="evolucion_ecrps_horizonte_arima.png"
#     318 )
#     320 # Resumen general
#     321 PlotManager.plot_results_summary(
#     322     df_final, model_cols,
#     323     step_name="Todos los escenarios ARIMA",
#     324     save_path="resumen_global_ecrps_arima.png"
#     325 )
#
# AttributeError: type object 'PlotManager' has no attribute 'plot_ecrps_evolution'
