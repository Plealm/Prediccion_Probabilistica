# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones_h_pasos\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_two_scenarios

main_two_scenarios()  # Descomenta para correr solo 2 escenarios
# Out:
# ================================================================================
# EVALUACIÓN CON 2 ESCENARIOS (100 TRAYECTORIAS CADA UNO)
# ================================================================================
#
# 📊 Configuración:
#    - Escenarios: 2 (AR(1) y MA(1))
#    - Distribución: Normal
#    - Varianza: 1.0
#    - Trayectorias por modelo: 100
#    - Trayectorias teóricas: 1000
#
# ================================================================================
# 🚀 INICIANDO EVALUACIÓN DE 2 ESCENARIOS
# ================================================================================
# 📊 Configuración:
#    - Trayectorias por modelo: 100
#    - Trayectorias teóricas: 1000
#    - Pasos de predicción: 12
#    - Procesos ARMA: 2
#    - Distribuciones: 1
#    - Varianzas: 1
#    - Procesos paralelos: 2
# Escenarios: 100%|██████████| 2/2 [00:00<00:00, 51.17it/s]
# ================================================================================
# ✅ PROCESO COMPLETADO
# ================================================================================
# 📁 Resultados guardados en: resultados_2_escenarios_trayectorias.xlsx
# 📊 Total de filas: 24
# 📈 Columnas: ['Paso_H', 'Proceso', 'Distribución', 'Varianza', 'LSPM', 'DeepAR', 'Sieve Bootstrap', 'MCPS']
#
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS - 100 TRAYECTORIAS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media ECRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    ECRPS Medio     Std
# ----------------------------------------------------------------------
# 1      Sieve Bootstrap           1.046902      0.363413
# 2      LSPM                      1.055160      0.352243
# 3      DeepAR                    1.065050      0.374228
# 4      MCPS                      1.069252      0.364697
#
# 🎯 2. VICTORIAS (Mejor modelo por cada paso-escenario)
# --------------------------------------------------------------------------------
#   LSPM                     :   10 victorias (41.7%)
#   Sieve Bootstrap          :    7 victorias (29.2%)
#   DeepAR                   :    6 victorias (25.0%)
#   MCPS                     :    1 victorias (4.2%)
#
# 📈 3. RENDIMIENTO POR HORIZONTE (Paso H)
# --------------------------------------------------------------------------------
#
# Paso   LSPM           DeepAR         Sieve BootstrapMCPS
# --------------------------------------------------------------------------------
# 1      1.094017       1.114943       1.105230       1.074547
# 2      1.115949       1.057937       1.065857       1.077048
# 3      1.034814       1.045021       1.037255       1.069798
# 4      1.120050       1.097365       1.080550       1.106724
# 5      1.069178       1.108864       1.073468       1.102700
# 6      1.071664       1.077227       1.051217       1.075785
# 7      1.031828       1.063143       1.033747       1.059914
# 8      1.037356       1.042889       1.021595       1.041574
# 9      0.996709       1.005907       0.992859       1.006444
# 10     1.005444       1.021824       1.013932       1.041118
# 11     1.016119       1.047665       1.020215       1.068141
# 12     1.068792       1.097813       1.066897       1.107230
#
# 🔄 4. RENDIMIENTO POR PROCESO ARMA
# --------------------------------------------------------------------------------
#
#   AR(1):
#     LSPM                : 1.396026 (8 victorias)
#     DeepAR              : 1.429397 (1 victorias)
#     Sieve Bootstrap     : 1.400387 (2 victorias)
#     MCPS                : 1.424718 (1 victorias)
#
#   MA(1):
#     LSPM                : 0.714294 (2 victorias)
#     DeepAR              : 0.700703 (5 victorias)
#     Sieve Bootstrap     : 0.693417 (5 victorias)
#     MCPS                : 0.713786 (0 victorias)
#
# 📊 5. RENDIMIENTO POR DISTRIBUCIÓN
# --------------------------------------------------------------------------------
#
#   normal:
#     LSPM                : 1.055160
#     DeepAR              : 1.065050
#     Sieve Bootstrap     : 1.046902
#     MCPS                : 1.069252
#
# 📉 6. RENDIMIENTO POR NIVEL DE VARIANZA
# --------------------------------------------------------------------------------
#
#   Varianza = 1.0:
#     LSPM                : 1.055160
#     DeepAR              : 1.065050
#     Sieve Bootstrap     : 1.046902
#     MCPS                : 1.069252
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# 📊 Generando gráficos de densidades...
#   ✅ Gráfico guardado: graficos_densidades/densidades_AR(1)_normal_var1.0.png
#   ✅ Gráfico guardado: graficos_densidades/densidades_MA(1)_normal_var1.0.png
#
# ✅ Gráficos guardados en: graficos_densidades/
#
# ⏱  Tiempo total: 60.7s
#     Paso_H Proceso Distribución  Varianza      LSPM    DeepAR  \
# 0        1   AR(1)       normal       1.0  1.466262  1.478662
# 1        2   AR(1)       normal       1.0  1.510064  1.407600
# 2        3   AR(1)       normal       1.0  1.375705  1.382173
# 3        4   AR(1)       normal       1.0  1.529411  1.481701
# 4        5   AR(1)       normal       1.0  1.420278  1.510761
# 5        6   AR(1)       normal       1.0  1.409145  1.442384
# 6        7   AR(1)       normal       1.0  1.361958  1.451558
# 7        8   AR(1)       normal       1.0  1.355894  1.412950
# 8        9   AR(1)       normal       1.0  1.301266  1.358039
# 9       10   AR(1)       normal       1.0  1.323946  1.361952
# 10      11   AR(1)       normal       1.0  1.308000  1.400072
# 11      12   AR(1)       normal       1.0  1.390380  1.464908
# 12       1   MA(1)       normal       1.0  0.721773  0.751224
# 13       2   MA(1)       normal       1.0  0.721834  0.708273
# 14       3   MA(1)       normal       1.0  0.693923  0.707868
# 15       4   MA(1)       normal       1.0  0.710690  0.713029
# 16       5   MA(1)       normal       1.0  0.718077  0.706966
# 17       6   MA(1)       normal       1.0  0.734183  0.712070
# 18       7   MA(1)       normal       1.0  0.701698  0.674728
# 19       8   MA(1)       normal       1.0  0.718818  0.672829
# 20       9   MA(1)       normal       1.0  0.692152  0.653775
# 21      10   MA(1)       normal       1.0  0.686942  0.681695
# 22      11   MA(1)       normal       1.0  0.724238  0.695258
# 23      12   MA(1)       normal       1.0  0.747204  0.730718
#
#     Sieve Bootstrap      MCPS
# 0          1.531724  1.425975
# 1          1.430614  1.448835
# 2          1.376864  1.426169
# 3          1.442420  1.492185
# 4          1.435970  1.493254
# 5          1.387172  1.428243
# 6          1.389677  1.410445
# 7          1.375720  1.386031
# 8          1.335640  1.346470
# 9          1.356934  1.389226
# 10         1.343781  1.399948
# 11         1.398132  1.449829
# 12         0.678737  0.723119
# 13         0.701101  0.705260
# 14         0.697646  0.713428
# 15         0.718681  0.721263
# 16         0.710965  0.712146
# 17         0.715263  0.723327
# 18         0.677817  0.709382
# 19         0.667470  0.697118
# 20         0.650079  0.666419
# 21         0.670931  0.693009
# 22         0.696649  0.736335
# 23         0.735663  0.764631

# %%
from runner import main_full_140

main_full_140()
# Out:
# ================================================================================
# INICIANDO SIMULACIÓN DE 140 ESCENARIOS CON 100 TRAYECTORIAS
# ================================================================================
# 🚀 Iniciando evaluación de 140 escenarios con 100 trayectorias cada uno...
# 100%|██████████| 140/140 [35:18<00:00, 15.13s/it]
# ✅ Proceso completado. Resultados guardados en resultados_140_trayectorias_FINAL.xlsx
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS - 100 TRAYECTORIAS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media CRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    CRPS Medio
# ------------------------------------------------------------
# 1      Sieve Bootstrap           0.787471
# 2      LSPM                      0.869012
# 3      DeepAR                    0.869357
# 4      MCPS                      0.920303
#
# 🎯 2. VICTORIAS (Mejor modelo por cada paso-escenario)
# --------------------------------------------------------------------------------
#   DeepAR                   :  444 victorias (26.4%)
#   MCPS                     :  430 victorias (25.6%)
#   LSPM                     :  416 victorias (24.8%)
#   Sieve Bootstrap          :  390 victorias (23.2%)
#
# 📈 3. RENDIMIENTO POR HORIZONTE (Paso H)
# --------------------------------------------------------------------------------
#
#   Paso H=1:
#     LSPM                : 0.814038
#     DeepAR              : 0.561291
#     Sieve Bootstrap     : 0.534679
#     MCPS                : 0.642849
#
#   Paso H=2:
#     LSPM                : 0.706839
#     DeepAR              : 0.702125
#     Sieve Bootstrap     : 0.671137
#     MCPS                : 0.727114
#
#   Paso H=3:
#     LSPM                : 0.864260
#     DeepAR              : 0.801374
#     Sieve Bootstrap     : 0.722081
#     MCPS                : 0.820007
#
#   Paso H=4:
#     LSPM                : 0.831395
#     DeepAR              : 0.892428
#     Sieve Bootstrap     : 0.768630
#     MCPS                : 0.825321
#
#   Paso H=5:
#     LSPM                : 0.960881
#     DeepAR              : 0.933915
#     Sieve Bootstrap     : 0.797427
#     MCPS                : 0.885146
#
#   Paso H=6:
#     LSPM                : 0.880791
#     DeepAR              : 0.932196
#     Sieve Bootstrap     : 0.834950
#     MCPS                : 0.929460
#
#   Paso H=7:
#     LSPM                : 0.904982
#     DeepAR              : 0.905481
#     Sieve Bootstrap     : 0.809817
#     MCPS                : 0.916696
#
#   Paso H=8:
#     LSPM                : 0.840992
#     DeepAR              : 0.910739
#     Sieve Bootstrap     : 0.835985
#     MCPS                : 0.978396
#
#   Paso H=9:
#     LSPM                : 0.859827
#     DeepAR              : 0.893945
#     Sieve Bootstrap     : 0.849812
#     MCPS                : 1.083310
#
#   Paso H=10:
#     LSPM                : 0.872587
#     DeepAR              : 0.899946
#     Sieve Bootstrap     : 0.817512
#     MCPS                : 1.055905
#
#   Paso H=11:
#     LSPM                : 0.936439
#     DeepAR              : 0.984274
#     Sieve Bootstrap     : 0.879502
#     MCPS                : 1.057063
#
#   Paso H=12:
#     LSPM                : 0.955114
#     DeepAR              : 1.014568
#     Sieve Bootstrap     : 0.928124
#     MCPS                : 1.122364
#
# 🔄 4. RENDIMIENTO POR PROCESO ARMA
# --------------------------------------------------------------------------------
#
#   AR(1):
#     LSPM                : 1.026542
#     DeepAR              : 1.002470
#     Sieve Bootstrap     : 0.924182
#     MCPS                : 1.293949
#
#   AR(2):
#     LSPM                : 0.608563
#     DeepAR              : 0.613970
#     Sieve Bootstrap     : 0.595457
#     MCPS                : 0.608343
#
#   ARMA(1,1):
#     LSPM                : 0.961375
#     DeepAR              : 0.938336
#     Sieve Bootstrap     : 0.857351
#     MCPS                : 0.901034
#
#   ARMA(2,1):
#     LSPM                : 1.189110
#     DeepAR              : 1.482019
#     Sieve Bootstrap     : 1.067594
#     MCPS                : 1.458319
#
#   ARMA(2,2):
#     LSPM                : 0.930284
#     DeepAR              : 0.809835
#     Sieve Bootstrap     : 0.815446
#     MCPS                : 0.850573
#
#   MA(1):
#     LSPM                : 0.782679
#     DeepAR              : 0.652759
#     Sieve Bootstrap     : 0.659767
#     MCPS                : 0.708270
#
#   MA(2):
#     LSPM                : 0.584532
#     DeepAR              : 0.586108
#     Sieve Bootstrap     : 0.592503
#     MCPS                : 0.621630
#
# 📊 5. RENDIMIENTO POR DISTRIBUCIÓN
# --------------------------------------------------------------------------------
#
#   exponential:
#     LSPM                : 0.774884
#     DeepAR              : 0.808674
#     Sieve Bootstrap     : 0.689195
#     MCPS                : 0.882039
#
#   mixture:
#     LSPM                : 0.862585
#     DeepAR              : 0.917617
#     Sieve Bootstrap     : 0.801515
#     MCPS                : 0.891390
#
#   normal:
#     LSPM                : 0.971346
#     DeepAR              : 0.866922
#     Sieve Bootstrap     : 0.862745
#     MCPS                : 0.999208
#
#   t-student:
#     LSPM                : 0.803640
#     DeepAR              : 0.839421
#     Sieve Bootstrap     : 0.765854
#     MCPS                : 0.882237
#
#   uniform:
#     LSPM                : 0.932605
#     DeepAR              : 0.914151
#     Sieve Bootstrap     : 0.818047
#     MCPS                : 0.946639
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# ⏱  Tiempo total: 2242.7s (0.62 horas)
#       Paso_H proces_simulacion Distribución  Varianza  Valor_Real      LSPM  \
# 0          1             AR(1)       normal       0.2   -0.196414  0.107587
# 1          2             AR(1)       normal       0.2   -0.108544  0.104158
# 2          3             AR(1)       normal       0.2    0.560381  0.361844
# 3          4             AR(1)       normal       0.2   -0.643501  0.201137
# 4          5             AR(1)       normal       0.2   -0.685074  0.358362
# ...      ...               ...          ...       ...         ...       ...
# 1675       8         ARMA(2,1)      mixture       3.0   -3.687029  0.884089
# 1676       9         ARMA(2,1)      mixture       3.0   -4.592007  1.132926
# 1677      10         ARMA(2,1)      mixture       3.0   -3.897565  1.070619
# 1678      11         ARMA(2,1)      mixture       3.0   -4.054822  1.019281
# 1679      12         ARMA(2,1)      mixture       3.0   -5.821369  1.771466
#
#         DeepAR  Sieve Bootstrap      MCPS
# 0     0.116088         0.079217  0.218496
# 1     0.136190         0.139773  0.205657
# 2     0.522413         0.471601  0.316376
# 3     0.217361         0.236298  0.436701
# 4     0.231435         0.286553  0.502421
# ...        ...              ...       ...
# 1675  2.145297         1.277092  2.002665
# 1676  1.801442         1.702918  2.942195
# 1677  2.294436         1.753094  2.543343
# 1678  2.189363         1.950010  2.703640
# 1679  1.575572         3.117796  4.050947
#
# [1680 rows x 9 columns]
