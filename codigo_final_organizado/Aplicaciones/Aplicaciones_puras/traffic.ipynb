# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Aplicaciones\Aplicaciones_puras\Codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
import warnings
from pipeline import PipelineTraffic
from plot import visualize_predictions

# Ignorar advertencias para mantener la salida limpia
warnings.filterwarnings("ignore")

if __name__ == "__main__":
    print("🚦 INICIANDO EXPERIMENTO DE TRÁFICO")
    print("="*40)

    # 1. Instanciar el pipeline asignándolo a la variable CORRECTA
    traffic_pipeline = PipelineTraffic(  
        n_boot=1000,
        seed=42,
        val_ratio=0.15,
        max_data_points=2160, # Recorte a ~3 meses de datos
        verbose=True
    )

    # 2. Ejecutar visualización
    # Esto generará:
    # - Gráficas verticales separadas (9 modelos uno bajo otro)
    # - Gráficas superpuestas (Top 3 Mejores, Peores, etc.)
    # - Excel con métricas
    visualize_predictions(
        pipeline=traffic_pipeline,      
        series_index=0, 
        output_prefix="traffic",
        output_folder="resultados_traffic"
    )
    
    print("\n✅ Proceso finalizado. Revisa la carpeta 'resultados_traffic'.")
# Out:
# c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\.venv\Lib\site-packages\gluonts\json.py:102: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(
# 🚦 INICIANDO EXPERIMENTO DE TRÁFICO
# ========================================
#
# 🎨 Iniciando visualización avanzada para serie 0...
# ============================================================
# 🚦 TRAFFIC DATASET - Serie 0
# ============================================================
# Cargando dataset: Traffic...
#
# ⚡ OPTIMIZACIÓN EFICIENTE (9 Modelos)
# Optimizando Sieve Bootstrap:  11%|█         | 1/9 [00:03<00:31,  3.98s/modelo]
#   ✓ Block Bootstrapping : Mejor CRPS=0.0137 [4.0s]
# Optimizando LSPMW:  22%|██▏       | 2/9 [00:06<00:22,  3.28s/modelo]
#   ✓ Sieve Bootstrap     : Mejor CRPS=0.0048 [2.8s]
# Optimizando AREPD:  44%|████▍     | 4/9 [00:09<00:10,  2.03s/modelo]
#   ✓ LSPMW               : Mejor CRPS=0.0075 [2.6s]
# Optimizando MCPS:  56%|█████▌    | 5/9 [00:10<00:07,  1.90s/modelo]
#   ✓ AREPD               : Mejor CRPS=0.0138 [1.6s]
# Optimizando AV-MCPS:  67%|██████▋   | 6/9 [00:14<00:07,  2.45s/modelo]
#   ✓ MCPS                : Mejor CRPS=0.0028 [3.7s]
# Optimizando DeepAR:  78%|███████▊  | 7/9 [00:15<00:03,  1.91s/modelo]
#   ✓ AV-MCPS             : Mejor CRPS=0.0028 [0.7s]
#   Early stopping at epoch 9
#   Early stopping at epoch 13
#   Early stopping at epoch 11
#   Early stopping at epoch 9
# Optimizando EnCQR-LSTM:  89%|████████▉ | 8/9 [02:10<00:36, 36.24s/modelo]
#   ✓ DeepAR              : Mejor CRPS=0.0034 [115.1s]
# Optimizando EnCQR-LSTM: 100%|██████████| 9/9 [31:15<00:00, 208.39s/modelo]
#   ✓ EnCQR-LSTM          : Mejor CRPS=0.0054 [1745.0s]
#
# 🔒 Fase 2: Congelamiento (Entrenamiento Final)
# Congelando modelos:  67%|██████▋   | 6/9 [00:00<00:00, 54.08it/s]
#   CBB congelado: block_length=48
#   Sieve Bootstrap congelado: order=24, n_residuos=2112
#   LSPM congelado: n_lags=12
#   LSPM congelado: n_lags=12
#   ✅ LSPMW congelado: ρ=0.95, n_lags=12, n_critical=2123
#   AREPD congelado: n_lags=24, rho=0.95, mean=0.0462, std=0.0478
#   MCPS congelado: n_lags=12, n_bins=5
#   Early stopping at epoch 7
#   DeepAR congelado: mean=0.0462, std=0.0478, model_trained=True
# Congelando modelos: 100%|██████████| 9/9 [00:52<00:00,  5.80s/it]
#   ✓ EnCQR-LSTM congelado con KDE: n_lags=24, B=3, units=48
#
# 🔮 Fase 3: Predicción (24 pasos)
# Prediciendo Steps: 100%|██████████| 24/24 [00:27<00:00,  1.16s/it]
#  📊 Generando Reporte Estadístico Agregado (Diagnóstico)...
#   💾 Excel guardado: resultados_traffic\traffic_resultados_full.xlsx
#
#   📸 Generando Imágenes Tipo A (Vertical Stack 24 Pasos)...
#
#   📸 Generando Imágenes Tipo B (Corte Transversal Pasos 1, 8, 16, 24)...
#
# 🔬 Ejecutando Análisis Estadístico en 'resultados_traffic\Analisis'...
#    ✓ Ranking HLN-DM guardado: resultados_traffic\Analisis\Ranking_Estadistico_HLN_DM.xlsx
#    ✓ Bonferroni α = 0.001389 (36 comparaciones)
#    ✓ Análisis completo guardado en 'resultados_traffic\Analisis'
#
# ✨ Visualización completada.
#    - Tipo A: 12 imágenes (24 subplots verticales).
#    - Tipo B: 4 imágenes.
#    - Diagnóstico: PIT/Reliability.
#    - Análisis: Carpeta 'Analisis' con Rankings y Heatmaps (HLN-DM).
#
# ✅ Proceso finalizado. Revisa la carpeta 'resultados_traffic'.
