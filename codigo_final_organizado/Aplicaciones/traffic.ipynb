# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Aplicaciones/Codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from pipeline import PipelineTraffic
from plot import visualize_predictions

# 1. Instanciar el pipeline asignándolo a la variable CORRECTA
traffic_pipeline = PipelineTraffic(  
    n_boot=1000,
    seed=42,
    val_ratio=0.15,
    max_data_points=2160,
    verbose=True
)

# 2. Ejecutar visualización
visualize_predictions(
    pipeline=traffic_pipeline,      
    series_index=0, 
    output_prefix="traffic",
    output_folder="resultados_traffic"
)
# Out:
# 🎨 Generando visualizaciones detalladas para la serie 0...
# ============================================================
# 🚦 TRAFFIC DATASET - Serie 0
# ============================================================
# Cargando dataset: Traffic...
#
# ⚡ OPTIMIZACIÓN EFICIENTE (9 Modelos)
# Optimizando Sieve Bootstrap:  11%|█         | 1/9 [00:01<00:11,  1.49s/modelo]
#   ✓ Block Bootstrapping : Mejor CRPS=0.0137 [1.5s]
# Optimizando LSPMW:  22%|██▏       | 2/9 [00:03<00:12,  1.77s/modelo]
#   ✓ Sieve Bootstrap     : Mejor CRPS=0.0048 [2.0s]
# Optimizando AREPD:  44%|████▍     | 4/9 [00:05<00:06,  1.34s/modelo]
#   ✓ LSPMW               : Mejor CRPS=0.0074 [2.1s]
# Optimizando MCPS:  56%|█████▌    | 5/9 [00:07<00:05,  1.40s/modelo]
#   ✓ AREPD               : Mejor CRPS=0.0138 [1.5s]
# Optimizando AV-MCPS:  67%|██████▋   | 6/9 [00:10<00:05,  1.95s/modelo]
#   ✓ MCPS                : Mejor CRPS=0.0028 [3.2s]
# Optimizando DeepAR:  78%|███████▊  | 7/9 [00:10<00:03,  1.53s/modelo]
#   ✓ AV-MCPS             : Mejor CRPS=0.0028 [0.6s]
#   Early stopping at epoch 9
#   Early stopping at epoch 13
#   Early stopping at epoch 11
#   Early stopping at epoch 9
# Optimizando EnCQR-LSTM:  89%|████████▉ | 8/9 [01:26<00:24, 24.11s/modelo]Exception ignored in: <function EnCQR_LSTM_Model.__del__ at 0x00000256C9D48B80>
# Traceback (most recent call last):
#   File "C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Aplicaciones/Codigo_base\modelos.py", line 1755, in __del__
#     self._cleanup()
#   File "C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Aplicaciones/Codigo_base\modelos.py", line 1477, in _cleanup
#     self.tf.keras.backend.clear_session()
#     ^^^^^^^
# AttributeError: 'EnCQR_LSTM_Model' object has no attribute 'tf'
#   ✓ DeepAR              : Mejor CRPS=0.0034 [76.0s]
# Exception ignored in: <function EnCQR_LSTM_Model.__del__ at 0x00000256C9D48B80>
# Traceback (most recent call last):
#   File "C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Aplicaciones/Codigo_base\modelos.py", line 1755, in __del__
#     self._cleanup()
#   File "C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Aplicaciones/Codigo_base\modelos.py", line 1477, in _cleanup
#     self.tf.keras.backend.clear_session()
#     ^^^^^^^
# AttributeError: 'EnCQR_LSTM_Model' object has no attribute 'tf'
# Optimizando EnCQR-LSTM: 100%|██████████| 9/9 [22:25<00:00, 149.52s/modelo]
#   ✓ EnCQR-LSTM          : Mejor CRPS=0.0053 [1258.8s]
#
# 🔒 Fase 2: Congelamiento (Entrenamiento Final)
# Congelando modelos:  67%|██████▋   | 6/9 [00:00<00:00, 57.77it/s]
#   CBB congelado: block_length=48
#   Sieve Bootstrap congelado: order=24, n_residuos=2112
#   LSPM congelado: n_lags=12
#   LSPM congelado: n_lags=12
#   ✅ LSPMW congelado: ρ=0.95, n_lags=12, n_critical=2123
#   AREPD congelado: n_lags=24, rho=0.95, mean=0.0462, std=0.0478
#   MCPS congelado: n_lags=12, n_bins=5
#   Early stopping at epoch 7
#   DeepAR congelado: mean=0.0462, std=0.0478, model_trained=True
# Congelando modelos: 100%|██████████| 9/9 [00:40<00:00,  4.54s/it]
#   ✓ EnCQR-LSTM congelado con KDE: n_lags=24, B=3, units=48
#
# 🔮 Fase 3: Predicción (24 pasos)
# Prediciendo Steps: 100%|██████████| 24/24 [00:24<00:00,  1.02s/it]
#   💾 Resultados guardados en: resultados_traffic\traffic_resultados.xlsx
#   🏆 Mejores 3: Sieve Bootstrap, AV-MCPS, MCPS
#   💀 Peores 3:  Block Bootstrapping, AREPD, LSPMW
#
#   📸 Generando imágenes individuales...
#   ✅ Guardado: resultados_traffic\traffic_modelo_Block Bootstrapping.png
#   ✅ Guardado: resultados_traffic\traffic_modelo_Sieve Bootstrap.png
#   ✅ Guardado: resultados_traffic\traffic_modelo_LSPM.png
#   ✅ Guardado: resultados_traffic\traffic_modelo_LSPMW.png
#   ✅ Guardado: resultados_traffic\traffic_modelo_AREPD.png
#   ✅ Guardado: resultados_traffic\traffic_modelo_MCPS.png
#   ✅ Guardado: resultados_traffic\traffic_modelo_AV-MCPS.png
#   ✅ Guardado: resultados_traffic\traffic_modelo_DeepAR.png
#   ✅ Guardado: resultados_traffic\traffic_modelo_EnCQR-LSTM.png
#
#   📸 Generando comparativas...
#   ✅ Guardado: resultados_traffic\traffic_COMPARACION_TOP3_MEJORES.png
#   ✅ Guardado: resultados_traffic\traffic_COMPARACION_TOP3_PEORES.png
#   ✅ Guardado: resultados_traffic\traffic_COMPARACION_TOP2_VS_PEOR.png
#
# ✨ Proceso finalizado. Revisa la carpeta 'resultados_traffic'.
