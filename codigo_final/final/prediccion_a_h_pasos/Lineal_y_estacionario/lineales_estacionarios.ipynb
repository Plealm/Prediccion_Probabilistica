# %%
from pipeline import ScenarioRunnerMejorado


print("="*80)
print("INICIANDO SIMULACIÓN DE PRONÓSTICO MULTI-STEP")
print("ADVERTENCIA: El proceso es computacionalmente intensivo.")
print("="*80)
    
runner = ScenarioRunnerMejorado()
runner.run(
        n_scenarios=1,          # <<-- EMPEZAR CON UN NÚMERO MUY BAJO
        excel_filename="resultados_multistep_test_final.xlsx",
        batch_size=1,           # Lotes pequeños
        restart_every=1,        # Reiniciar el pool de procesos frecuentemente
        plot=False              # Desactivar para las primeras pruebas, consume mucho disco
    )
# Out:
# ...
# INICIANDO SIMULACIÓN DE PRONÓSTICO MULTI-STEP
# ADVERTENCIA: El proceso es computacionalmente intensivo.
# ...
# Ejecutando 1 escenarios en 1 lotes.
#
# ...
# LOTE 1/1 (Escenarios 1-1)
# ...
#     Sublote 1/1
# ...
#       Escenarios: 100%|██████████| 1/1 [08:02<00:00, 482.24s/it]
#   Limpiando memoria del lote...
#
# ✅ 6 filas de resultados guardadas en 'resultados_multistep_test_final.xlsx'
# c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final\final\prediccion_a_h_pasos\Lineal_y_estacionario\pipeline.py:1446: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(ax=axes[0], data=df_melted, x='Modelo', y='ECRPS', palette='viridis')
# c:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final\final\prediccion_a_h_pasos\Lineal_y_estacionario\pipeline.py:1446: FutureWarning:
#
# ...
